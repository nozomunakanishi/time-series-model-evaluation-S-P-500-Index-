# %%
# Importing the necessary libraries for the project. 
import pandas as pd 
import yfinance as yf
import numpy as np # for numerical operations
import seaborn as sns #visualisation
import matplotlib.pyplot as plt # visualization
# %matplotlib inline 
import matplotlib.ticker as ticker # Library to customize ticks
from datetime import date
import matplotlib.dates as mdates
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from math import sqrt
# Mean Squared Error and Mean Absolute Error metrics from sklearn for evaluating model accuracy.
from tensorflow.keras.losses import MeanAbsoluteError, MeanSquaredError
from sklearn.metrics import mean_squared_error, mean_absolute_error
# TimeSeriesSplit for cross-validation with time series data to preserve the temporal ordering of data.
from sklearn.model_selection import TimeSeriesSplit
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterSampler
from tensorflow.keras.optimizers import Adam
from keras.layers import BatchNormalization, Dropout, Dense, LSTM
import random
import optuna
from optuna.samplers import TPESampler
from keras_tuner import BayesianOptimization

import warnings # filter warnings
warnings.filterwarnings('ignore')

# %%
# Importing the dataset after the Log Returns transformation.
df1 = pd.read_csv('df1.csv', index_col=0, parse_dates=True)

# Along with the importation, the code will set the date as the index, value of 0 because is the first column.
## Setting parse_dates=true to ensure the dates are in datetime, making more appropriate for ML models.

# %%
df1.describe()
# Out:
#              Close        lag_1        lag_4  rolling_mean_4w  \
# count  1031.000000  1031.000000  1031.000000      1031.000000
# mean      0.001575     0.001608     0.001508         0.001578
# std       0.020723     0.020744     0.020750         0.009796
# min      -0.069935    -0.069935    -0.069935        -0.051352
# 25%      -0.007633    -0.007633    -0.007858        -0.003032
# 50%       0.003635     0.003666     0.003626         0.002937
# 75%       0.013568     0.013643     0.013514         0.007596
# max       0.051947     0.051947     0.051947         0.031089
#
#        rolling_mean_12w  volatility_4w
# count       1031.000000    1031.000000
# mean           0.001516       7.731465
# std            0.005364      23.505939
# min           -0.026288       0.154122
# 25%           -0.001013       1.538535
# 50%            0.002346       2.585030
# 75%            0.004979       6.157669
# max            0.019145     338.128664

# %%
# Define the selected exogenous variables and target variable.
features = df1[['rolling_mean_4w', 'rolling_mean_12w', 'volatility_4w', 'lag_1', 'lag_4']]
target = df1['Close']

# %%
# Split data into training and testing sets, same ratio applied in SARIMAX.
train_size = int(0.85 * len(features))
X_train, X_test = features[:train_size], features[train_size:]
y_train, y_test = target[:train_size], target[train_size:]

# Initialize and fit RobustScalers to scale data with reduced sensitivity to outliers.
scaler_X = RobustScaler()
scaler_y = RobustScaler()

# Fit scalers on training data and transform both training and test data.
X_train_scaled = scaler_X.fit_transform(X_train) # Fit scaler on training features and transform.
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)) # Fit scaler on training target and transform.

# Transform test data without fitting again to avoid data leakage.
X_test_scaled = scaler_X.transform(X_test) # Transform test features using the scaler fitted on training data.
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1)) # Transform test target using the scaler fitted on training data

# Print minimum and maximum values of the scaled training and test data for verification.
print("Scaled Training Features - Min:", X_train_scaled.min(), "Max:", X_train_scaled.max())
print("Scaled Training Target - Min:", y_train_scaled.min(), "Max:", y_train_scaled.max())
print("Scaled Test Features - Min:", X_test_scaled.min(), "Max:", X_test_scaled.max())
print("Scaled Test Target - Min:", y_test_scaled.min(), "Max:", y_test_scaled.max())
# Out:
# Scaled Training Features - Min: -5.403959826651211 Max: 27.13019517164182
# Scaled Training Target - Min: -3.6389567455761282 Max: 2.3883417923341392
# Scaled Test Features - Min: -3.6389567455761282 Max: 79.04390234398078
# Scaled Test Target - Min: -3.6389567455761282 Max: 2.3883417923341392

# %% [markdown]
# **Different values for sequence length will be tested in all models that requires this value in the input (LSTM, GRU and Bi-LSTM)**
#
# - Despite the true value of number of weeks not being a interger (approx,: 52.14), the input (sequence length) has to a interger number, thus the values to be tested are 4 (month), 12 (quarter), 26 (six months) and (52 year).

# %% [markdown]
# ## Sequence Length = 4

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 4  # Number of time steps used for target prediction, 4 weeks.

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (872, 4, 5)
# Reshaped y_train_seq shape: (872, 1)
# Reshaped X_test_seq shape: (151, 4, 5)
# Reshaped  y_test_seq shape: (151, 1)

# %% [markdown]
# The workflow of the LSTM will follow:
# - Random Parameters with 2 layers (check improvements without any hyperparamenter tunning, just random values).
# - Random Parameters with 3 layers (check improvements without any hyperparamenter tunning, just random values).
# - LSTM structure with 2 layers with random search.
# - LSTM structure with 3 layers with random search.
# - LSTM with OPTUNA Hyperparamenter tunning.
# - LSTM with Keras Tuner.
#
# Therefore, it will be 6 different models for each sequence length tested and the best performer will be compared against other optimal performers of others sequence length.

# %% [markdown]
# ### Random Parameters. (Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define hyperparameters
dropout_rate = 0.3          # Dropout rate to help prevent overfitting by randomly dropping nodes during training.
l2_lambda = 0.01            # L2 regularization factor, penalizes large weights and attempt to prevent overfitting.
learning_rate = 0.0002      # Learning rate for the optimizer to control how much to adjust weights during backpropagation.
epochs = 50                 # Maximum number of training epochs.
batch_size = 128            # Batch size for each training step, determines how many samples are used in each gradient update.

# Initialize the LSTM model.
model = Sequential()

# First LSTM layer with L2 regularization and dropout.
model.add(LSTM(units=64,                    # Number of LSTM units (neurons) in the layer.
               return_sequences=True,       # Ensures that the layer returns the entire sequence for the next LSTM layer.
               input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape: (sequence length, number of features).
               kernel_regularizer=l2(l2_lambda)))  # Applies L2 regularization to reduce overfitting.
model.add(Dropout(dropout_rate))            # Adds dropout layer to reduce overfitting by randomly setting some neurons to 0.

# Second LSTM layer with L2 regularization and dropout.
model.add(LSTM(units=64,                    # Number of LSTM units in the second layer.
               return_sequences=False,      # Last LSTM layer should not return sequences; it outputs only the final state.
               kernel_regularizer=l2(l2_lambda)))  # L2 regularization to prevent overfitting.
model.add(Dropout(dropout_rate))            # Dropout for regularization.

# Output layer
model.add(Dense(1))                         # Dense layer with a single unit, since its predicting a single value (regression).

# Compile the model
model.compile(optimizer=Adam(learning_rate=learning_rate),  # Adam optimizer with a specified learning rate.
              loss='mean_squared_error')                    # Mean Squared Error (MSE) as the loss function for regression.

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss',          # Monitor validation loss to stop if it stops improving.
                               patience=10,                 # Wait for 10 epochs with no improvement before stopping.
                               restore_best_weights=True)   # Restore model weights from the epoch with the lowest validation loss.

# Train the model
history = model.fit(X_train_seq, y_train_seq,               # Training data (features and target).
                    epochs=epochs,                          # Maximum number of epochs.
                    batch_size=batch_size,                  # Batch size.
                    validation_data=(X_test_seq, y_test_seq),  # Validation data to monitor overfitting.
                    callbacks=[early_stopping],             # Callback for early stopping. 
                    shuffle=False,
                    verbose=1)                              # Verbose output for progress during training.

# Print final training and validation loss values.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 2.1039 - val_loss: 2.1881
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 2.0671 - val_loss: 2.1574
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 2.0464 - val_loss: 2.1271
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 2.0166 - val_loss: 2.0979
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.9850 - val_loss: 2.0699
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9511 - val_loss: 2.0425
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.9218 - val_loss: 2.0160
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.8952 - val_loss: 1.9905
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8727 - val_loss: 1.9657
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8447 - val_loss: 1.9418
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8206 - val_loss: 1.9185
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.8062 - val_loss: 1.8958
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.7841 - val_loss: 1.8737
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7579 - val_loss: 1.8522
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7377 - val_loss: 1.8313
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7200 - val_loss: 1.8112
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.6953 - val_loss: 1.7917
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6769 - val_loss: 1.7726
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.6588 - val_loss: 1.7541
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6362 - val_loss: 1.7361
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.6187 - val_loss: 1.7185
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6018 - val_loss: 1.7014
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.5885 - val_loss: 1.6847
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5643 - val_loss: 1.6686
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5538 - val_loss: 1.6528
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5365 - val_loss: 1.6374
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5185 - val_loss: 1.6225
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.5077 - val_loss: 1.6080
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4984 - val_loss: 1.5938
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4756 - val_loss: 1.5802
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4641 - val_loss: 1.5670
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4528 - val_loss: 1.5540
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4368 - val_loss: 1.5413
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4247 - val_loss: 1.5290
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.4154 - val_loss: 1.5170
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4009 - val_loss: 1.5054
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3939 - val_loss: 1.4940
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3784 - val_loss: 1.4830
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3609 - val_loss: 1.4723
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3514 - val_loss: 1.4618
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3441 - val_loss: 1.4515
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3358 - val_loss: 1.4416
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3229 - val_loss: 1.4320
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3127 - val_loss: 1.4228
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3101 - val_loss: 1.4139
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.3025 - val_loss: 1.4053
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2894 - val_loss: 1.3970
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2774 - val_loss: 1.3889
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2753 - val_loss: 1.3808
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.2647 - val_loss: 1.3728
# Final Training Loss: 1.2973817586898804
# Final Validation Loss: 1.3727530241012573

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 999us/step
# LSTM Model Performance:
# Training RMSE: 0.020274764054727078
# Test RMSE: 0.023086916831245
# Training MAE: 0.014680984858060181
# Test MAE: 0.01751282042353632
# Directional Accuracy on Training Data: 52.69804822043628%
# Directional Accuracy on Test Data: 50.0%

# %% [markdown]
# ### Model 2 - Random Parameters with 3 layers

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'units3': 64,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-6,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 150,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False,
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 203s 2s/step - loss: 3.2901 - val_loss: 1.4815
# Epoch 2/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - loss: 2.3323 - val_loss: 1.4762
# Epoch 3/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.2903 - val_loss: 1.4755
# Epoch 4/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.1210 - val_loss: 1.4726
# Epoch 5/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.9361 - val_loss: 1.4758
# Epoch 6/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.8143 - val_loss: 1.4721
# Epoch 7/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.7270 - val_loss: 1.4700
# Epoch 8/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 1.6844 - val_loss: 1.4662
# Epoch 9/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.6973 - val_loss: 1.4605
# Epoch 10/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.6083 - val_loss: 1.4599
# Epoch 11/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4526 - val_loss: 1.4552
# Epoch 12/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.4282 - val_loss: 1.4563
# Epoch 13/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.3722 - val_loss: 1.4567
# Epoch 14/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.4468 - val_loss: 1.4545
# Epoch 15/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3649 - val_loss: 1.4435
# Epoch 16/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.2744 - val_loss: 1.4476
# Epoch 17/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2432 - val_loss: 1.4416
# Epoch 18/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.2589 - val_loss: 1.4495
# Epoch 19/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1986 - val_loss: 1.4376
# Epoch 20/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 193ms/step - loss: 1.2314 - val_loss: 1.4332
# Epoch 21/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.2734 - val_loss: 1.4407
# Epoch 22/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1443 - val_loss: 1.4406
# Epoch 23/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.1084 - val_loss: 1.4292
# Epoch 24/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 64ms/step - loss: 1.1227 - val_loss: 1.4410
# Epoch 25/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1706 - val_loss: 1.4305
# Epoch 26/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.1325 - val_loss: 1.4182
# Epoch 27/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.0994 - val_loss: 1.4267
# Epoch 28/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - loss: 1.0830 - val_loss: 1.4242
# Epoch 29/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0699 - val_loss: 1.4347
# Epoch 30/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0295 - val_loss: 1.4447
# Epoch 31/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0208 - val_loss: 1.4267
# Epoch 32/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 0.9943 - val_loss: 1.4396
# Epoch 33/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0157 - val_loss: 1.4591
# Epoch 34/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.9920 - val_loss: 1.4547
# Epoch 35/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9478 - val_loss: 1.4722
# Epoch 36/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.9764 - val_loss: 1.4716
# Final Training Loss: 0.976780116558075
# Final Validation Loss: 1.4715520143508911

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 32s 525ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# LSTM Model Performance:
# Training RMSE: 0.019779043998202503
# Test RMSE: 0.023053982899312972
# Training MAE: 0.014436500615451103
# Test MAE: 0.0174176765134108
# Directional Accuracy on Training Data: 59.35706084959816%
# Directional Accuracy on Test Data: 54.0%

# %% [markdown]
# ### 1.Random Search

# %% [markdown]
# ### Two Layers (Model 3)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.2684329748153687
# Final Validation Loss: 1.5459833145141602
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.166832685470581
# Final Validation Loss: 2.164638042449951
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 0.871383786201477
# Final Validation Loss: 1.2956427335739136
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.1009979248046875
# Final Validation Loss: 6.444252014160156
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.3447673320770264
# Final Validation Loss: 2.8747808933258057
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.1610198020935059
# Final Validation Loss: 1.1536486148834229
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.225225448608398
# Final Validation Loss: 9.469817161560059
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.8960630893707275
# Final Validation Loss: 1.7794506549835205
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.732206344604492
# Final Validation Loss: 2.3604788780212402
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.2558716535568237
# Final Validation Loss: 1.3621313571929932
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.54506254196167
# Final Validation Loss: 6.319368839263916
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.5768368244171143
# Final Validation Loss: 1.1379859447479248
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.237236976623535
# Final Validation Loss: 4.402152061462402
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1.7579779624938965
# Final Validation Loss: 1.3694701194763184
# Running combination 15/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.5207284688949585
# Final Validation Loss: 1.405551791191101
# Running combination 16/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.703336238861084
# Final Validation Loss: 2.2212159633636475
# Running combination 17/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 13.475326538085938
# Final Validation Loss: 12.077259063720703
# Running combination 18/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 14.384416580200195
# Final Validation Loss: 13.562281608581543
# Running combination 19/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 20.088375091552734
# Final Validation Loss: 19.457683563232422
# Running combination 20/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.6890385150909424
# Final Validation Loss: 1.9347877502441406
# Running combination 21/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.4354431629180908
# Final Validation Loss: 1.5964807271957397
# Running combination 22/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.080714225769043
# Final Validation Loss: 1.624105453491211
# Running combination 23/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 7.324155330657959
# Final Validation Loss: 6.404502868652344
# Running combination 24/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.0605759620666504
# Final Validation Loss: 2.9667651653289795
# Running combination 25/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 14.949885368347168
# Final Validation Loss: 14.327539443969727
# Running combination 26/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 2.474515438079834
# Final Validation Loss: 1.7433586120605469
# Running combination 27/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.7792742252349854
# Final Validation Loss: 1.4145450592041016
# Running combination 28/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.4388378858566284
# Final Validation Loss: 1.3435535430908203
# Running combination 29/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 1.8803024291992188
# Final Validation Loss: 1.433322548866272
# Running combination 30/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 5.816998481750488
# Final Validation Loss: 5.520961284637451
# Top results:
# {'params': {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 1.5768368244171143, 'final_val_loss': 1.1379859447479248}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.1610198020935059, 'final_val_loss': 1.1536486148834229}
# {'params': {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}, 'final_train_loss': 0.871383786201477, 'final_val_loss': 1.2956427335739136}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.4388378858566284, 'final_val_loss': 1.3435535430908203}
# {'params': {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.2558716535568237, 'final_val_loss': 1.3621313571929932}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 91ms/step - loss: 2.9878 - val_loss: 1.3788
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.3838 - val_loss: 1.3716
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2718 - val_loss: 1.3686
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.1857 - val_loss: 1.3687
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.0168 - val_loss: 1.3696
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 1.9973 - val_loss: 1.3647
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9421 - val_loss: 1.3730
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.7370 - val_loss: 1.3651
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.7552 - val_loss: 1.3665
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 1.7218 - val_loss: 1.3692
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6840 - val_loss: 1.3693
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.6952 - val_loss: 1.3624
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.4775 - val_loss: 1.3699
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6342 - val_loss: 1.3703
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6137 - val_loss: 1.3714
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.5979 - val_loss: 1.3784
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5194 - val_loss: 1.3612
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5067 - val_loss: 1.3749
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3846 - val_loss: 1.3614
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.5898 - val_loss: 1.3631
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4221 - val_loss: 1.3468
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3900 - val_loss: 1.3646
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3653 - val_loss: 1.3497
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2612 - val_loss: 1.3499
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3457 - val_loss: 1.3324
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2571 - val_loss: 1.3436
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2910 - val_loss: 1.3460
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2535 - val_loss: 1.3527
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2034 - val_loss: 1.3362
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1861 - val_loss: 1.3478
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1146 - val_loss: 1.3712
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1688 - val_loss: 1.3338
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.2406 - val_loss: 1.3464
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.1305 - val_loss: 1.3404
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1742 - val_loss: 1.3298
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.0551 - val_loss: 1.3616
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1229 - val_loss: 1.3625
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1406 - val_loss: 1.3401
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0939 - val_loss: 1.3334
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1051 - val_loss: 1.3408
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0608 - val_loss: 1.3418
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.0009 - val_loss: 1.3412
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0694 - val_loss: 1.3536
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.0585 - val_loss: 1.3744
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 1.0457 - val_loss: 1.3460
# Final Training Loss: 1.0852596759796143
# Final Validation Loss: 1.345977783203125

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# LSTM Model Performance:
# Training RMSE: 0.019593881228405594
# Test RMSE: 0.022897613470813566
# Training MAE: 0.014263972917568916
# Test MAE: 0.01760594463780927
# Directional Accuracy on Training Data: 63.375430539609646%
# Directional Accuracy on Test Data: 48.66666666666667%

# %% [markdown]
# ### Three Layers (Model 4)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],
    'recurrent_dropout': [0.1, 0.2],
    'l2_lambda': [0.001, 0.01, 0.1],
    'learning_rate': [0.001, 0.0005, 0.0001],
    'learning_rate_decay': [1e-6, 1e-5, 0],
    'units1': [32, 64, 128],
    'units2': [32, 64, 128],
    'units3': [32, 64, 128],
    'batch_size': [32, 64, 120, 256],  
    'epochs': [50, 100, 200],
    'optimizer': ['adam'],
    'clipnorm': [1.0, 5.0]
}

# Generate a list of random combinations with ParameterSampler
n_iter_search = 30
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42))

# Define the function to build the model with variable parameters
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, units3, optimizer_name, loss_function):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units2, return_sequences=True, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units3, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer.
    model.add(Dense(1))
    
    # Select optimizer with decay and clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to keep track of results
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        units3=params['units3'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.0359541177749634
# Final Validation Loss: 1.44378662109375
# Running combination 2/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 4.07795524597168
# Final Validation Loss: 3.9964523315429688
# Running combination 3/30: {'units3': 128, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.599644422531128
# Final Validation Loss: 1.5307891368865967
# Running combination 4/30: {'units3': 128, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 8.441230773925781
# Final Validation Loss: 7.276986122131348
# Running combination 5/30: {'units3': 64, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.403014659881592
# Final Validation Loss: 3.8446948528289795
# Running combination 6/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.2405595779418945
# Final Validation Loss: 1.426335096359253
# Running combination 7/30: {'units3': 32, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.882528305053711
# Final Validation Loss: 2.6900196075439453
# Running combination 8/30: {'units3': 32, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.503670692443848
# Final Validation Loss: 3.4954586029052734
# Running combination 9/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.4655025005340576
# Final Validation Loss: 1.495111346244812
# Running combination 10/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 2.455831289291382
# Final Validation Loss: 1.3981738090515137
# Running combination 11/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.4213969707489014
# Final Validation Loss: 1.4947043657302856
# Running combination 12/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 17.046260833740234
# Final Validation Loss: 16.406015396118164
# Running combination 13/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.460647702217102
# Final Validation Loss: 1.479286789894104
# Running combination 14/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 0.9405034184455872
# Final Validation Loss: 1.2559678554534912
# Running combination 15/30: {'units3': 128, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 3.9644556045532227
# Final Validation Loss: 2.9190258979797363
# Running combination 16/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.8700287342071533
# Final Validation Loss: 2.8287556171417236
# Running combination 17/30: {'units3': 128, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 15.932779312133789
# Final Validation Loss: 15.035264015197754
# Running combination 18/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.924781084060669
# Final Validation Loss: 1.264104962348938
# Running combination 19/30: {'units3': 128, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.96043586730957
# Final Validation Loss: 4.0428290367126465
# Running combination 20/30: {'units3': 64, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.560201406478882
# Final Validation Loss: 2.5957460403442383
# Running combination 21/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.7153701782226562
# Final Validation Loss: 3.1415836811065674
# Running combination 22/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 33.233741760253906
# Final Validation Loss: 31.29315948486328
# Running combination 23/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 18.170530319213867
# Final Validation Loss: 16.639719009399414
# Running combination 24/30: {'units3': 64, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 37.81884002685547
# Final Validation Loss: 37.15442657470703
# Running combination 25/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 11.632169723510742
# Final Validation Loss: 10.937487602233887
# Running combination 26/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 3.8410186767578125
# Final Validation Loss: 3.18851375579834
# Running combination 27/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.079662799835205
# Final Validation Loss: 3.7117984294891357
# Running combination 28/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.058366060256958
# Final Validation Loss: 2.4906020164489746
# Running combination 29/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 11.103375434875488
# Final Validation Loss: 10.790358543395996
# Running combination 30/30: {'units3': 128, 'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 5.230482578277588
# Final Validation Loss: 3.8947219848632812
# Top results:
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 0.9405034184455872, 'final_val_loss': 1.2559678554534912}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 2.924781084060669, 'final_val_loss': 1.264104962348938}
# {'params': {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 2.455831289291382, 'final_val_loss': 1.3981738090515137}
# {'params': {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.2405595779418945, 'final_val_loss': 1.426335096359253}
# {'params': {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}, 'final_train_loss': 1.0359541177749634, 'final_val_loss': 1.44378662109375}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - loss: 3.0075 - val_loss: 1.2691
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.1442 - val_loss: 1.2678
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.0451 - val_loss: 1.2671
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.7848 - val_loss: 1.2670
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.9368 - val_loss: 1.2672
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.7208 - val_loss: 1.2676
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.7061 - val_loss: 1.2671
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.6806 - val_loss: 1.2664
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.5883 - val_loss: 1.2667
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.6840 - val_loss: 1.2660
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.5855 - val_loss: 1.2659
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4884 - val_loss: 1.2646
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.4425 - val_loss: 1.2634
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.5057 - val_loss: 1.2646
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.4279 - val_loss: 1.2676
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.4405 - val_loss: 1.2669
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.3461 - val_loss: 1.2669
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.3473 - val_loss: 1.2638
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.3781 - val_loss: 1.2625
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.3383 - val_loss: 1.2638
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.3930 - val_loss: 1.2661
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.4028 - val_loss: 1.2607
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.3300 - val_loss: 1.2538
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2669 - val_loss: 1.2551
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2238 - val_loss: 1.2587
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2461 - val_loss: 1.2606
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2637 - val_loss: 1.2563
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.2077 - val_loss: 1.2551
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2229 - val_loss: 1.2585
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.2546 - val_loss: 1.2589
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 1.2671 - val_loss: 1.2539
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1974 - val_loss: 1.2481
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2006 - val_loss: 1.2459
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.2211 - val_loss: 1.2438
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1815 - val_loss: 1.2410
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1282 - val_loss: 1.2382
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.1402 - val_loss: 1.2382
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1676 - val_loss: 1.2393
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.1737 - val_loss: 1.2423
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.1538 - val_loss: 1.2390
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.1149 - val_loss: 1.2338
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.0875 - val_loss: 1.2333
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 1.1111 - val_loss: 1.2313
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.0209 - val_loss: 1.2327
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.0331 - val_loss: 1.2294
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0646 - val_loss: 1.2206
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.0711 - val_loss: 1.2226
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.0082 - val_loss: 1.2220
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.0587 - val_loss: 1.2183
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.0055 - val_loss: 1.2180
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0721 - val_loss: 1.2082
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.0441 - val_loss: 1.2086
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.0550 - val_loss: 1.2062
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.9741 - val_loss: 1.2111
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.9988 - val_loss: 1.2145
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0132 - val_loss: 1.2272
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.0685 - val_loss: 1.2380
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.9806 - val_loss: 1.2385
# Epoch 59/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.8910 - val_loss: 1.2334
# Epoch 60/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.9879 - val_loss: 1.2256
# Epoch 61/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 0.9783 - val_loss: 1.2252
# Epoch 62/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 0.9691 - val_loss: 1.2435
# Epoch 63/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 0.9665 - val_loss: 1.2552
# Final Training Loss: 0.9282188415527344
# Final Validation Loss: 1.2552132606506348

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# LSTM Model Performance:
# Training RMSE: 0.01882954153953576
# Test RMSE: 0.022622831098212382
# Training MAE: 0.01355491546802285
# Test MAE: 0.01727320165237998
# Directional Accuracy on Training Data: 59.70149253731343%
# Directional Accuracy on Test Data: 52.0%

# %% [markdown]
# ### 2. Optuna (Model 5)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.

    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    # Compile the model with mean squared error loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-12 11:00:11,110] A new study created in memory with name: no-name-91fd14af-ce76-42da-b556-aa4e2eb3bd3e
# [I 2024-11-12 11:00:18,640] Trial 0 finished with value: 1.5721849203109741 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.5721849203109741.
# [I 2024-11-12 11:00:23,844] Trial 1 finished with value: 3.80015230178833 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.5721849203109741.
# [I 2024-11-12 11:00:34,838] Trial 2 finished with value: 4.312074661254883 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.5721849203109741.
# [I 2024-11-12 11:00:43,119] Trial 3 finished with value: 1.6686816215515137 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.5721849203109741.
# [I 2024-11-12 11:00:46,595] Trial 4 finished with value: 1.4497443437576294 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 4 with value: 1.4497443437576294.
# [I 2024-11-12 11:00:56,980] Trial 5 finished with value: 1.5321403741836548 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06621901977279396, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 256}. Best is trial 4 with value: 1.4497443437576294.
# [I 2024-11-12 11:01:05,639] Trial 6 finished with value: 2.854414701461792 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0038300508438275606, 'learning_rate': 0.0001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 3, 'epochs': 50, 'batch_size': 256}. Best is trial 4 with value: 1.4497443437576294.
# [I 2024-11-12 11:01:09,371] Trial 7 finished with value: 1.185947299003601 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.185947299003601.
# [I 2024-11-12 11:01:15,617] Trial 8 finished with value: 1.4512150287628174 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0017384974140603195, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 1.185947299003601.
# [I 2024-11-12 11:01:20,262] Trial 9 finished with value: 1.1749918460845947 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.028980866560207673, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:22,839] Trial 10 finished with value: 1.2299690246582031 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.015225998328909448, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:25,611] Trial 11 finished with value: 1.1994266510009766 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011454828358668492, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:29,886] Trial 12 finished with value: 1.2308322191238403 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.01030003475248839, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:32,691] Trial 13 finished with value: 1.2976678609848022 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.004045666906144077, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 32}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:41,489] Trial 14 finished with value: 1.3023900985717773 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.027052150070236074, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 100, 'batch_size': 64}. Best is trial 9 with value: 1.1749918460845947.
# [I 2024-11-12 11:01:44,854] Trial 15 finished with value: 1.1283349990844727 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.007328101485625913, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 15 with value: 1.1283349990844727.
# [I 2024-11-12 11:01:56,106] Trial 16 finished with value: 1.2497570514678955 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008223676169211188, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 200, 'batch_size': 120}. Best is trial 15 with value: 1.1283349990844727.
# [I 2024-11-12 11:01:58,953] Trial 17 finished with value: 1.2102735042572021 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.022327831680113843, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 15 with value: 1.1283349990844727.
# [I 2024-11-12 11:02:02,227] Trial 18 finished with value: 1.1145355701446533 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.006750035538813451, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:10,021] Trial 19 finished with value: 1.391481637954712 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.007463331655845889, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:18,480] Trial 20 finished with value: 1.4425528049468994 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.006452775043568459, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 64, 'num_layers': 2, 'epochs': 200, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:22,658] Trial 21 finished with value: 1.1490981578826904 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.014185233978332904, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:26,976] Trial 22 finished with value: 1.1396589279174805 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.012057186824664579, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:29,606] Trial 23 finished with value: 1.1494007110595703 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.004915190547383267, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:32,421] Trial 24 finished with value: 1.3382656574249268 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.012459541218374707, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 18 with value: 1.1145355701446533.
# [I 2024-11-12 11:02:35,651] Trial 25 finished with value: 1.1144814491271973 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0028422840476253894, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 25 with value: 1.1144814491271973.
# [I 2024-11-12 11:02:39,500] Trial 26 finished with value: 1.0897679328918457 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.002609502050539667, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}. Best is trial 26 with value: 1.0897679328918457.
# [I 2024-11-12 11:02:44,353] Trial 27 finished with value: 1.1870083808898926 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0021176113656889537, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 26 with value: 1.0897679328918457.
# [I 2024-11-12 11:02:47,999] Trial 28 finished with value: 1.0743422508239746 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.002714142252080901, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}. Best is trial 28 with value: 1.0743422508239746.
# [I 2024-11-12 11:02:56,934] Trial 29 finished with value: 1.4329476356506348 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.002624042269961081, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 32}. Best is trial 28 with value: 1.0743422508239746.
# Best hyperparameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.002714142252080901, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}
# Best validation loss: 1.0743422508239746

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.002714142252080901,
    'epochs': 150,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 76ms/step - loss: 2.2084 - val_loss: 1.1093
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5848 - val_loss: 1.0920
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4645 - val_loss: 1.0899
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4850 - val_loss: 1.0917
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2559 - val_loss: 1.0936
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.3488 - val_loss: 1.0910
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.3664 - val_loss: 1.0895
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1667 - val_loss: 1.0905
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2097 - val_loss: 1.0918
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1674 - val_loss: 1.0898
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1843 - val_loss: 1.0877
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2123 - val_loss: 1.0877
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2544 - val_loss: 1.0892
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2136 - val_loss: 1.0911
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1862 - val_loss: 1.0917
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1794 - val_loss: 1.0913
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1569 - val_loss: 1.0882
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2059 - val_loss: 1.0863
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1119 - val_loss: 1.0866
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0974 - val_loss: 1.0877
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1229 - val_loss: 1.0897
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1706 - val_loss: 1.0865
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1078 - val_loss: 1.0856
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0630 - val_loss: 1.0879
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1034 - val_loss: 1.0871
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1164 - val_loss: 1.0886
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1645 - val_loss: 1.0881
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1147 - val_loss: 1.0870
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0534 - val_loss: 1.0895
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0452 - val_loss: 1.0932
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0958 - val_loss: 1.0936
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0750 - val_loss: 1.0924
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1103 - val_loss: 1.0887
# Final Training Loss: 1.105406403541565
# Final Validation Loss: 1.0887320041656494

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# LSTM Model Performance:
# Training RMSE: 0.02014859508135637
# Test RMSE: 0.022906913325519
# Training MAE: 0.01454627638546929
# Test MAE: 0.01745026191331487
# Directional Accuracy on Training Data: 59.58668197474167%
# Directional Accuracy on Test Data: 60.66666666666667%

# %% [markdown]
# ### 3. Keras Tuner (Model 6)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.


    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 23s]
# val_loss: 1.2789044380187988
#
# Best val_loss So Far: 1.2789044380187988
# Total elapsed time: 00h 07m 02s
# Built model with params: dropout_rate=0.4, recurrent_dropout=0.2, l2_lambda=0.0218590046119431, learning_rate=0.001, learning_rate_decay=1e-05, clipnorm=1.0, units=32, num_layers=3, batch_size=64
# Best hyperparameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0218590046119431, 'learning_rate': 0.001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'batch_size': 64}
# Best batch size: 64

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.001,
    'l2_lambda': 0.0218590046119431,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 11s 79ms/step - loss: 6.4853 - val_loss: 3.5865
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.5017 - val_loss: 3.5303
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 5.4864 - val_loss: 3.4686
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.6802 - val_loss: 3.4030
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 4.5685 - val_loss: 3.3369
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 4.2873 - val_loss: 3.2685
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 4.0987 - val_loss: 3.1975
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 4.1569 - val_loss: 3.1233
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.6632 - val_loss: 3.0516
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.5783 - val_loss: 2.9822
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.3468 - val_loss: 2.9046
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 3.3011 - val_loss: 2.8346
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 3.2471 - val_loss: 2.7644
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 3.1193 - val_loss: 2.6917
# Epoch 15/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.8931 - val_loss: 2.6168
# Epoch 16/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.8396 - val_loss: 2.5486
# Epoch 17/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 2.6793 - val_loss: 2.4707
# Epoch 18/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.4980 - val_loss: 2.3887
# Epoch 19/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 2.4758 - val_loss: 2.3185
# Epoch 20/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 2.2661 - val_loss: 2.2487
# Epoch 21/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 2.2650 - val_loss: 2.1830
# Epoch 22/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.1300 - val_loss: 2.1164
# Epoch 23/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 2.0146 - val_loss: 2.0532
# Epoch 24/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9457 - val_loss: 1.9982
# Epoch 25/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8266 - val_loss: 1.9400
# Epoch 26/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.8698 - val_loss: 1.8888
# Epoch 27/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7985 - val_loss: 1.8434
# Epoch 28/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.7168 - val_loss: 1.8025
# Epoch 29/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6013 - val_loss: 1.7598
# Epoch 30/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.5663 - val_loss: 1.7211
# Epoch 31/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5939 - val_loss: 1.6858
# Epoch 32/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5606 - val_loss: 1.6574
# Epoch 33/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4920 - val_loss: 1.6322
# Epoch 34/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.4733 - val_loss: 1.6053
# Epoch 35/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3998 - val_loss: 1.5784
# Epoch 36/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.4000 - val_loss: 1.5570
# Epoch 37/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3536 - val_loss: 1.5383
# Epoch 38/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3192 - val_loss: 1.5183
# Epoch 39/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.3143 - val_loss: 1.4968
# Epoch 40/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 1.2581 - val_loss: 1.4783
# Epoch 41/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2415 - val_loss: 1.4652
# Epoch 42/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2278 - val_loss: 1.4489
# Epoch 43/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2133 - val_loss: 1.4370
# Epoch 44/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1860 - val_loss: 1.4219
# Epoch 45/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2076 - val_loss: 1.4061
# Epoch 46/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1543 - val_loss: 1.3935
# Epoch 47/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1551 - val_loss: 1.3873
# Epoch 48/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1352 - val_loss: 1.3774
# Epoch 49/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1159 - val_loss: 1.3691
# Epoch 50/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.1164 - val_loss: 1.3662
# Epoch 51/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 1.1144 - val_loss: 1.3601
# Epoch 52/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0886 - val_loss: 1.3551
# Epoch 53/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0929 - val_loss: 1.3436
# Epoch 54/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0878 - val_loss: 1.3335
# Epoch 55/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0754 - val_loss: 1.3311
# Epoch 56/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0744 - val_loss: 1.3273
# Epoch 57/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0564 - val_loss: 1.3204
# Epoch 58/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0633 - val_loss: 1.3138
# Epoch 59/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0633 - val_loss: 1.3069
# Epoch 60/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.0635 - val_loss: 1.2994
# Epoch 61/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0528 - val_loss: 1.2981
# Epoch 62/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0428 - val_loss: 1.2905
# Epoch 63/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.0327 - val_loss: 1.2836
# Epoch 64/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0286 - val_loss: 1.2753
# Epoch 65/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0278 - val_loss: 1.2744
# Epoch 66/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0182 - val_loss: 1.2740
# Epoch 67/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0146 - val_loss: 1.2725
# Epoch 68/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0204 - val_loss: 1.2682
# Epoch 69/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.0113 - val_loss: 1.2640
# Epoch 70/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0010 - val_loss: 1.2620
# Epoch 71/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0079 - val_loss: 1.2644
# Epoch 72/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9973 - val_loss: 1.2598
# Epoch 73/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.0122 - val_loss: 1.2560
# Epoch 74/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9948 - val_loss: 1.2585
# Epoch 75/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0046 - val_loss: 1.2531
# Epoch 76/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.0040 - val_loss: 1.2484
# Epoch 77/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9746 - val_loss: 1.2523
# Epoch 78/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9922 - val_loss: 1.2523
# Epoch 79/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 0.9763 - val_loss: 1.2535
# Epoch 80/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.9838 - val_loss: 1.2500
# Epoch 81/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9872 - val_loss: 1.2513
# Epoch 82/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9847 - val_loss: 1.2504
# Epoch 83/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9716 - val_loss: 1.2444
# Epoch 84/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9772 - val_loss: 1.2352
# Epoch 85/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9670 - val_loss: 1.2451
# Epoch 86/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9660 - val_loss: 1.2556
# Epoch 87/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9707 - val_loss: 1.2558
# Epoch 88/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9670 - val_loss: 1.2478
# Epoch 89/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9776 - val_loss: 1.2359
# Epoch 90/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9676 - val_loss: 1.2348
# Epoch 91/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9642 - val_loss: 1.2340
# Epoch 92/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9678 - val_loss: 1.2333
# Epoch 93/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9737 - val_loss: 1.2284
# Epoch 94/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9618 - val_loss: 1.2295
# Epoch 95/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9691 - val_loss: 1.2302
# Epoch 96/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9617 - val_loss: 1.2275
# Epoch 97/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9609 - val_loss: 1.2286
# Epoch 98/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9478 - val_loss: 1.2258
# Epoch 99/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.9574 - val_loss: 1.2294
# Epoch 100/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9555 - val_loss: 1.2424
# Epoch 101/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9369 - val_loss: 1.2464
# Epoch 102/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9691 - val_loss: 1.2408
# Epoch 103/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9563 - val_loss: 1.2349
# Epoch 104/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.9552 - val_loss: 1.2307
# Epoch 105/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.9491 - val_loss: 1.2354
# Epoch 106/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.9549 - val_loss: 1.2373
# Epoch 107/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.9550 - val_loss: 1.2363
# Epoch 108/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.9667 - val_loss: 1.2303
# Final Training Loss: 1.0198677778244019
# Final Validation Loss: 1.2303118705749512

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# LSTM Model Performance:
# Training RMSE: 0.020402919340866355
# Test RMSE: 0.023087480904757263
# Training MAE: 0.014758700251080328
# Test MAE: 0.017369250470369947
# Directional Accuracy on Training Data: 54.19058553386912%
# Directional Accuracy on Test Data: 54.0%

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 4
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       | Model 5       | Model 6       |
# |-----------------|---------------|---------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020274764   | 0.019779044   | 0.019593881   | 0.018829542   | 0.020148595   | 0.020402919   |
# | **Test RMSE**  | 0.023086917   | 0.023053983   | 0.022897613   | 0.022622831   | 0.022906913   | 0.023087481   |
# | **Train MAE**  | 0.014680985   | 0.014436501   | 0.014263973   | 0.013554915   | 0.014546276   | 0.0147587     |
# | **Test MAE**   | 0.01751282    | 0.017417677   | 0.017605945   | 0.017273202   | 0.017450262   | 0.01736925    |
# | **Train Loss** | 1.297381759   | 0.976780117   | 1.085259676   | 0.928218842   | 1.105406404   | 1.019867778   |
# | **Val Loss**   | 1.372753024   | 1.471552014   | 1.345977783   | 1.255213261   | 1.088732004   | 1.230311871   |
# | **Train DA**   | 53%           | 59%           | 63%           | 60%           | 60%           | 54%           |
# | **Test DA**    | 50%           | 54%           | 49%           | 52%           | 61%           | 54%           |
#
# **Legend:**
# - RMSE: Root Mean Squared Error
# - MAE: Mean Absolute Error
# - Loss: Training or Validation Loss
# - DA: Directional Accuracy
#
#
# **The best perfomer with sequence length of 4 is the model 5**.
# - Second lowest train and test RMSE.
# - Decent directional accuracy.
# - Regarding the train_loss and val_loss, it presents the best convergence between all models.

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.002714142252080901,
    'epochs': 150,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 85ms/step - loss: 2.2084 - val_loss: 1.1093
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5848 - val_loss: 1.0920
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4645 - val_loss: 1.0899
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4850 - val_loss: 1.0917
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2559 - val_loss: 1.0936
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3488 - val_loss: 1.0910
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3664 - val_loss: 1.0895
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1667 - val_loss: 1.0905
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2097 - val_loss: 1.0918
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.1674 - val_loss: 1.0898
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1843 - val_loss: 1.0877
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2123 - val_loss: 1.0877
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2544 - val_loss: 1.0892
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2136 - val_loss: 1.0911
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1862 - val_loss: 1.0917
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1794 - val_loss: 1.0913
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1569 - val_loss: 1.0882
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2059 - val_loss: 1.0863
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1119 - val_loss: 1.0866
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0974 - val_loss: 1.0877
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1229 - val_loss: 1.0897
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1706 - val_loss: 1.0865
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1078 - val_loss: 1.0856
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0630 - val_loss: 1.0879
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1034 - val_loss: 1.0871
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1164 - val_loss: 1.0886
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1645 - val_loss: 1.0881
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1147 - val_loss: 1.0870
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0534 - val_loss: 1.0895
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0452 - val_loss: 1.0932
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0958 - val_loss: 1.0936
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0750 - val_loss: 1.0924
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1103 - val_loss: 1.0887
# Final Training Loss: 1.105406403541565
# Final Validation Loss: 1.0887320041656494

# %%
# Extract scaled train and validation loss from history
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Retrieve the center (median) and scale (IQR) from the RobustScaler
center = scaler_y.center_[0]  # Median used by the RobustScaler
scale = scaler_y.scale_[0]    # IQR used by the RobustScaler

# Descale the train and validation losses
descaled_train_loss = scaled_train_loss * scale + center
descaled_val_loss = scaled_val_loss * scale + center

# Print the descaled losses
print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.026003578975836977
# Descaled Validation Loss: 0.025666395532208664

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Best hyperparameters
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.002714142252080901,
    'epochs': 150,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Fold 1 RMSE: 1.4075114266575035
# Fold 2
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 2 RMSE: 0.944227100602572
# Fold 3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 3 RMSE: 0.7815021430797672
# Fold 4
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 4 RMSE: 1.1330964732787847
# Average RMSE from TSCV: 1.066584285904657

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 308ms/step
# Rolling window RMSE: 1.282263627916293
# Rolling window starting at index 50
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/stepWARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x00000211330805E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step
# Rolling window RMSE: 1.2557183069200915
# Rolling window starting at index 100
# WARNING:tensorflow:6 out of the last 24 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x000002112B4D6AC0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 399ms/step
# Rolling window RMSE: 0.8866326222795031
# Rolling window starting at index 150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step
# Rolling window RMSE: 0.7642937880236872
# Rolling window starting at index 200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 311ms/step
# Rolling window RMSE: 0.7709395612773532
# Rolling window starting at index 250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 303ms/step
# Rolling window RMSE: 0.8932344469383195
# Rolling window starting at index 300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 405ms/step
# Rolling window RMSE: 0.8397269618856268
# Rolling window starting at index 350
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step
# Rolling window RMSE: 0.5078688303294521
# Rolling window starting at index 400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step
# Rolling window RMSE: 0.7733137282365051
# Rolling window starting at index 450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 326ms/step
# Rolling window RMSE: 1.0347878912054695
# Rolling window starting at index 500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step
# Rolling window RMSE: 1.3350849650782612
# Average Rolling Window RMSE: 0.940351339099142

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.03211263332527141, 0.022744271628006532, 0.019453708633511993, 0.02656351716958024]
# Descaled FRWCV RMSE Values: [0.029579919364525906, 0.029043129850017425, 0.021579617711716226, 0.0191057277385978, 0.019240116070118798, 0.021713117331253067, 0.020631109058378356, 0.01392039852113448, 0.019288125582964683, 0.024575557933724578, 0.03064805261237471]
# Average Descaled TSCV RMSE: 0.025218532689092542
# Average Descaled FRWCV RMSE: 0.022665897434073275

# %% [markdown]
# ## Sequence Length = 12

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 12  # Number of time steps used for target prediction, 12 weeks (Quarterly).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (864, 12, 5)
# Reshaped y_train_seq shape: (864, 1)
# Reshaped X_test_seq shape: (143, 12, 5)
# Reshaped  y_test_seq shape: (143, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.68854558467865
# Final Validation Loss: 1.7941575050354004
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.78792405128479
# Final Validation Loss: 1.8863483667373657
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1.4570540189743042
# Final Validation Loss: 1.4287189245224
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.248965740203857
# Final Validation Loss: 6.6147050857543945
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.314948558807373
# Final Validation Loss: 2.9004037380218506
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.3611804246902466
# Final Validation Loss: 1.1769843101501465
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.331243515014648
# Final Validation Loss: 9.595550537109375
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.050511360168457
# Final Validation Loss: 1.8959242105484009
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.7813549041748047
# Final Validation Loss: 2.4276211261749268
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.3556571006774902
# Final Validation Loss: 1.4143285751342773
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.920587539672852
# Final Validation Loss: 6.548037528991699
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.2006155252456665
# Final Validation Loss: 1.1703214645385742
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.910167694091797
# Final Validation Loss: 4.249303817749023
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1.597486972808838
# Final Validation Loss: 1.3887441158294678
# Running combination 15/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.6590970754623413
# Final Validation Loss: 1.4930511713027954
# Running combination 16/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.601867198944092
# Final Validation Loss: 2.2493574619293213
# Running combination 17/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 13.535061836242676
# Final Validation Loss: 12.106851577758789
# Running combination 18/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 14.431686401367188
# Final Validation Loss: 13.618693351745605
# Running combination 19/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 20.010520935058594
# Final Validation Loss: 19.473018646240234
# Running combination 20/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.703463315963745
# Final Validation Loss: 1.9909887313842773
# Running combination 21/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.4060701131820679
# Final Validation Loss: 1.6471920013427734
# Running combination 22/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.1234688758850098
# Final Validation Loss: 1.6608052253723145
# Running combination 23/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 7.409421920776367
# Final Validation Loss: 6.554379463195801
# Running combination 24/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.200150728225708
# Final Validation Loss: 3.3729443550109863
# Running combination 25/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 14.831811904907227
# Final Validation Loss: 14.398903846740723
# Running combination 26/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 2.3192341327667236
# Final Validation Loss: 1.8118548393249512
# Running combination 27/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.544745922088623
# Final Validation Loss: 1.5420162677764893
# Running combination 28/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.3428057432174683
# Final Validation Loss: 1.3682873249053955
# Running combination 29/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.014646053314209
# Final Validation Loss: 1.4583336114883423
# Running combination 30/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 5.930438995361328
# Final Validation Loss: 5.661813259124756
# Top results:
# {'params': {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 1.2006155252456665, 'final_val_loss': 1.1703214645385742}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.3611804246902466, 'final_val_loss': 1.1769843101501465}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.3428057432174683, 'final_val_loss': 1.3682873249053955}
# {'params': {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}, 'final_train_loss': 1.597486972808838, 'final_val_loss': 1.3887441158294678}
# {'params': {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.3556571006774902, 'final_val_loss': 1.4143285751342773}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'units2': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 32
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 11s 87ms/step - loss: 3.0075 - val_loss: 1.2375
# Epoch 2/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 2.6027 - val_loss: 1.2330
# Epoch 3/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 2.3794 - val_loss: 1.2274
# Epoch 4/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.8804 - val_loss: 1.2362
# Epoch 5/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.9403 - val_loss: 1.2394
# Epoch 6/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.6976 - val_loss: 1.2260
# Epoch 7/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.7387 - val_loss: 1.2779
# Epoch 8/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.4596 - val_loss: 1.2758
# Epoch 9/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.4230 - val_loss: 1.2221
# Epoch 10/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.4733 - val_loss: 1.2459
# Epoch 11/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.2364 - val_loss: 1.2856
# Epoch 12/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.1217 - val_loss: 1.3106
# Epoch 13/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.1018 - val_loss: 1.3023
# Epoch 14/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.0893 - val_loss: 1.2924
# Epoch 15/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.0863 - val_loss: 1.2673
# Epoch 16/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.0077 - val_loss: 1.3618
# Epoch 17/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.0134 - val_loss: 1.3040
# Epoch 18/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 0.9942 - val_loss: 1.3288
# Epoch 19/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 0.9444 - val_loss: 1.3797
# Final Training Loss: 0.9575512409210205
# Final Validation Loss: 1.379671335220337

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# LSTM Model Performance:
# Training RMSE: 0.02046258335646106
# Test RMSE: 0.02414229554599416
# Training MAE: 0.015112096707269804
# Test MAE: 0.018599400921303782
# Directional Accuracy on Training Data: 60.42402826855123%
# Directional Accuracy on Test Data: 60.9375%

# %% [markdown]
# ### Three Layers (Model 2)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],
    'recurrent_dropout': [0.1, 0.2],
    'l2_lambda': [0.001, 0.01, 0.1],
    'learning_rate': [0.001, 0.0005, 0.0001],
    'learning_rate_decay': [1e-6, 1e-5, 0],
    'units1': [32, 64, 128],
    'units2': [32, 64, 128],
    'units3': [32, 64, 128],
    'batch_size': [32, 64, 120, 256],  
    'epochs': [50, 100, 200],
    'optimizer': ['adam'],
    'clipnorm': [1.0, 5.0]
}

# Generate a list of random combinations with ParameterSampler
n_iter_search = 30
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42))

# Define the function to build the model with variable parameters
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, units3, optimizer_name, loss_function):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units2, return_sequences=True, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units3, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer.
    model.add(Dense(1))
    
    # Select optimizer with decay and clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to keep track of results
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        units3=params['units3'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.0086045265197754
# Final Validation Loss: 1.6518462896347046
# Running combination 2/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 4.176858901977539
# Final Validation Loss: 4.096490383148193
# Running combination 3/30: {'units3': 128, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.260801076889038
# Final Validation Loss: 1.5577127933502197
# Running combination 4/30: {'units3': 128, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 8.234109878540039
# Final Validation Loss: 7.174563407897949
# Running combination 5/30: {'units3': 64, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.1586408615112305
# Final Validation Loss: 3.8877696990966797
# Running combination 6/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.1066019535064697
# Final Validation Loss: 1.4474060535430908
# Running combination 7/30: {'units3': 32, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.8847293853759766
# Final Validation Loss: 2.7258999347686768
# Running combination 8/30: {'units3': 32, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.653611660003662
# Final Validation Loss: 3.6153640747070312
# Running combination 9/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.3006513118743896
# Final Validation Loss: 1.5165246725082397
# Running combination 10/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 2.3548293113708496
# Final Validation Loss: 1.4383693933486938
# Running combination 11/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.5886988639831543
# Final Validation Loss: 1.5257741212844849
# Running combination 12/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 17.378658294677734
# Final Validation Loss: 16.743370056152344
# Running combination 13/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.606345772743225
# Final Validation Loss: 1.539908528327942
# Running combination 14/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.3926889896392822
# Final Validation Loss: 1.3285162448883057
# Running combination 15/30: {'units3': 128, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.0069169998168945
# Final Validation Loss: 2.9561307430267334
# Running combination 16/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.9539546966552734
# Final Validation Loss: 2.9808549880981445
# Running combination 17/30: {'units3': 128, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 15.788098335266113
# Final Validation Loss: 15.076945304870605
# Running combination 18/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.5046699047088623
# Final Validation Loss: 1.3127573728561401
# Running combination 19/30: {'units3': 128, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.304744720458984
# Final Validation Loss: 4.0969719886779785
# Running combination 20/30: {'units3': 64, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.227477550506592
# Final Validation Loss: 2.620112895965576
# Running combination 21/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.8223836421966553
# Final Validation Loss: 3.2154483795166016
# Running combination 22/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 32.76371765136719
# Final Validation Loss: 31.048982620239258
# Running combination 23/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 18.185455322265625
# Final Validation Loss: 16.65015411376953
# Running combination 24/30: {'units3': 64, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 37.85411834716797
# Final Validation Loss: 37.2357063293457
# Running combination 25/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 11.743882179260254
# Final Validation Loss: 11.121406555175781
# Running combination 26/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 3.8512935638427734
# Final Validation Loss: 3.237273931503296
# Running combination 27/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 3.758235454559326
# Final Validation Loss: 3.4772307872772217
# Running combination 28/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.297395706176758
# Final Validation Loss: 2.538283348083496
# Running combination 29/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 11.352842330932617
# Final Validation Loss: 10.90536117553711
# Running combination 30/30: {'units3': 128, 'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 5.003570079803467
# Final Validation Loss: 3.9782352447509766
# Top results:
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 2.5046699047088623, 'final_val_loss': 1.3127573728561401}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.3926889896392822, 'final_val_loss': 1.3285162448883057}
# {'params': {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 2.3548293113708496, 'final_val_loss': 1.4383693933486938}
# {'params': {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.1066019535064697, 'final_val_loss': 1.4474060535430908}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 256}, 'final_train_loss': 2.3006513118743896, 'final_val_loss': 1.5165246725082397}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 52s 699ms/step - loss: 3.0433 - val_loss: 1.3046
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 62ms/step - loss: 2.1805 - val_loss: 1.2938
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.9464 - val_loss: 1.2943
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.9166 - val_loss: 1.2944
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.8273 - val_loss: 1.2921
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - loss: 1.7212 - val_loss: 1.2927
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - loss: 1.6782 - val_loss: 1.2993
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - loss: 1.7104 - val_loss: 1.2986
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step - loss: 1.4945 - val_loss: 1.2974
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - loss: 1.5518 - val_loss: 1.3029
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5292 - val_loss: 1.2980
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.5126 - val_loss: 1.3034
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.4422 - val_loss: 1.2969
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.3168 - val_loss: 1.3150
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.4586 - val_loss: 1.3198
# Final Training Loss: 1.4952706098556519
# Final Validation Loss: 1.3198204040527344

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# LSTM Model Performance:
# Training RMSE: 0.02036313999229088
# Test RMSE: 0.023252558309642058
# Training MAE: 0.01470445120457061
# Test MAE: 0.01746296325726268
# Directional Accuracy on Training Data: 50.63731170336037%
# Directional Accuracy on Test Data: 47.183098591549296%

# %% [markdown]
# ### 2. Optuna (Model 3)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.

    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    # Compile the model with mean squared error loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-12 11:16:06,333] A new study created in memory with name: no-name-3209fd40-9291-48b0-bd5b-00ebea04666e
# [I 2024-11-12 11:16:12,870] Trial 0 finished with value: 1.6677783727645874 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.6677783727645874.
# [I 2024-11-12 11:16:19,035] Trial 1 finished with value: 3.840607166290283 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.6677783727645874.
# [I 2024-11-12 11:16:38,675] Trial 2 finished with value: 4.308155059814453 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.6677783727645874.
# [I 2024-11-12 11:16:48,261] Trial 3 finished with value: 1.8318575620651245 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.6677783727645874.
# [I 2024-11-12 11:16:51,695] Trial 4 finished with value: 1.5349124670028687 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 4 with value: 1.5349124670028687.
# [I 2024-11-12 11:17:06,746] Trial 5 finished with value: 1.562707781791687 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06621901977279396, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 256}. Best is trial 4 with value: 1.5349124670028687.
# [I 2024-11-12 11:17:21,414] Trial 6 finished with value: 2.930145502090454 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0038300508438275606, 'learning_rate': 0.0001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 3, 'epochs': 50, 'batch_size': 256}. Best is trial 4 with value: 1.5349124670028687.
# [I 2024-11-12 11:17:25,648] Trial 7 finished with value: 1.2540634870529175 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.2540634870529175.
# [I 2024-11-12 11:17:32,043] Trial 8 finished with value: 1.491469144821167 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0017384974140603195, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 1.2540634870529175.
# [I 2024-11-12 11:17:37,650] Trial 9 finished with value: 1.262712001800537 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.028980866560207673, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 7 with value: 1.2540634870529175.
# [I 2024-11-12 11:17:41,511] Trial 10 finished with value: 1.2368425130844116 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010012325682668814, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.2368425130844116.
# [I 2024-11-12 11:17:45,248] Trial 11 finished with value: 1.2349098920822144 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011454828358668492, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:17:49,098] Trial 12 finished with value: 1.2418503761291504 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011554791595316783, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:17:53,694] Trial 13 finished with value: 1.2879024744033813 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008097857902138784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:00,914] Trial 14 finished with value: 1.4423328638076782 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001049410437362456, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:04,178] Trial 15 finished with value: 1.3195818662643433 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.003502431872516879, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 32}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:11,295] Trial 16 finished with value: 1.5790010690689087 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.009118985456676882, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:14,851] Trial 17 finished with value: 1.2664676904678345 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.002085993900111682, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:18,480] Trial 18 finished with value: 1.2896915674209595 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.005040684715226819, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:26,708] Trial 19 finished with value: 1.6193733215332031 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.021365105049329695, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 150, 'batch_size': 32}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:40,702] Trial 20 finished with value: 1.6173111200332642 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.016427446091396673, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:43,567] Trial 21 finished with value: 1.2510688304901123 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010046340599894252, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:47,124] Trial 22 finished with value: 1.243351936340332 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0015394277020084359, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:50,532] Trial 23 finished with value: 1.2614340782165527 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0025012773532357905, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:54,363] Trial 24 finished with value: 1.2363110780715942 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0012923257479048517, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:18:57,607] Trial 25 finished with value: 1.297965168952942 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.00599884652001288, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:19:01,415] Trial 26 finished with value: 1.2483816146850586 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0026426776949695988, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:19:07,137] Trial 27 finished with value: 1.6120529174804688 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0015548773626474959, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 150, 'batch_size': 32}. Best is trial 11 with value: 1.2349098920822144.
# [I 2024-11-12 11:19:10,105] Trial 28 finished with value: 1.0997122526168823 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0012240775718069888, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}. Best is trial 28 with value: 1.0997122526168823.
# [I 2024-11-12 11:19:18,576] Trial 29 finished with value: 1.402254343032837 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.003022043934966891, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 120}. Best is trial 28 with value: 1.0997122526168823.
# Best hyperparameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0012240775718069888, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}
# Best validation loss: 1.0997122526168823

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0012240775718069888,
    'epochs': 150,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 2.3244 - val_loss: 1.1336
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7604 - val_loss: 1.1182
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.7420 - val_loss: 1.1203
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.6975 - val_loss: 1.1198
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4328 - val_loss: 1.1160
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4970 - val_loss: 1.1097
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3233 - val_loss: 1.1167
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.5585 - val_loss: 1.1230
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3023 - val_loss: 1.1226
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.4161 - val_loss: 1.1124
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3250 - val_loss: 1.1056
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3238 - val_loss: 1.1086
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2871 - val_loss: 1.1148
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.3676 - val_loss: 1.1115
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1967 - val_loss: 1.1055
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2330 - val_loss: 1.1082
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.2806 - val_loss: 1.1105
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.2427 - val_loss: 1.1092
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2018 - val_loss: 1.1110
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.2281 - val_loss: 1.1085
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1810 - val_loss: 1.1051
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1733 - val_loss: 1.1052
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1771 - val_loss: 1.1074
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1635 - val_loss: 1.1022
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1053 - val_loss: 1.1044
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1509 - val_loss: 1.1095
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 1.1103 - val_loss: 1.1045
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1481 - val_loss: 1.1012
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1572 - val_loss: 1.1040
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1626 - val_loss: 1.1068
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.1339 - val_loss: 1.1089
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0750 - val_loss: 1.1035
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1121 - val_loss: 1.1075
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0842 - val_loss: 1.1089
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1666 - val_loss: 1.1110
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.1221 - val_loss: 1.1078
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 1.0450 - val_loss: 1.1101
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0539 - val_loss: 1.1116
# Final Training Loss: 1.1106399297714233
# Final Validation Loss: 1.1116175651550293

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# LSTM Model Performance:
# Training RMSE: 0.020067693141061327
# Test RMSE: 0.02321681888631882
# Training MAE: 0.014603502794180514
# Test MAE: 0.01749191427906337
# Directional Accuracy on Training Data: 60.02317497103129%
# Directional Accuracy on Test Data: 57.04225352112676%

# %% [markdown]
# ### 3. Keras Tuner (Model 4)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.


    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 03s]
# val_loss: 1.3014826774597168
#
# Best val_loss So Far: 1.3014826774597168
# Total elapsed time: 00h 06m 43s
# Built model with params: dropout_rate=0.3, recurrent_dropout=0.2, l2_lambda=0.001, learning_rate=0.0005, learning_rate_decay=1e-05, clipnorm=5.0, units=32, num_layers=1, batch_size=32
# Best hyperparameters: {'dropout_rate': 0.3, 'recurrent_dropout': 0.2, 'l2_lambda': 0.001, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'batch_size': 32}
# Best batch size: 32

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.3,
    'clipnorm': 5.0,
    'batch_size': 32
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model
    
# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 2.2405 - val_loss: 1.3087
# Epoch 2/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8115 - val_loss: 1.3033
# Epoch 3/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5926 - val_loss: 1.2997
# Epoch 4/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5462 - val_loss: 1.2990
# Epoch 5/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3853 - val_loss: 1.3041
# Epoch 6/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3453 - val_loss: 1.3159
# Epoch 7/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3528 - val_loss: 1.3134
# Epoch 8/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2184 - val_loss: 1.3142
# Epoch 9/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2222 - val_loss: 1.3318
# Epoch 10/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2066 - val_loss: 1.3309
# Epoch 11/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1057 - val_loss: 1.3501
# Epoch 12/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1121 - val_loss: 1.3589
# Epoch 13/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0955 - val_loss: 1.3720
# Epoch 14/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1768 - val_loss: 1.3621
# Final Training Loss: 1.2699766159057617
# Final Validation Loss: 1.362116813659668

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# LSTM Model Performance:
# Training RMSE: 0.020476492418478345
# Test RMSE: 0.023281786821013953
# Training MAE: 0.014707478621401694
# Test MAE: 0.017468277754463614
# Directional Accuracy on Training Data: 46.581691772885286%
# Directional Accuracy on Test Data: 57.04225352112676%

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 12
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020462583   | 0.02036314    | 0.020067693   | 0.020476492   |
# | **Test RMSE**  | 0.024142296   | 0.023252558   | 0.023216819   | 0.023281787   |
# | **Train MAE**  | 0.014867623   | 0.014704451   | 0.014603503   | 0.014707479   |
# | **Test MAE**   | 0.018599401   | 0.017462963   | 0.017491914   | 0.017468278   |
# | **Train Loss** | 0.957551241   | 1.49527061    | 1.11063993    | 1.269976616   |
# | **Val Loss**   | 1.379671335   | 1.319820404   | 1.111617565   | 1.362116814   |
# | **Train DA**   | 60%           | 51%           | 60%           | 47%           |
# | **Test DA**    | 61%           | 47%           | 57%           | 57%           |
#
#
# For the Sequence Length of 12 the **best performer is the model 3**, due to the lower RMSE, MAE so as the directional accuracy. In addition, looking the train and val loss, the convergenge between them is more balanced than the others.

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0012240775718069888,
    'epochs': 150,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 2.3244 - val_loss: 1.1336
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.7604 - val_loss: 1.1182
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.7420 - val_loss: 1.1203
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6975 - val_loss: 1.1198
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4328 - val_loss: 1.1160
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.4970 - val_loss: 1.1097
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.3233 - val_loss: 1.1167
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.5585 - val_loss: 1.1230
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3023 - val_loss: 1.1226
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.4161 - val_loss: 1.1124
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.3250 - val_loss: 1.1056
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.3238 - val_loss: 1.1086
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2871 - val_loss: 1.1148
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3676 - val_loss: 1.1115
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1967 - val_loss: 1.1055
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.2330 - val_loss: 1.1082
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2806 - val_loss: 1.1105
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2427 - val_loss: 1.1092
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.2018 - val_loss: 1.1110
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2281 - val_loss: 1.1085
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1810 - val_loss: 1.1051
# Epoch 22/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1733 - val_loss: 1.1052
# Epoch 23/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1771 - val_loss: 1.1074
# Epoch 24/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1635 - val_loss: 1.1022
# Epoch 25/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1053 - val_loss: 1.1044
# Epoch 26/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1509 - val_loss: 1.1095
# Epoch 27/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1103 - val_loss: 1.1045
# Epoch 28/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.1481 - val_loss: 1.1012
# Epoch 29/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1572 - val_loss: 1.1040
# Epoch 30/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 1.1626 - val_loss: 1.1068
# Epoch 31/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.1339 - val_loss: 1.1089
# Epoch 32/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0750 - val_loss: 1.1035
# Epoch 33/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.1121 - val_loss: 1.1075
# Epoch 34/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.0842 - val_loss: 1.1089
# Epoch 35/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.1666 - val_loss: 1.1110
# Epoch 36/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.1221 - val_loss: 1.1078
# Epoch 37/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.0450 - val_loss: 1.1101
# Epoch 38/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0539 - val_loss: 1.1116
# Final Training Loss: 1.1106399297714233
# Final Validation Loss: 1.1116175651550293

# %%
# Extract scaled train and validation loss from history
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Retrieve the center (median) and scale (IQR) from the RobustScaler
center = scaler_y.center_[0]  # Median used by the RobustScaler
scale = scaler_y.scale_[0]    # IQR used by the RobustScaler

# Descale the train and validation losses
descaled_train_loss = scaled_train_loss * scale + center
descaled_val_loss = scaled_val_loss * scale + center

# Print the descaled losses
print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.026109409378283235
# Descaled Validation Loss: 0.026129178753948618

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0012240775718069888,
    'epochs': 150,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
        
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step
# Fold 1 RMSE: 1.4110826428501086
# Fold 2
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Fold 2 RMSE: 0.9387710407969232
# Fold 3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3 RMSE: 0.8040516074014755
# Fold 4
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# Fold 4 RMSE: 1.1263726016449342
# Average RMSE from TSCV: 1.0700694731733604

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 306ms/step
# Rolling window RMSE: 1.2926857039172333
# Rolling window starting at index 50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 391ms/step
# Rolling window RMSE: 1.386101126655668
# Rolling window starting at index 100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 285ms/step
# Rolling window RMSE: 0.9300439811439869
# Rolling window starting at index 150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 282ms/step
# Rolling window RMSE: 0.7318849551306942
# Rolling window starting at index 200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 322ms/step
# Rolling window RMSE: 0.827111260496412
# Rolling window starting at index 250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step
# Rolling window RMSE: 0.9113291132250944
# Rolling window starting at index 300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 324ms/step
# Rolling window RMSE: 0.9323424941980335
# Rolling window starting at index 350
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 312ms/step
# Rolling window RMSE: 0.451594167930477
# Rolling window starting at index 400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 318ms/step
# Rolling window RMSE: 0.8231182518722951
# Rolling window starting at index 450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 307ms/step
# Rolling window RMSE: 0.9378300030276461
# Rolling window starting at index 500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 358ms/step
# Rolling window RMSE: 1.4596133756470382
# Average Rolling Window RMSE: 0.9712413121131434

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.032184849118273406, 0.02263394123514285, 0.01990969543462878, 0.026427549561937883]
# Descaled FRWCV RMSE Values: [0.029790670672355853, 0.03167968227732172, 0.022457465911493286, 0.01845036848802006, 0.020375999081562873, 0.022079020879100943, 0.02250394557947506, 0.012782433426924582, 0.02029525396037656, 0.022614911922693524, 0.03316621937559794]
# Average Descaled TSCV RMSE: 0.02528900883749573
# Average Descaled FRWCV RMSE: 0.023290542870447486

# %% [markdown]
# ## Sequence Length = 26

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 26  # Number of time steps used for target prediction, 26 weeks (Six-Months).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (850, 26, 5)
# Reshaped y_train_seq shape: (850, 1)
# Reshaped X_test_seq shape: (129, 26, 5)
# Reshaped  y_test_seq shape: (129, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.906967043876648
# Final Validation Loss: 1.7449560165405273
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.219129800796509
# Final Validation Loss: 1.9963220357894897
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1.899275779724121
# Final Validation Loss: 1.2382384538650513
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.285343170166016
# Final Validation Loss: 6.542275428771973
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.293200731277466
# Final Validation Loss: 2.652348279953003
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.3065541982650757
# Final Validation Loss: 1.2485722303390503
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.459460258483887
# Final Validation Loss: 9.392422676086426
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.9610633850097656
# Final Validation Loss: 1.7232389450073242
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.753098726272583
# Final Validation Loss: 2.3158445358276367
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.2343220710754395
# Final Validation Loss: 1.2861942052841187
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.79821252822876
# Final Validation Loss: 6.41287899017334
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.236247181892395
# Final Validation Loss: 1.2529935836791992
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.914656162261963
# Final Validation Loss: 4.477446556091309
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1.6688860654830933
# Final Validation Loss: 1.5028269290924072
# Running combination 15/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.723233938217163
# Final Validation Loss: 1.4073044061660767
# Running combination 16/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.648341178894043
# Final Validation Loss: 2.3738491535186768
# Running combination 17/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 13.398627281188965
# Final Validation Loss: 12.143445014953613
# Running combination 18/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 14.101696968078613
# Final Validation Loss: 13.77945327758789
# Running combination 19/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 20.06484603881836
# Final Validation Loss: 19.505950927734375
# Running combination 20/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.7217905521392822
# Final Validation Loss: 1.857625961303711
# Running combination 21/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.4276814460754395
# Final Validation Loss: 1.5260605812072754
# Running combination 22/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.0188372135162354
# Final Validation Loss: 1.7473595142364502
# Running combination 23/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 7.4843668937683105
# Final Validation Loss: 6.698601722717285
# Running combination 24/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.143657922744751
# Final Validation Loss: 3.3842082023620605
# Running combination 25/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 14.940683364868164
# Final Validation Loss: 14.54581356048584
# Running combination 26/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 2.5745811462402344
# Final Validation Loss: 1.577146053314209
# Running combination 27/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.5002291202545166
# Final Validation Loss: 1.5949159860610962
# Running combination 28/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.3330538272857666
# Final Validation Loss: 1.2864501476287842
# Running combination 29/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 1.9023240804672241
# Final Validation Loss: 1.5721735954284668
# Running combination 30/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 5.917635440826416
# Final Validation Loss: 5.4413299560546875
# Top results:
# {'params': {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}, 'final_train_loss': 1.899275779724121, 'final_val_loss': 1.2382384538650513}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.3065541982650757, 'final_val_loss': 1.2485722303390503}
# {'params': {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 1.236247181892395, 'final_val_loss': 1.2529935836791992}
# {'params': {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.2343220710754395, 'final_val_loss': 1.2861942052841187}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.3330538272857666, 'final_val_loss': 1.2864501476287842}

# %%
# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'units2': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam', 
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 32
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 10s 67ms/step - loss: 3.1251 - val_loss: 1.2478
# Epoch 2/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 2.6496 - val_loss: 1.2394
# Epoch 3/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 2.4609 - val_loss: 1.2190
# Epoch 4/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 2.0647 - val_loss: 1.2188
# Epoch 5/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 2.0062 - val_loss: 1.2135
# Epoch 6/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.9668 - val_loss: 1.2482
# Epoch 7/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.5663 - val_loss: 1.2348
# Epoch 8/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.5482 - val_loss: 1.2825
# Epoch 9/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.4322 - val_loss: 1.2457
# Epoch 10/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.3012 - val_loss: 1.2257
# Epoch 11/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.3202 - val_loss: 1.2081
# Epoch 12/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.1894 - val_loss: 1.2687
# Epoch 13/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.1362 - val_loss: 1.3157
# Epoch 14/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.1332 - val_loss: 1.3575
# Epoch 15/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.1746 - val_loss: 1.3558
# Epoch 16/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.0483 - val_loss: 1.2754
# Epoch 17/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.0334 - val_loss: 1.3224
# Epoch 18/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 0.9838 - val_loss: 1.3651
# Epoch 19/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.9799 - val_loss: 1.4038
# Epoch 20/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.0207 - val_loss: 1.3631
# Epoch 21/200
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.9020 - val_loss: 1.4032
# Final Training Loss: 0.958985447883606
# Final Validation Loss: 1.4031987190246582

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# LSTM Model Performance:
# Training RMSE: 0.02045132528847457
# Test RMSE: 0.02389254993427906
# Training MAE: 0.014867622764142616
# Test MAE: 0.018289230918761123
# Directional Accuracy on Training Data: 57.95053003533569%
# Directional Accuracy on Test Data: 63.28125%

# %% [markdown]
# ### Three Layers (Model 2)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],
    'recurrent_dropout': [0.1, 0.2],
    'l2_lambda': [0.001, 0.01, 0.1],
    'learning_rate': [0.001, 0.0005, 0.0001],
    'learning_rate_decay': [1e-6, 1e-5, 0],
    'units1': [32, 64, 128],
    'units2': [32, 64, 128],
    'units3': [32, 64, 128],
    'batch_size': [32, 64, 120, 256],  
    'epochs': [50, 100, 200],
    'optimizer': ['adam'],
    'clipnorm': [1.0, 5.0]
}

# Generate a list of random combinations with ParameterSampler
n_iter_search = 30
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42))

# Define the function to build the model with variable parameters
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, units3, optimizer_name, loss_function):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units2, return_sequences=True, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units3, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer.
    model.add(Dense(1))
    
    # Select optimizer with decay and clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to keep track of results
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        units3=params['units3'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.0787794589996338
# Final Validation Loss: 1.4564430713653564
# Running combination 2/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 4.176022052764893
# Final Validation Loss: 4.013821601867676
# Running combination 3/30: {'units3': 128, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.7349512577056885
# Final Validation Loss: 1.6662168502807617
# Running combination 4/30: {'units3': 128, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 8.128924369812012
# Final Validation Loss: 7.2703962326049805
# Running combination 5/30: {'units3': 64, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.278831958770752
# Final Validation Loss: 3.9878907203674316
# Running combination 6/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.272596597671509
# Final Validation Loss: 1.363166332244873
# Running combination 7/30: {'units3': 32, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 3.0026144981384277
# Final Validation Loss: 2.838118314743042
# Running combination 8/30: {'units3': 32, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.687049865722656
# Final Validation Loss: 3.320486307144165
# Running combination 9/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.183878183364868
# Final Validation Loss: 1.6259069442749023
# Running combination 10/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.9260318279266357
# Final Validation Loss: 1.2655452489852905
# Running combination 11/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.5646636486053467
# Final Validation Loss: 1.5255234241485596
# Running combination 12/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 17.492652893066406
# Final Validation Loss: 16.826868057250977
# Running combination 13/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.532920479774475
# Final Validation Loss: 1.2857314348220825
# Running combination 14/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.4101358652114868
# Final Validation Loss: 1.3549787998199463
# Running combination 15/30: {'units3': 128, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 3.9785923957824707
# Final Validation Loss: 3.0422513484954834
# Running combination 16/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.0070862770080566
# Final Validation Loss: 2.9220144748687744
# Running combination 17/30: {'units3': 128, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 15.899103164672852
# Final Validation Loss: 15.184717178344727
# Running combination 18/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.643212080001831
# Final Validation Loss: 1.3144559860229492
# Running combination 19/30: {'units3': 128, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.292004108428955
# Final Validation Loss: 4.2327423095703125
# Running combination 20/30: {'units3': 64, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.165900945663452
# Final Validation Loss: 2.7040300369262695
# Running combination 21/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.7631685733795166
# Final Validation Loss: 3.075751304626465
# Running combination 22/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 33.37615203857422
# Final Validation Loss: 31.472293853759766
# Running combination 23/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 18.161930084228516
# Final Validation Loss: 16.831972122192383
# Running combination 24/30: {'units3': 64, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 37.73628234863281
# Final Validation Loss: 37.396697998046875
# Running combination 25/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 11.991292953491211
# Final Validation Loss: 11.329154968261719
# Running combination 26/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 3.8187763690948486
# Final Validation Loss: 3.3658900260925293
# Running combination 27/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.26653528213501
# Final Validation Loss: 3.5731849670410156
# Running combination 28/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 2.97536039352417
# Final Validation Loss: 2.660989761352539
# Running combination 29/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 11.499101638793945
# Final Validation Loss: 11.101824760437012
# Running combination 30/30: {'units3': 128, 'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 5.297171592712402
# Final Validation Loss: 3.820237636566162
# Top results:
# {'params': {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 1.9260318279266357, 'final_val_loss': 1.2655452489852905}
# {'params': {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 1.532920479774475, 'final_val_loss': 1.2857314348220825}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 2.643212080001831, 'final_val_loss': 1.3144559860229492}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.4101358652114868, 'final_val_loss': 1.3549787998199463}
# {'params': {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.272596597671509, 'final_val_loss': 1.363166332244873}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'units3': 128,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
        
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 16s 213ms/step - loss: 3.7799 - val_loss: 1.3053
# Epoch 2/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 4s 103ms/step - loss: 2.4057 - val_loss: 1.3075
# Epoch 3/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 2.2163 - val_loss: 1.3077
# Epoch 4/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 2.0399 - val_loss: 1.2873
# Epoch 5/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 1.9132 - val_loss: 1.3150
# Epoch 6/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 1.8821 - val_loss: 1.3195
# Epoch 7/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 107ms/step - loss: 1.8268 - val_loss: 1.2792
# Epoch 8/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 111ms/step - loss: 1.9069 - val_loss: 1.3071
# Epoch 9/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 1.9675 - val_loss: 1.3029
# Epoch 10/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 1.8100 - val_loss: 1.2974
# Epoch 11/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 1.6048 - val_loss: 1.3615
# Epoch 12/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 1.5735 - val_loss: 1.3115
# Epoch 13/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 1.6046 - val_loss: 1.2991
# Epoch 14/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 1.6668 - val_loss: 1.2871
# Epoch 15/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 1.6351 - val_loss: 1.2651
# Epoch 16/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 1.5249 - val_loss: 1.2870
# Epoch 17/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 105ms/step - loss: 1.5075 - val_loss: 1.2975
# Epoch 18/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 1.5495 - val_loss: 1.3427
# Epoch 19/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 1.4711 - val_loss: 1.3503
# Epoch 20/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 1.3938 - val_loss: 1.4121
# Epoch 21/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 1.5029 - val_loss: 1.5205
# Epoch 22/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 3s 110ms/step - loss: 1.4988 - val_loss: 1.4421
# Epoch 23/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 111ms/step - loss: 1.4197 - val_loss: 1.4388
# Epoch 24/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 1.3753 - val_loss: 1.3614
# Epoch 25/100
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 108ms/step - loss: 1.3644 - val_loss: 1.4571
# Final Training Loss: 1.3773084878921509
# Final Validation Loss: 1.457067608833313

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 65ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# LSTM Model Performance:
# Training RMSE: 0.020485583516343667
# Test RMSE: 0.024109121633025827
# Training MAE: 0.015027833107223365
# Test MAE: 0.018324891480172485
# Directional Accuracy on Training Data: 52.65017667844523%
# Directional Accuracy on Test Data: 58.59375%

# %% [markdown]
# ### 2. Optuna (Model 3)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.

    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    # Compile the model with mean squared error loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-12 11:34:10,754] A new study created in memory with name: no-name-3cb7531c-84c6-4f2b-93e4-b185d17a3dcd
# [I 2024-11-12 11:34:18,145] Trial 0 finished with value: 1.4179606437683105 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:34:26,089] Trial 1 finished with value: 3.978782892227173 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:34:46,293] Trial 2 finished with value: 5.994845867156982 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:35:00,219] Trial 3 finished with value: 1.943937063217163 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:35:05,220] Trial 4 finished with value: 1.4278881549835205 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:35:28,482] Trial 5 finished with value: 1.7957264184951782 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06621901977279396, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:35:55,130] Trial 6 finished with value: 3.0288195610046387 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0038300508438275606, 'learning_rate': 0.0001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 3, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.4179606437683105.
# [I 2024-11-12 11:35:58,763] Trial 7 finished with value: 0.9843617081642151 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 0.9843617081642151.
# [I 2024-11-12 11:36:11,029] Trial 8 finished with value: 1.4790369272232056 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0017384974140603195, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 0.9843617081642151.
# [I 2024-11-12 11:36:18,797] Trial 9 finished with value: 1.2671000957489014 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.028980866560207673, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 7 with value: 0.9843617081642151.
# [I 2024-11-12 11:36:23,854] Trial 10 finished with value: 0.963615357875824 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010012325682668814, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 0.963615357875824.
# [I 2024-11-12 11:36:29,454] Trial 11 finished with value: 0.9630685448646545 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011454828358668492, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 11 with value: 0.9630685448646545.
# [I 2024-11-12 11:36:35,836] Trial 12 finished with value: 0.9598102569580078 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011554791595316783, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:36:42,908] Trial 13 finished with value: 0.9955556988716125 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008097857902138784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:36:52,343] Trial 14 finished with value: 1.226648211479187 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010494090688129005, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:36:57,443] Trial 15 finished with value: 1.2190101146697998 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008178069238115187, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 32}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:03,608] Trial 16 finished with value: 1.1890201568603516 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0034273241341765317, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:07,600] Trial 17 finished with value: 0.987539529800415 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0021937683714059186, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:14,458] Trial 18 finished with value: 1.03449547290802 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0129316545365617, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:20,121] Trial 19 finished with value: 1.260119080543518 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0015110031084659837, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 150, 'batch_size': 32}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:42,700] Trial 20 finished with value: 1.476563811302185 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.005616343791737484, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:48,051] Trial 21 finished with value: 0.9817957878112793 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010046340599894252, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:53,628] Trial 22 finished with value: 0.9710972309112549 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.002514919935423883, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:37:58,247] Trial 23 finished with value: 0.9862649440765381 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0012524579658409949, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:03,357] Trial 24 finished with value: 0.980018138885498 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026330213119091822, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:06,997] Trial 25 finished with value: 1.0006309747695923 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0013056214129911383, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:14,117] Trial 26 finished with value: 0.9849701523780823 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0050556828013785735, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:33,502] Trial 27 finished with value: 1.6966063976287842 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.014766174314700611, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 32}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:35,867] Trial 28 finished with value: 1.119903564453125 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0016453505299683577, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 100, 'batch_size': 120}. Best is trial 12 with value: 0.9598102569580078.
# [I 2024-11-12 11:38:47,027] Trial 29 finished with value: 1.6089078187942505 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.003120232515467871, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 200, 'batch_size': 64}. Best is trial 12 with value: 0.9598102569580078.
# Best hyperparameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011554791595316783, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}
# Best validation loss: 0.9598102569580078

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0011554791595316783,
    'epochs': 200,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 1.9617 - val_loss: 1.0205
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.6882 - val_loss: 0.9854
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.7532 - val_loss: 1.0043
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4373 - val_loss: 0.9747
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.5096 - val_loss: 0.9870
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2097 - val_loss: 0.9791
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2452 - val_loss: 0.9918
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1727 - val_loss: 0.9874
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2345 - val_loss: 1.0106
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1735 - val_loss: 1.0038
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2035 - val_loss: 1.0052
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1153 - val_loss: 0.9834
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1820 - val_loss: 0.9906
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1653 - val_loss: 0.9852
# Final Training Loss: 1.1768219470977783
# Final Validation Loss: 0.9851685166358948

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# LSTM Model Performance:
# Training RMSE: 0.02049090151199721
# Test RMSE: 0.024202665883877532
# Training MAE: 0.014824705716491363
# Test MAE: 0.018446662186742232
# Directional Accuracy on Training Data: 63.60424028268551%
# Directional Accuracy on Test Data: 64.84375%

# %% [markdown]
# ### 3. Keras Tuner (Model 4)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.


    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 06s]
# val_loss: 1.1726760864257812
#
# Best val_loss So Far: 1.1726760864257812
# Total elapsed time: 00h 09m 29s
# Built model with params: dropout_rate=0.3, recurrent_dropout=0.1, l2_lambda=0.0029343923926946802, learning_rate=0.001, learning_rate_decay=0.0, clipnorm=1.0, units=64, num_layers=1, batch_size=120
# Best hyperparameters: {'dropout_rate': 0.3, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0029343923926946802, 'learning_rate': 0.001, 'learning_rate_decay': 0.0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'batch_size': 120}
# Best batch size: 120

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 64,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 00.0029343923926946802,
    'epochs': 200,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 1.8447 - val_loss: 1.2412
# Epoch 2/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.6957 - val_loss: 1.1935
# Epoch 3/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.6915 - val_loss: 1.2109
# Epoch 4/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4072 - val_loss: 1.1834
# Epoch 5/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.3855 - val_loss: 1.1809
# Epoch 6/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.4130 - val_loss: 1.2066
# Epoch 7/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.4127 - val_loss: 1.2005
# Epoch 8/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.3875 - val_loss: 1.2036
# Epoch 9/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2930 - val_loss: 1.2272
# Epoch 10/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.3312 - val_loss: 1.2046
# Epoch 11/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.2877 - val_loss: 1.2099
# Epoch 12/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2525 - val_loss: 1.2079
# Epoch 13/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.2052 - val_loss: 1.1928
# Epoch 14/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 1.2559 - val_loss: 1.2092
# Epoch 15/200
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1727 - val_loss: 1.1957
# Final Training Loss: 1.1160093545913696
# Final Validation Loss: 1.1956651210784912

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# LSTM Model Performance:
# Training RMSE: 0.020436755690125378
# Test RMSE: 0.02435714599002603
# Training MAE: 0.014786491937594367
# Test MAE: 0.018710137185414526
# Directional Accuracy on Training Data: 59.59952885747939%
# Directional Accuracy on Test Data: 58.59375%

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 26
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020451325   | 0.020485584   | 0.020490902   | 0.020436756   |
# | **Test RMSE**  | 0.02389255    | 0.024109122   | 0.024202666   | 0.024357146   |
# | **Train MAE**  | 0.014867623   | 0.015027833   | 0.014824706   | 0.014786492   |
# | **Test MAE**   | 0.018289231   | 0.018324891   | 0.018446662   | 0.018710137   |
# | **Train Loss** | 0.958985448   | 1.377308488   | 1.176821947   | 1.116009355   |
# | **Val Loss**   | 1.403198719   | 1.457067609   | 0.985168517   | 1.195665121   |
# | **Train DA**   | 58%           | 53%           | 64%           | 60%           |
# | **Test DA**    | 63%           | 59%           | 65%           | 59%           |
#
#
# **The best model for the sequence length of 26 is the model 3**.
# - Despite having the lowest RMSE, the model 1 shows signs of overfitting after 10-15 epochs.
# - Model 4 has the highest of the scores and its plot shows instability after 11 epochs.
# - The validation loss of model 2 does not decreases, in fact slightly increases after certain epochs.

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0011554791595316783,
    'epochs': 200,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 5s 83ms/step - loss: 1.9617 - val_loss: 1.0205
# Epoch 2/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.6882 - val_loss: 0.9854
# Epoch 3/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.7532 - val_loss: 1.0043
# Epoch 4/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.4373 - val_loss: 0.9747
# Epoch 5/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.5096 - val_loss: 0.9870
# Epoch 6/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.2097 - val_loss: 0.9791
# Epoch 7/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.2452 - val_loss: 0.9918
# Epoch 8/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.1727 - val_loss: 0.9874
# Epoch 9/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.2345 - val_loss: 1.0106
# Epoch 10/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.1735 - val_loss: 1.0038
# Epoch 11/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.2035 - val_loss: 1.0052
# Epoch 12/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - loss: 1.1153 - val_loss: 0.9834
# Epoch 13/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step - loss: 1.1820 - val_loss: 0.9906
# Epoch 14/200
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - loss: 1.1653 - val_loss: 0.9852
# Final Training Loss: 1.1768219470977783
# Final Validation Loss: 0.9851685166358948

# %%
# Extract scaled train and validation loss from history
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Retrieve the center (median) and scale (IQR) from the RobustScaler
center = scaler_y.center_[0]  # Median used by the RobustScaler
scale = scaler_y.scale_[0]    # IQR used by the RobustScaler

# Descale the train and validation losses
descaled_train_loss = scaled_train_loss * scale + center
descaled_val_loss = scaled_val_loss * scale + center

# Print the descaled losses
print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.027447717284030147
# Descaled Validation Loss: 0.023572173571213842

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0011554791595316783,
    'epochs': 200,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Fold 1 RMSE: 1.397435351054143
# Fold 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Fold 2 RMSE: 0.9501629731875095
# Fold 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Fold 3 RMSE: 0.7571079417799228
# Fold 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# Fold 4 RMSE: 1.1397426834835287
# Average RMSE from TSCV: 1.061112237376276

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average RMSE from FRWCV: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step
# Rolling window RMSE: 1.0042528222796188
# Rolling window starting at index 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# Rolling window RMSE: 1.5329369558317876
# Rolling window starting at index 100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# Rolling window RMSE: 0.9691734899306531
# Rolling window starting at index 150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step
# Rolling window RMSE: 0.7924602015393607
# Rolling window starting at index 200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# Rolling window RMSE: 0.8016921371527006
# Rolling window starting at index 250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# Rolling window RMSE: 1.002672730469931
# Rolling window starting at index 300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Rolling window RMSE: 0.6056635150648219
# Rolling window starting at index 350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# Rolling window RMSE: 0.41679454559013174
# Rolling window starting at index 400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# Rolling window RMSE: 0.8032528917772532
# Rolling window starting at index 450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Rolling window RMSE: 0.6266712940255121
# Rolling window starting at index 500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# Rolling window RMSE: 1.6993967472314175
# Average RMSE from FRWCV: 0.9322697573539263

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.0319088787075724, 0.02286430461474302, 0.018960418253846235, 0.026697914336961878]
# Descaled FRWCV RMSE Values: [0.02395808923456905, 0.034648941284104055, 0.02324872814665539, 0.01967529837738145, 0.019861983113142127, 0.02392613721125306, 0.015897965917969534, 0.012078728529785629, 0.019893544107160634, 0.01632277733655528, 0.038015028686979174]
# Average Descaled TSCV RMSE: 0.025107878978280884
# Average Descaled FRWCV RMSE: 0.02250247472232322

# %% [markdown]
# ## Sequence Length = 52

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 52  # Number of time steps used for target prediction, 52 weeks (One year).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (824, 52, 5)
# Reshaped y_train_seq shape: (824, 1)
# Reshaped X_test_seq shape: (103, 52, 5)
# Reshaped  y_test_seq shape: (103, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.672315001487732
# Final Validation Loss: 1.9968889951705933
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.5030605792999268
# Final Validation Loss: 2.5075130462646484
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1.7099303007125854
# Final Validation Loss: 1.6403313875198364
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.410898685455322
# Final Validation Loss: 6.875063896179199
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.5231165885925293
# Final Validation Loss: 3.220935106277466
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.569894552230835
# Final Validation Loss: 1.680540680885315
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.481560707092285
# Final Validation Loss: 9.890140533447266
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.955323576927185
# Final Validation Loss: 2.000710964202881
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.9017443656921387
# Final Validation Loss: 2.55843448638916
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.2019776105880737
# Final Validation Loss: 1.4918084144592285
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.883412837982178
# Final Validation Loss: 6.819369316101074
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.7305622100830078
# Final Validation Loss: 1.688315510749817
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.324139595031738
# Final Validation Loss: 5.1842041015625
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1.8331708908081055
# Final Validation Loss: 1.6907588243484497
# Running combination 15/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.7051609754562378
# Final Validation Loss: 1.6078088283538818
# Running combination 16/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.7554423809051514
# Final Validation Loss: 2.568275213241577
# Running combination 17/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 14.710824966430664
# Final Validation Loss: 13.655237197875977
# Running combination 18/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 14.367362022399902
# Final Validation Loss: 14.243341445922852
# Running combination 19/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 20.323062896728516
# Final Validation Loss: 20.4150390625
# Running combination 20/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.699561834335327
# Final Validation Loss: 2.0984504222869873
# Running combination 21/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.5302172899246216
# Final Validation Loss: 1.769514560699463
# Running combination 22/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.1833088397979736
# Final Validation Loss: 2.1979970932006836
# Running combination 23/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 7.4715962409973145
# Final Validation Loss: 6.858918190002441
# Running combination 24/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.203373432159424
# Final Validation Loss: 3.3583498001098633
# Running combination 25/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 14.938125610351562
# Final Validation Loss: 14.737594604492188
# Running combination 26/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 2.488090991973877
# Final Validation Loss: 1.9993748664855957
# Running combination 27/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.735687255859375
# Final Validation Loss: 1.593536138534546
# Running combination 28/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.0944255590438843
# Final Validation Loss: 1.6043510437011719
# Running combination 29/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.1262764930725098
# Final Validation Loss: 1.7611863613128662
# Running combination 30/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 6.281000137329102
# Final Validation Loss: 6.1629228591918945
# Top results:
# {'params': {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.2019776105880737, 'final_val_loss': 1.4918084144592285}
# {'params': {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.735687255859375, 'final_val_loss': 1.593536138534546}
# {'params': {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 1.0944255590438843, 'final_val_loss': 1.6043510437011719}
# {'params': {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}, 'final_train_loss': 1.7051609754562378, 'final_val_loss': 1.6078088283538818}
# {'params': {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}, 'final_train_loss': 1.7099303007125854, 'final_val_loss': 1.6403313875198364}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 11s 184ms/step - loss: 3.1909 - val_loss: 1.6266
# Epoch 2/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 2.7980 - val_loss: 1.6025
# Epoch 3/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 2.3747 - val_loss: 1.6063
# Epoch 4/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 2.1621 - val_loss: 1.6113
# Epoch 5/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 2.1667 - val_loss: 1.5911
# Epoch 6/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 2.0251 - val_loss: 1.6050
# Epoch 7/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 2.0962 - val_loss: 1.5984
# Epoch 8/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.8677 - val_loss: 1.6024
# Epoch 9/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 126ms/step - loss: 1.8672 - val_loss: 1.5889
# Epoch 10/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.6251 - val_loss: 1.6086
# Epoch 11/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 134ms/step - loss: 1.7378 - val_loss: 1.5907
# Epoch 12/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.5539 - val_loss: 1.5950
# Epoch 13/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.6187 - val_loss: 1.6049
# Epoch 14/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 136ms/step - loss: 1.5603 - val_loss: 1.6279
# Epoch 15/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 1.6077 - val_loss: 1.6791
# Epoch 16/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 133ms/step - loss: 1.6078 - val_loss: 1.5887
# Epoch 17/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 140ms/step - loss: 1.4876 - val_loss: 1.6058
# Epoch 18/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.5247 - val_loss: 1.5537
# Epoch 19/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 120ms/step - loss: 1.6192 - val_loss: 1.5846
# Epoch 20/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 129ms/step - loss: 1.4541 - val_loss: 1.6163
# Epoch 21/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 135ms/step - loss: 1.3779 - val_loss: 1.5570
# Epoch 22/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 1.4255 - val_loss: 1.5437
# Epoch 23/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 1.4213 - val_loss: 1.5610
# Epoch 24/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 1.3547 - val_loss: 1.5909
# Epoch 25/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.3788 - val_loss: 1.5615
# Epoch 26/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 1.4058 - val_loss: 1.5524
# Epoch 27/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 128ms/step - loss: 1.3544 - val_loss: 1.6042
# Epoch 28/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 125ms/step - loss: 1.3137 - val_loss: 1.5580
# Epoch 29/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 121ms/step - loss: 1.3236 - val_loss: 1.5717
# Epoch 30/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 132ms/step - loss: 1.1672 - val_loss: 1.5788
# Epoch 31/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 132ms/step - loss: 1.2967 - val_loss: 1.6463
# Epoch 32/200
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 2s 130ms/step - loss: 1.2271 - val_loss: 1.6273
# Final Training Loss: 1.2516448497772217
# Final Validation Loss: 1.627251386642456

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# LSTM Model Performance:
# Training RMSE: 0.020429780171916382
# Test RMSE: 0.025069797837061127
# Training MAE: 0.015164817767655688
# Test MAE: 0.01938799695281954
# Directional Accuracy on Training Data: 61.482381530984206%
# Directional Accuracy on Test Data: 59.80392156862745%

# %% [markdown]
# ### Three Layers (Model 2)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],
    'recurrent_dropout': [0.1, 0.2],
    'l2_lambda': [0.001, 0.01, 0.1],
    'learning_rate': [0.001, 0.0005, 0.0001],
    'learning_rate_decay': [1e-6, 1e-5, 0],
    'units1': [32, 64, 128],
    'units2': [32, 64, 128],
    'units3': [32, 64, 128],
    'batch_size': [32, 64, 120, 256],  
    'epochs': [50, 100, 200],
    'optimizer': ['adam'],
    'clipnorm': [1.0, 5.0]
}

# Generate a list of random combinations with ParameterSampler
n_iter_search = 30
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42))

# Define the function to build the model with variable parameters
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, units3, optimizer_name, loss_function):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units2, return_sequences=True, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=units3, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer.
    model.add(Dense(1))
    
    # Select optimizer with decay and clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    return model

# Define early stopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to keep track of results
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        units3=params['units3'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.0537693500518799
# Final Validation Loss: 1.5788577795028687
# Running combination 2/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 4.270679950714111
# Final Validation Loss: 4.273068428039551
# Running combination 3/30: {'units3': 128, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 2.810617446899414
# Final Validation Loss: 1.8536036014556885
# Running combination 4/30: {'units3': 128, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 8.657731056213379
# Final Validation Loss: 8.205729484558105
# Running combination 5/30: {'units3': 64, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 4.341814994812012
# Final Validation Loss: 4.404841423034668
# Running combination 6/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.439628839492798
# Final Validation Loss: 1.699810266494751
# Running combination 7/30: {'units3': 32, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.9046592712402344
# Final Validation Loss: 3.0257654190063477
# Running combination 8/30: {'units3': 32, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.615027904510498
# Final Validation Loss: 3.7948646545410156
# Running combination 9/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.6869592666625977
# Final Validation Loss: 1.8093658685684204
# Running combination 10/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 2.519881010055542
# Final Validation Loss: 1.6297146081924438
# Running combination 11/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.6166305541992188
# Final Validation Loss: 2.0366618633270264
# Running combination 12/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 18.169696807861328
# Final Validation Loss: 17.727420806884766
# Running combination 13/30: {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.6237534284591675
# Final Validation Loss: 1.7494831085205078
# Running combination 14/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.4318310022354126
# Final Validation Loss: 1.8040692806243896
# Running combination 15/30: {'units3': 128, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 3.900239944458008
# Final Validation Loss: 3.4907240867614746
# Running combination 16/30: {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.0986580848693848
# Final Validation Loss: 3.1560416221618652
# Running combination 17/30: {'units3': 128, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 15.978487014770508
# Final Validation Loss: 15.76058292388916
# Running combination 18/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.700014352798462
# Final Validation Loss: 1.8230865001678467
# Running combination 19/30: {'units3': 128, 'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.087512493133545
# Final Validation Loss: 4.6361284255981445
# Running combination 20/30: {'units3': 64, 'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.5109710693359375
# Final Validation Loss: 3.1226563453674316
# Running combination 21/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.7881722450256348
# Final Validation Loss: 3.31266450881958
# Running combination 22/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 33.298606872558594
# Final Validation Loss: 31.704444885253906
# Running combination 23/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 18.529232025146484
# Final Validation Loss: 17.101139068603516
# Running combination 24/30: {'units3': 64, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 38.19190216064453
# Final Validation Loss: 37.686100006103516
# Running combination 25/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 12.49333667755127
# Final Validation Loss: 12.228593826293945
# Running combination 26/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 4.019441604614258
# Final Validation Loss: 3.5292234420776367
# Running combination 27/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.5678839683532715
# Final Validation Loss: 4.313586711883545
# Running combination 28/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.136901378631592
# Final Validation Loss: 3.076019048690796
# Running combination 29/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 11.743561744689941
# Final Validation Loss: 11.332521438598633
# Running combination 30/30: {'units3': 128, 'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 5.305420875549316
# Final Validation Loss: 4.137351989746094
# Top results:
# {'params': {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}, 'final_train_loss': 1.0537693500518799, 'final_val_loss': 1.5788577795028687}
# {'params': {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 2.519881010055542, 'final_val_loss': 1.6297146081924438}
# {'params': {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.439628839492798, 'final_val_loss': 1.699810266494751}
# {'params': {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 1.6237534284591675, 'final_val_loss': 1.7494831085205078}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}, 'final_train_loss': 1.4318310022354126, 'final_val_loss': 1.8040692806243896}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'units3': 128,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 17s 311ms/step - loss: 3.2362 - val_loss: 1.7845
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 4s 235ms/step - loss: 2.4524 - val_loss: 1.7658
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 243ms/step - loss: 2.3933 - val_loss: 1.7533
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 221ms/step - loss: 1.9966 - val_loss: 1.7824
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 228ms/step - loss: 2.1754 - val_loss: 1.7462
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - loss: 1.9346 - val_loss: 1.7610
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 230ms/step - loss: 1.8172 - val_loss: 1.7739
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - loss: 1.7901 - val_loss: 1.7441
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - loss: 1.8391 - val_loss: 1.7229
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - loss: 1.7131 - val_loss: 1.7738
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - loss: 1.7383 - val_loss: 1.7482
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 229ms/step - loss: 1.8245 - val_loss: 1.7535
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 232ms/step - loss: 1.6105 - val_loss: 1.7722
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 235ms/step - loss: 1.5243 - val_loss: 1.8002
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - loss: 1.5762 - val_loss: 1.7443
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - loss: 1.6363 - val_loss: 1.8186
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 242ms/step - loss: 1.6382 - val_loss: 1.8246
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 234ms/step - loss: 1.4731 - val_loss: 1.7566
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 244ms/step - loss: 1.5568 - val_loss: 1.7505
# Final Training Loss: 1.5780762434005737
# Final Validation Loss: 1.7505383491516113

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 86ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# LSTM Model Performance:
# Training RMSE: 0.020624962516487516
# Test RMSE: 0.025770019709508155
# Training MAE: 0.014903610394360875
# Test MAE: 0.02021249324008041
# Directional Accuracy on Training Data: 52.61239368165249%
# Directional Accuracy on Test Data: 53.92156862745098%

# %% [markdown]
# ### 2. Optuna (Model 3)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.
    
    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-12 11:59:14,450] A new study created in memory with name: no-name-d6379542-7a33-4b89-ae83-580bfd6f208c
# [I 2024-11-12 11:59:23,255] Trial 0 finished with value: 1.865431547164917 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.865431547164917.
# [I 2024-11-12 11:59:34,241] Trial 1 finished with value: 4.173610210418701 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.865431547164917.
# [I 2024-11-12 12:00:35,370] Trial 2 finished with value: 5.049676895141602 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.865431547164917.
# [I 2024-11-12 12:01:00,239] Trial 3 finished with value: 2.1329047679901123 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.865431547164917.
# [I 2024-11-12 12:01:08,632] Trial 4 finished with value: 1.674993634223938 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 4 with value: 1.674993634223938.
# [I 2024-11-12 12:01:48,898] Trial 5 finished with value: 1.8671469688415527 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06621901977279396, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 256}. Best is trial 4 with value: 1.674993634223938.
# [I 2024-11-12 12:02:39,629] Trial 6 finished with value: 3.1943225860595703 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0038300508438275606, 'learning_rate': 0.0001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 3, 'epochs': 50, 'batch_size': 256}. Best is trial 4 with value: 1.674993634223938.
# [I 2024-11-12 12:02:48,543] Trial 7 finished with value: 1.4324874877929688 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.4324874877929688.
# [I 2024-11-12 12:02:58,964] Trial 8 finished with value: 2.0077767372131348 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0017384974140603195, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 1.4324874877929688.
# [I 2024-11-12 12:03:11,413] Trial 9 finished with value: 1.7220938205718994 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.028980866560207673, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 7 with value: 1.4324874877929688.
# [I 2024-11-12 12:03:24,395] Trial 10 finished with value: 1.4158042669296265 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010012325682668814, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:03:32,479] Trial 11 finished with value: 1.4237568378448486 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011454828358668492, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:03:42,389] Trial 12 finished with value: 1.4305897951126099 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011554791595316783, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:03:54,558] Trial 13 finished with value: 1.4407804012298584 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008097857902138784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:04:26,524] Trial 14 finished with value: 1.579376220703125 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001049410437362456, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:04:32,962] Trial 15 finished with value: 1.441379427909851 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.003502431872516879, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 32}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:04:45,332] Trial 16 finished with value: 1.8051848411560059 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.009118985456676882, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:04:57,099] Trial 17 finished with value: 1.4298474788665771 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.002085993900111682, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:05:05,685] Trial 18 finished with value: 1.4535903930664062 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.005040684715226819, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:05:26,184] Trial 19 finished with value: 1.955100655555725 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.021365105049329695, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 150, 'batch_size': 32}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:06:13,175] Trial 20 finished with value: 1.6827003955841064 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.016427446091396673, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:06:19,496] Trial 21 finished with value: 1.4378172159194946 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001916436471842951, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:06:24,987] Trial 22 finished with value: 1.437157392501831 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0015394277020084359, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:06:31,198] Trial 23 finished with value: 1.4415879249572754 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026560892744139633, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 50, 'batch_size': 64}. Best is trial 10 with value: 1.4158042669296265.
# [I 2024-11-12 12:06:42,608] Trial 24 finished with value: 1.409308671951294 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010171855559193877, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 24 with value: 1.409308671951294.
# [I 2024-11-12 12:06:50,627] Trial 25 finished with value: 1.438157320022583 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001047148538910998, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 24 with value: 1.409308671951294.
# [I 2024-11-12 12:07:00,996] Trial 26 finished with value: 1.4526830911636353 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0060731748002025385, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 24 with value: 1.409308671951294.
# [I 2024-11-12 12:07:12,689] Trial 27 finished with value: 1.705185890197754 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0013741746881028485, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 50, 'batch_size': 32}. Best is trial 24 with value: 1.409308671951294.
# [I 2024-11-12 12:07:16,001] Trial 28 finished with value: 1.6264092922210693 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0025132531071661948, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}. Best is trial 24 with value: 1.409308671951294.
# [I 2024-11-12 12:07:34,480] Trial 29 finished with value: 1.9550223350524902 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0030420102604423256, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 24 with value: 1.409308671951294.
# Best hyperparameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010171855559193877, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}
# Best validation loss: 1.409308671951294

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0010171855559193877,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Select the loss function based on tuning results.
    if params['loss_function'] == 'huber_loss':
        loss = Huber()  # Huber loss is more robust to outliers
    else:
        loss = MeanSquaredError()  # Use MSE as default loss function for regression
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 6s 81ms/step - loss: 1.9887 - val_loss: 1.4403
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - loss: 1.6756 - val_loss: 1.4401
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.9348 - val_loss: 1.4537
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.3666 - val_loss: 1.4346
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 65ms/step - loss: 1.3473 - val_loss: 1.4492
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.3998 - val_loss: 1.4355
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.2918 - val_loss: 1.4357
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 77ms/step - loss: 1.2615 - val_loss: 1.4399
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.2845 - val_loss: 1.4418
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.2594 - val_loss: 1.4364
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 66ms/step - loss: 1.2983 - val_loss: 1.4497
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.2277 - val_loss: 1.4449
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - loss: 1.1164 - val_loss: 1.4407
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 1.1451 - val_loss: 1.4428
# Final Training Loss: 1.1853878498077393
# Final Validation Loss: 1.4427810907363892

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# LSTM Model Performance:
# Training RMSE: 0.02056920173651604
# Test RMSE: 0.025666255766009654
# Training MAE: 0.014946540576591604
# Test MAE: 0.020163378673659513
# Directional Accuracy on Training Data: 59.41676792223573%
# Directional Accuracy on Test Data: 60.78431372549019%

# %% [markdown]
# ### 3. Keras Tuner (Model 4)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.

    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 12s]
# val_loss: 1.4193192720413208
#
# Best val_loss So Far: 1.4193192720413208
# Total elapsed time: 00h 17m 43s
# Built model with params: dropout_rate=0.4, recurrent_dropout=0.1, l2_lambda=0.0026041400819170504, learning_rate=0.001, learning_rate_decay=0.0, clipnorm=1.0, units=128, num_layers=1, batch_size=256
# Best hyperparameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026041400819170504, 'learning_rate': 0.001, 'learning_rate_decay': 0.0, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'batch_size': 256}
# Best batch size: 256

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0026041400819170504,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 256
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 6s 374ms/step - loss: 3.2269 - val_loss: 1.6458
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 3.1412 - val_loss: 1.6261
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 236ms/step - loss: 2.4844 - val_loss: 1.6338
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - loss: 2.3072 - val_loss: 1.6348
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 233ms/step - loss: 2.3157 - val_loss: 1.6304
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 2.3536 - val_loss: 1.6259
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 227ms/step - loss: 2.0618 - val_loss: 1.6293
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 232ms/step - loss: 2.0086 - val_loss: 1.6265
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 2.1821 - val_loss: 1.6323
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 252ms/step - loss: 1.8754 - val_loss: 1.6364
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - loss: 2.1018 - val_loss: 1.6373
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 1.9244 - val_loss: 1.6308
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 235ms/step - loss: 1.7706 - val_loss: 1.6256
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 1.9209 - val_loss: 1.6348
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step - loss: 1.8426 - val_loss: 1.6424
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step - loss: 1.8864 - val_loss: 1.6351
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 240ms/step - loss: 1.8397 - val_loss: 1.6333
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 234ms/step - loss: 1.8472 - val_loss: 1.6354
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step - loss: 1.7382 - val_loss: 1.6384
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 243ms/step - loss: 1.6053 - val_loss: 1.6334
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 245ms/step - loss: 1.6935 - val_loss: 1.6327
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 230ms/step - loss: 1.6130 - val_loss: 1.6412
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 189ms/step - loss: 1.6463 - val_loss: 1.6429
# Final Training Loss: 1.6032986640930176
# Final Validation Loss: 1.6429017782211304

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# LSTM Model Performance:
# Training RMSE: 0.02057050495959062
# Test RMSE: 0.025580470942135083
# Training MAE: 0.014940840090374925
# Test MAE: 0.02002691173210288
# Directional Accuracy on Training Data: 63.06196840826246%
# Directional Accuracy on Test Data: 64.70588235294117%

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 52
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.02042978    | 0.020624963   | 0.020569202   | 0.020570505   |
# | **Test RMSE**  | 0.025069798   | 0.02577002    | 0.025666256   | 0.025580471   |
# | **Train MAE**  | 0.015164818   | 0.01490361    | 0.014946541   | 0.01494084    |
# | **Test MAE**   | 0.019387997   | 0.020212493   | 0.020163379   | 0.020026912   |
# | **Train Loss** | 1.25164485    | 1.578076243   | 1.18538785    | 1.603298783   |
# | **Val Loss**   | 1.627251387   | 1.750538349   | 1.442781091   | 1.642901778   |
# | **Train DA**   | 61%           | 53%           | 59%           | 63%           |
# | **Test DA**    | 60%           | 54%           | 61%           | 65%           |
#
# - Model 1 presents the lowest RMSE metrics, however looking at the convergence plot, it shows that overfits after 18, 19 epochs.
# - Model 2 have the highest RMSE metrics and its val and train loss plot shows that overfits after 12 eopchs.
# - Model 3 has better metrics than model 2.
# - Model 4 presents metrics that better than model 2 and 3, but also the convergence plot shows that after 20 epochs the val and train loss stabilizes.
#
# **Thus, the best performer for sequence length of 52 is Model 4**.

# %%
# Extract scaled train and validation loss from history
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Retrieve the center (median) and scale (IQR) from the RobustScaler
center = scaler_y.center_[0]  # Median used by the RobustScaler
scale = scaler_y.scale_[0]    # IQR used by the RobustScaler

# Descale the train and validation losses
descaled_train_loss = scaled_train_loss * scale + center
descaled_val_loss = scaled_val_loss * scale + center

# Print the descaled losses
print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.0360717693306339
# Descaled Validation Loss: 0.0368726086351914

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0026041400819170504,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 256
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Fold 1 RMSE: 1.4982000845943906
# Fold 2
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step
# Fold 2 RMSE: 0.772304867627562
# Fold 3
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 3 RMSE: 0.7595531027582859
# Fold 4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# Fold 4 RMSE: 1.193235070482095
# Average RMSE from TSCV: 1.0558232813655835

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 53    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Rolling window RMSE: 0.47106680010817564
# Rolling window starting at index 53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step
# Rolling window RMSE: 0.42985293940284136
# Rolling window starting at index 106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# Rolling window RMSE: 0.07850797056797837
# Rolling window starting at index 159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 127ms/step
# Rolling window RMSE: 0.3375756026767223
# Rolling window starting at index 212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step
# Rolling window RMSE: 0.9681510356447411
# Rolling window starting at index 265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# Rolling window RMSE: 0.8996598665957319
# Rolling window starting at index 318
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Rolling window RMSE: 0.12398350407292341
# Rolling window starting at index 371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# Rolling window RMSE: 0.1359857155936818
# Rolling window starting at index 424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 125ms/step
# Rolling window RMSE: 0.3064119415106834
# Rolling window starting at index 477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 122ms/step
# Rolling window RMSE: 3.707803276788458
# Average Rolling Window RMSE: 0.7458998652961937

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.0319088787075724, 0.02286430461474302, 0.018960418253846235, 0.026697914336961878]
# Descaled FRWCV RMSE Values: [0.02395808923456905, 0.034648941284104055, 0.02324872814665539, 0.01967529837738145, 0.019861983113142127, 0.02392613721125306, 0.015897965917969534, 0.012078728529785629, 0.019893544107160634, 0.01632277733655528, 0.038015028686979174]
# Average Descaled TSCV RMSE: 0.025107878978280884
# Average Descaled FRWCV RMSE: 0.02250247472232322

# %% [markdown]
# ## Evaluation
#
# ### LSTM - Robust Scaling Performance Metrics
#
# | Metrics        | SL = 4         | SL = 12         | SL = 26         | SL = 52         |
# |-----------------|----------------|-----------------|-----------------|-----------------|
# | **Train RMSE** | 0.020148595    | 0.020067693     | 0.020490902     | 0.020570505     |
# | **Test RMSE**  | 0.022906913    | 0.023216819     | 0.024202666     | 0.025580471     |
# | **Train MAE**  | 0.014546276    | 0.014603503     | 0.014824706     | 0.01494084      |
# | **Test MAE**   | 0.017450262    | 0.017491914     | 0.018446662     | 0.020026912     |
# | **Train Loss** | 1.105406404    | 1.11063993      | 1.176821947     | 1.603298783     |
# | **Val Loss**   | 1.088732004    | 1.111617565     | 0.985168517     | 1.642901778     |
# | **Avg RMSE - TSCV** | 1.072480028 | 1.070069473     | 1.063599337     | 1.055823281     |
# | **Avg RMSE - FRWCV** | 0.946568711 | 0.971241312     | 0.934724649     | 0.745899865     |
# | **Train DA**   | 60%            | 60%             | 64%             | 63.00%          |
# | **Test DA**    | 61%            | 57%             | 65%             | 65.00%          |
#
# ---
#
# # TSCV RMSE Comparison
#
# | Sequence Length (SL) | Fold 1 RMSE | Fold 2 RMSE | Fold 3 RMSE | Fold 4 RMSE | Average TSCV RMSE | Training Loss | Validation Loss |
# |-----------------------|-------------|-------------|-------------|-------------|-------------------|---------------|-----------------|
# | SL = 4               | 0.032112633 | 0.022744272 | 0.019453709 | 0.026563517 | **0.025218533**   | 0.026003579   | 0.025666396     |
# | SL = 12              | 0.032184849 | 0.022633941 | 0.019909695 | 0.026427550 | **0.025289009**   | 0.026109409   | 0.026129179     |
# | SL = 26              | 0.031908879 | 0.022864305 | 0.018960418 | 0.026697914 | **0.025107879**   | 0.027447717   | 0.023572174     |
# | SL = 52              | 0.031908879 | 0.022864305 | 0.018960418 | 0.026697914 | **0.025107879**   | 0.036071769   | 0.036872609     |
#
# ---
#
# # FRWCV RMSE Comparison
#
# | Sequence Length (SL) | Window 1 RMSE | Window 2 RMSE | Window 3 RMSE | Window 4 RMSE | Window 5 RMSE | Window 6 RMSE | Window 7 RMSE | Window 8 RMSE | Window 9 RMSE | Window 10 RMSE | Window 11 RMSE | Average FRWCV RMSE |
# |-----------------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|----------------|-----------------|---------------------|
# | SL = 4               | 0.029579919   | 0.029043130   | 0.021579618   | 0.019105728   | 0.019240116   | 0.021713117   | 0.020631109   | 0.013920399   | 0.019288126   | 0.024575558    | 0.030648053     | **0.022665897**     |
# | SL = 12              | 0.029790671   | 0.031679682   | 0.022457466   | 0.018450368   | 0.020376000   | 0.022079021   | 0.022503946   | 0.012782433   | 0.020295254   | 0.022614912    | 0.033166219     | **0.023290543**     |
# | SL = 26              | 0.023958089   | 0.034648941   | 0.023248728   | 0.019675298   | 0.019861983   | 0.023926137   | 0.015897966   | 0.012078729   | 0.019893544   | 0.016322777    | 0.038015029     | **0.022502475**     |
#
# ---
#
# ### Best Model: SL = 4.
#
# Using the 4 timesteps to forecast, the model presented the most balanced performance between accuracy metrics and its cross-validation scores. It has the lowest RMSE and MAE test. In addition the values of the Average RMSE of both CV's have similar performance compare to th second best model (SL = 12).
# The convergence between the training and validation loss are satisfatory and no visual detection of under/overfitting.
# In addition, both cross validation shows that the models performed similary to each other, struggling to predict at the first and at the end of either folds or windows.
