# %%
# Importing the necessary libraries for the project. 
import pandas as pd 
import yfinance as yf
import numpy as np # for numerical operations
import seaborn as sns #visualisation
import matplotlib.pyplot as plt # visualization
# %matplotlib inline 
import matplotlib.ticker as ticker # Library to customize ticks
from datetime import date
import matplotlib.dates as mdates
from scipy import stats
import statsmodels.api as sm
from sklearn.preprocessing import MinMaxScaler, RobustScaler, StandardScaler
from math import sqrt
# Mean Squared Error and Mean Absolute Error metrics from sklearn for evaluating model accuracy.
from tensorflow.keras.losses import MeanAbsoluteError, MeanSquaredError
from sklearn.metrics import mean_squared_error, mean_absolute_error
# TimeSeriesSplit for cross-validation with time series data to preserve the temporal ordering of data.
from sklearn.model_selection import TimeSeriesSplit
import tensorflow as tf
from tensorflow.keras.models import Sequential
from keras.regularizers import l2
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.model_selection import ParameterSampler
from tensorflow.keras.optimizers import Adam
from keras.layers import BatchNormalization, Dropout, Dense, LSTM
import random
import optuna
from optuna.samplers import TPESampler
from keras_tuner import BayesianOptimization

import warnings # filter warnings
warnings.filterwarnings('ignore')

# %%
# Importing the dataset after the Log Returns transformation.
df1 = pd.read_csv('df1.csv', index_col=0, parse_dates=True)

# Along with the importation, the code will set the date as the index, value of 0 because is the first column.
## Setting parse_dates=true to ensure the dates are in datetime, making more appropriate for ML models.

# %%
df1.describe()
# Out:
#              Close        lag_1        lag_4  rolling_mean_4w  \
# count  1031.000000  1031.000000  1031.000000      1031.000000
# mean      0.001575     0.001608     0.001508         0.001578
# std       0.020723     0.020744     0.020750         0.009796
# min      -0.069935    -0.069935    -0.069935        -0.051352
# 25%      -0.007633    -0.007633    -0.007858        -0.003032
# 50%       0.003635     0.003666     0.003626         0.002937
# 75%       0.013568     0.013643     0.013514         0.007596
# max       0.051947     0.051947     0.051947         0.031089
#
#        rolling_mean_12w  volatility_4w
# count       1031.000000    1031.000000
# mean           0.001516       7.731465
# std            0.005364      23.505939
# min           -0.026288       0.154122
# 25%           -0.001013       1.538535
# 50%            0.002346       2.585030
# 75%            0.004979       6.157669
# max            0.019145     338.128664

# %%
# Define the selected exogenous variables and target variable.
features = df1[['rolling_mean_4w', 'rolling_mean_12w', 'volatility_4w', 'lag_1', 'lag_4']]
target = df1['Close']

# %%
# Split data into training and testing sets, same ratio applied in SARIMAX.
train_size = int(0.85 * len(features))
X_train, X_test = features[:train_size], features[train_size:]
y_train, y_test = target[:train_size], target[train_size:]

# Initialize and fit StandardScalers to scale data using Z-score normalization.
scaler_X = StandardScaler()
scaler_y = StandardScaler()

# Fit scalers on training data and transform both training and test data.
X_train_scaled = scaler_X.fit_transform(X_train)  # Fit scaler on training features and transform.
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))  # Fit scaler on training target and transform.

# Transform test data without fitting again to avoid data leakage.
X_test_scaled = scaler_X.transform(X_test)  # Transform test features using the scaler fitted on training data.
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))  # Transform test target using the scaler fitted on training data.

# Print minimum and maximum values of the scaled training and test data for verification.
print("Scaled Training Features - Min:", X_train_scaled.min(), "Max:", X_train_scaled.max())
print("Scaled Training Target - Min:", y_train_scaled.min(), "Max:", y_train_scaled.max())
print("Scaled Test Features - Min:", X_test_scaled.min(), "Max:", X_test_scaled.max())
print("Scaled Test Target - Min:", y_test_scaled.min(), "Max:", y_test_scaled.max())
# Out:
# Scaled Training Features - Min: -5.4955652189278625 Max: 9.795796286704956
# Scaled Training Target - Min: -3.526234546763028 Max: 2.4845799166596207
# Scaled Test Features - Min: -3.5237835824322223 Max: 29.172000533821247
# Scaled Test Target - Min: -3.526234546763028 Max: 2.4845799166596207

# %% [markdown]
# ## Sequence Length = 4

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 4  # Number of time steps used for target prediction, 4 weeks.

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (872, 4, 5)
# Reshaped y_train_seq shape: (872, 1)
# Reshaped X_test_seq shape: (151, 4, 5)
# Reshaped  y_test_seq shape: (151, 1)

# %% [markdown]
# ### Random Parameters. (Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define hyperparameters
dropout_rate = 0.3          # Dropout rate to help prevent overfitting by randomly dropping nodes during training.
l2_lambda = 0.01            # L2 regularization factor, penalizes large weights and attempt to prevent overfitting.
learning_rate = 0.0002      # Learning rate for the optimizer to control how much to adjust weights during backpropagation.
epochs = 50                 # Maximum number of training epochs.
batch_size = 128            # Batch size for each training step, determines how many samples are used in each gradient update.

# Initialize the LSTM model.
model = Sequential()

# First LSTM layer with L2 regularization and dropout.
model.add(LSTM(units=64,                    # Number of LSTM units (neurons) in the layer.
               return_sequences=True,       # Ensures that the layer returns the entire sequence for the next LSTM layer.
               input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape: (sequence length, number of features).
               kernel_regularizer=l2(l2_lambda)))  # Applies L2 regularization to reduce overfitting.
model.add(Dropout(dropout_rate))            # Adds dropout layer to reduce overfitting by randomly setting some neurons to 0.

# Second LSTM layer with L2 regularization and dropout.
model.add(LSTM(units=64,                    # Number of LSTM units in the second layer.
               return_sequences=False,      # Last LSTM layer should not return sequences; it outputs only the final state.
               kernel_regularizer=l2(l2_lambda)))  # L2 regularization to prevent overfitting.
model.add(Dropout(dropout_rate))            # Dropout for regularization.

# Output layer
model.add(Dense(1))                         # Dense layer with a single unit, since its predicting a single value (regression).

# Compile the model
model.compile(optimizer=Adam(learning_rate=learning_rate),  # Adam optimizer with a specified learning rate.
              loss='mean_squared_error')                    # Mean Squared Error (MSE) as the loss function for regression.

# Set up early stopping
early_stopping = EarlyStopping(monitor='val_loss',          # Monitor validation loss to stop if it stops improving.
                               patience=10,                 # Wait for 10 epochs with no improvement before stopping.
                               restore_best_weights=True)   # Restore model weights from the epoch with the lowest validation loss.

# Train the model
history = model.fit(X_train_seq, y_train_seq,               # Training data (features and target).
                    epochs=epochs,                          # Maximum number of epochs.
                    batch_size=batch_size,                  # Batch size.
                    validation_data=(X_test_seq, y_test_seq),  # Validation data to monitor overfitting.
                    callbacks=[early_stopping],             # Callback for early stopping. 
                    shuffle=False,
                    verbose=1)                              # Verbose output for progress during training.

# Print final training and validation loss values.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 7s 120ms/step - loss: 2.0812 - val_loss: 2.1753
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 2.0504 - val_loss: 2.1441
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 2.0264 - val_loss: 2.1133
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9954 - val_loss: 2.0839
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.9676 - val_loss: 2.0555
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.9344 - val_loss: 2.0277
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.9054 - val_loss: 2.0009
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.8793 - val_loss: 1.9751
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.8576 - val_loss: 1.9500
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.8300 - val_loss: 1.9259
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.8045 - val_loss: 1.9022
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.7882 - val_loss: 1.8792
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.7664 - val_loss: 1.8568
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.7403 - val_loss: 1.8349
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.7190 - val_loss: 1.8137
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.7007 - val_loss: 1.7932
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.6765 - val_loss: 1.7735
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.6579 - val_loss: 1.7541
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.6381 - val_loss: 1.7353
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.6178 - val_loss: 1.7169
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5989 - val_loss: 1.6990
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.5840 - val_loss: 1.6817
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.5664 - val_loss: 1.6647
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5456 - val_loss: 1.6482
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5314 - val_loss: 1.6322
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.5170 - val_loss: 1.6166
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4968 - val_loss: 1.6015
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.4855 - val_loss: 1.5867
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4759 - val_loss: 1.5722
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4556 - val_loss: 1.5583
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.4455 - val_loss: 1.5448
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.4319 - val_loss: 1.5316
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.4152 - val_loss: 1.5187
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.4029 - val_loss: 1.5061
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3928 - val_loss: 1.4940
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3783 - val_loss: 1.4822
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 1.3716 - val_loss: 1.4706
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3560 - val_loss: 1.4593
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.3386 - val_loss: 1.4485
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.3297 - val_loss: 1.4378
# Epoch 41/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 1.3210 - val_loss: 1.4274
# Epoch 42/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.3124 - val_loss: 1.4173
# Epoch 43/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 1.3022 - val_loss: 1.4076
# Epoch 44/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2926 - val_loss: 1.3983
# Epoch 45/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2847 - val_loss: 1.3893
# Epoch 46/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2798 - val_loss: 1.3807
# Epoch 47/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 1.2641 - val_loss: 1.3724
# Epoch 48/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2550 - val_loss: 1.3642
# Epoch 49/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2511 - val_loss: 1.3560
# Epoch 50/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 1.2417 - val_loss: 1.3480
# Final Training Loss: 1.2757619619369507
# Final Validation Loss: 1.3479969501495361

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# LSTM Model Performance:
# Training RMSE: 0.020287423451894594
# Test RMSE: 0.023094093455977842
# Training MAE: 0.014687988017215093
# Test MAE: 0.01751759367668148
# Directional Accuracy on Training Data: 52.81285878300803%
# Directional Accuracy on Test Data: 56.666666666666664%

# %% [markdown]
# ### Model 2

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'units3': 64,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'huber_loss',
    'learning_rate_decay': 1e-6,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 150,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False,
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 14s 124ms/step - loss: 3.5201 - val_loss: 1.4710
# Epoch 2/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 2.2621 - val_loss: 1.4693
# Epoch 3/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 2.2747 - val_loss: 1.4705
# Epoch 4/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step - loss: 2.0766 - val_loss: 1.4693
# Epoch 5/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.9527 - val_loss: 1.4722
# Epoch 6/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.7489 - val_loss: 1.4685
# Epoch 7/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 1.7299 - val_loss: 1.4684
# Epoch 8/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 1.7223 - val_loss: 1.4653
# Epoch 9/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.6674 - val_loss: 1.4577
# Epoch 10/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.5854 - val_loss: 1.4552
# Epoch 11/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.4373 - val_loss: 1.4539
# Epoch 12/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.4871 - val_loss: 1.4492
# Epoch 13/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 1.3664 - val_loss: 1.4522
# Epoch 14/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - loss: 1.4189 - val_loss: 1.4448
# Epoch 15/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.3132 - val_loss: 1.4425
# Epoch 16/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 1.2719 - val_loss: 1.4361
# Epoch 17/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.2118 - val_loss: 1.4329
# Epoch 18/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.2504 - val_loss: 1.4436
# Epoch 19/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1934 - val_loss: 1.4199
# Epoch 20/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2389 - val_loss: 1.4244
# Epoch 21/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 1.2058 - val_loss: 1.4377
# Epoch 22/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 1.1505 - val_loss: 1.4310
# Epoch 23/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.1388 - val_loss: 1.4381
# Epoch 24/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 1.1082 - val_loss: 1.4419
# Epoch 25/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - loss: 1.1636 - val_loss: 1.4351
# Epoch 26/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 1.0977 - val_loss: 1.4569
# Epoch 27/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 1.1177 - val_loss: 1.4572
# Epoch 28/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0731 - val_loss: 1.4383
# Epoch 29/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.0191 - val_loss: 1.4204
# Final Training Loss: 1.070977807044983
# Final Validation Loss: 1.4204212427139282

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# LSTM Model Performance:
# Training RMSE: 0.0201052013947683
# Test RMSE: 0.022911279502954792
# Training MAE: 0.014736304543750413
# Test MAE: 0.017639764639251702
# Directional Accuracy on Training Data: 55.683122847301945%
# Directional Accuracy on Test Data: 51.33333333333333%

# %% [markdown]
# ### 1.Random Search

# %% [markdown]
# ### Two Layers (Model 3)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1


# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 14s 199ms/step - loss: 2.8816 - val_loss: 1.2623
# Epoch 2/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 2.1265 - val_loss: 1.2615
# Epoch 3/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 2.1041 - val_loss: 1.2608
# Epoch 4/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.7166 - val_loss: 1.2599
# Epoch 5/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.9041 - val_loss: 1.2604
# Epoch 6/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.6197 - val_loss: 1.2601
# Epoch 7/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.7041 - val_loss: 1.2595
# Epoch 8/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.6727 - val_loss: 1.2605
# Epoch 9/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.6655 - val_loss: 1.2619
# Epoch 10/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 1.6278 - val_loss: 1.2609
# Epoch 11/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.5656 - val_loss: 1.2630
# Epoch 12/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - loss: 1.5581 - val_loss: 1.2631
# Epoch 13/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.4947 - val_loss: 1.2599
# Epoch 14/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.5096 - val_loss: 1.2583
# Epoch 15/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4702 - val_loss: 1.2591
# Epoch 16/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.3730 - val_loss: 1.2606
# Epoch 17/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.4000 - val_loss: 1.2614
# Epoch 18/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.3116 - val_loss: 1.2608
# Epoch 19/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4132 - val_loss: 1.2622
# Epoch 20/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.2854 - val_loss: 1.2634
# Epoch 21/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4199 - val_loss: 1.2655
# Epoch 22/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.4218 - val_loss: 1.2593
# Epoch 23/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.3399 - val_loss: 1.2558
# Epoch 24/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.2278 - val_loss: 1.2597
# Epoch 25/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.2312 - val_loss: 1.2599
# Epoch 26/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.2066 - val_loss: 1.2595
# Epoch 27/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 1.2421 - val_loss: 1.2532
# Epoch 28/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2688 - val_loss: 1.2490
# Epoch 29/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.1861 - val_loss: 1.2587
# Epoch 30/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2682 - val_loss: 1.2595
# Epoch 31/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2348 - val_loss: 1.2533
# Epoch 32/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 1.1730 - val_loss: 1.2543
# Epoch 33/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.2701 - val_loss: 1.2565
# Epoch 34/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - loss: 1.1382 - val_loss: 1.2556
# Epoch 35/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.1649 - val_loss: 1.2493
# Epoch 36/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.0997 - val_loss: 1.2434
# Epoch 37/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 1.1710 - val_loss: 1.2465
# Epoch 38/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.1179 - val_loss: 1.2442
# Epoch 39/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.1414 - val_loss: 1.2445
# Epoch 40/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - loss: 1.0808 - val_loss: 1.2440
# Epoch 41/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - loss: 1.1011 - val_loss: 1.2437
# Epoch 42/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 1.1519 - val_loss: 1.2462
# Epoch 43/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.1004 - val_loss: 1.2419
# Epoch 44/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 1.0479 - val_loss: 1.2509
# Epoch 45/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.0174 - val_loss: 1.2630
# Epoch 46/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0550 - val_loss: 1.2573
# Epoch 47/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 1.0932 - val_loss: 1.2349
# Epoch 48/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.9635 - val_loss: 1.2344
# Epoch 49/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 1.0031 - val_loss: 1.2450
# Epoch 50/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.0758 - val_loss: 1.2535
# Epoch 51/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 1.0470 - val_loss: 1.2646
# Epoch 52/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 1.0137 - val_loss: 1.2773
# Epoch 53/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.9844 - val_loss: 1.2955
# Epoch 54/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - loss: 0.9897 - val_loss: 1.2867
# Epoch 55/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - loss: 1.0239 - val_loss: 1.2806
# Epoch 56/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - loss: 0.9897 - val_loss: 1.2924
# Epoch 57/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.9855 - val_loss: 1.3080
# Epoch 58/100
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - loss: 0.9527 - val_loss: 1.3219
# Final Training Loss: 0.9559860229492188
# Final Validation Loss: 1.3219329118728638

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# LSTM Model Performance:
# Training RMSE: 0.019353555449133083
# Test RMSE: 0.02264348179826494
# Training MAE: 0.013940608013415245
# Test MAE: 0.01749623625347844
# Directional Accuracy on Training Data: 59.127439724454646%
# Directional Accuracy on Test Data: 50.66666666666667%

# %% [markdown]
# ### 2. Optuna (Model 5)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.

    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    # Compile the model with mean squared error loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-13 15:00:59,669] A new study created in memory with name: no-name-794ed8ac-68d6-4dfe-9ed0-bda0cd9b71cf
# [I 2024-11-13 15:01:19,373] Trial 0 finished with value: 1.6123017072677612 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.6123017072677612.
# [I 2024-11-13 15:01:39,131] Trial 1 finished with value: 3.799720525741577 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.6123017072677612.
# [I 2024-11-13 15:02:36,053] Trial 2 finished with value: 4.23798942565918 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.6123017072677612.
# [I 2024-11-13 15:03:21,241] Trial 3 finished with value: 1.6275194883346558 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.6123017072677612.
# [I 2024-11-13 15:03:34,530] Trial 4 finished with value: 1.41196870803833 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 4 with value: 1
ters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.2, 'l2_lambda': 0.002683355490924503, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}
# Best validation loss: 1.081648588180542

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.002683355490924503,
    'epochs': 150,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq),
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 41s 355ms/step - loss: 2.0148 - val_loss: 1.0927
# Epoch 2/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4630 - val_loss: 1.0869
# Epoch 3/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.4302 - val_loss: 1.0870
# Epoch 4/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4546 - val_loss: 1.0881
# Epoch 5/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.2339 - val_loss: 1.0892
# Epoch 6/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.3296 - val_loss: 1.0874
# Epoch 7/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.3421 - val_loss: 1.0867
# Epoch 8/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.1348 - val_loss: 1.0867
# Epoch 9/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - loss: 1.1518 - val_loss: 1.0870
# Epoch 10/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1346 - val_loss: 1.0864
# Epoch 11/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1753 - val_loss: 1.0857
# Epoch 12/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - loss: 1.2015 - val_loss: 1.0860
# Epoch 13/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - loss: 1.2249 - val_loss: 1.0871
# Epoch 14/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1436 - val_loss: 1.0881
# Epoch 15/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.1724 - val_loss: 1.0881
# Epoch 16/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.1446 - val_loss: 1.0884
# Epoch 17/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.1260 - val_loss: 1.0873
# Epoch 18/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2136 - val_loss: 1.0868
# Epoch 19/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0541 - val_loss: 1.0879
# Epoch 20/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0508 - val_loss: 1.0885
# Epoch 21/150
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 1.1081 - val_loss: 1.0893
# Final Training Loss: 1.1712450981140137
# Final Validation Loss: 1.0893398523330688

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 61ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# LSTM Model Performance:
# Training RMSE: 0.020256658930624106
# Test RMSE: 0.02298512515860481
# Training MAE: 0.014630590368077874
# Test MAE: 0.017508579027366036
# Directional Accuracy on Training Data: 57.97933409873708%
# Directional Accuracy on Test Data: 53.333333333333336%

# %% [markdown]
# ### 3. Keras Tuner (Model 6)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.


    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 50s]
# val_loss: 1.2762640714645386
#
# Best val_loss So Far: 1.2692660093307495
# Total elapsed time: 00h 22m 15s
# Built model with params: dropout_rate=0.2, recurrent_dropout=0.1, l2_lambda=0.0848820698329123, learning_rate=0.0005, learning_rate_decay=1e-05, clipnorm=1.0, units=32, num_layers=3, batch_size=32
# Best hyperparameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0848820698329123, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'batch_size': 32}
# Best batch size: 32

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.0848820698329123,
    'epochs': 200,
    'dropout_rate': 0.2,
    'clipnorm': 1.0,
    'batch_size': 32
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    callbacks=[early_stopping],
    shuffle=False
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 105s 289ms/step - loss: 12.7019 - val_loss: 10.1365
# Epoch 2/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 10.5374 - val_loss: 9.3764
# Epoch 3/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 9.5786 - val_loss: 8.6328
# Epoch 4/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 8.9777 - val_loss: 7.9604
# Epoch 5/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 8.0021 - val_loss: 7.3211
# Epoch 6/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 7.4342 - val_loss: 6.7383
# Epoch 7/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 6.7950 - val_loss: 6.1781
# Epoch 8/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 6.2136 - val_loss: 5.6997
# Epoch 9/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.6261 - val_loss: 5.2610
# Epoch 10/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 5.1551 - val_loss: 4.8563
# Epoch 11/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 4.9323 - val_loss: 4.5169
# Epoch 12/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 4.2812 - val_loss: 4.1764
# Epoch 13/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 4.0352 - val_loss: 3.9039
# Epoch 14/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7334 - val_loss: 3.6739
# Epoch 15/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.5654 - val_loss: 3.4664
# Epoch 16/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 3.3051 - val_loss: 3.2978
# Epoch 17/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 3.1498 - val_loss: 3.1373
# Epoch 18/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 2.9333 - val_loss: 3.0005
# Epoch 19/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 2.7906 - val_loss: 2.8643
# Epoch 20/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 2.6325 - val_loss: 2.7924
# Epoch 21/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 2.4668 - val_loss: 2.6358
# Epoch 22/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 2.4459 - val_loss: 2.5517
# Epoch 23/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 2.3343 - val_loss: 2.4796
# Epoch 24/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.1943 - val_loss: 2.3759
# Epoch 25/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 2.1644 - val_loss: 2.3010
# Epoch 26/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 2.0906 - val_loss: 2.2370
# Epoch 27/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.9346 - val_loss: 2.1887
# Epoch 28/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8932 - val_loss: 2.1313
# Epoch 29/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.8508 - val_loss: 2.0926
# Epoch 30/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.7879 - val_loss: 2.0477
# Epoch 31/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 1.7467 - val_loss: 2.0004
# Epoch 32/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.6951 - val_loss: 1.9485
# Epoch 33/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.6346 - val_loss: 1.9572
# Epoch 34/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.5637 - val_loss: 1.9028
# Epoch 35/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.5334 - val_loss: 1.8337
# Epoch 36/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.5194 - val_loss: 1.8123
# Epoch 37/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4612 - val_loss: 1.7797
# Epoch 38/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.4503 - val_loss: 1.7585
# Epoch 39/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 1.3697 - val_loss: 1.7140
# Epoch 40/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.4239 - val_loss: 1.6946
# Epoch 41/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.3293 - val_loss: 1.6724
# Epoch 42/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.3358 - val_loss: 1.6449
# Epoch 43/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2920 - val_loss: 1.6543
# Epoch 44/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 1.2430 - val_loss: 1.6277
# Epoch 45/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.2530 - val_loss: 1.5703
# Epoch 46/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.2280 - val_loss: 1.5691
# Epoch 47/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1637 - val_loss: 1.5557
# Epoch 48/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 1.2218 - val_loss: 1.5657
# Epoch 49/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1772 - val_loss: 1.5639
# Epoch 50/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.1241 - val_loss: 1.5317
# Epoch 51/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 1.1802 - val_loss: 1.4971
# Epoch 52/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 1.1220 - val_loss: 1.5028
# Epoch 53/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 1.1163 - val_loss: 1.4732
# Epoch 54/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 1.1255 - val_loss: 1.4657
# Epoch 55/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0691 - val_loss: 1.4511
# Epoch 56/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0917 - val_loss: 1.4555
# Epoch 57/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0788 - val_loss: 1.4474
# Epoch 58/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 1.0514 - val_loss: 1.4599
# Epoch 59/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0603 - val_loss: 1.4307
# Epoch 60/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0148 - val_loss: 1.4231
# Epoch 61/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0245 - val_loss: 1.4001
# Epoch 62/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9985 - val_loss: 1.4254
# Epoch 63/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 1.0235 - val_loss: 1.4418
# Epoch 64/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0098 - val_loss: 1.4181
# Epoch 65/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0249 - val_loss: 1.4075
# Epoch 66/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 1.0025 - val_loss: 1.4294
# Epoch 67/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9988 - val_loss: 1.3629
# Epoch 68/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 1.0047 - val_loss: 1.3862
# Epoch 69/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9818 - val_loss: 1.3561
# Epoch 70/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 1.0029 - val_loss: 1.3729
# Epoch 71/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9761 - val_loss: 1.3511
# Epoch 72/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.9914 - val_loss: 1.3637
# Epoch 73/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9944 - val_loss: 1.3516
# Epoch 74/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9810 - val_loss: 1.3315
# Epoch 75/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9675 - val_loss: 1.3169
# Epoch 76/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9782 - val_loss: 1.3234
# Epoch 77/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9672 - val_loss: 1.3493
# Epoch 78/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9652 - val_loss: 1.3469
# Epoch 79/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9528 - val_loss: 1.3229
# Epoch 80/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.9562 - val_loss: 1.3219
# Epoch 81/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9729 - val_loss: 1.3367
# Epoch 82/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9412 - val_loss: 1.3082
# Epoch 83/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.9307 - val_loss: 1.3431
# Epoch 84/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9396 - val_loss: 1.3240
# Epoch 85/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9390 - val_loss: 1.2956
# Epoch 86/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9322 - val_loss: 1.3312
# Epoch 87/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9257 - val_loss: 1.3386
# Epoch 88/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9431 - val_loss: 1.3151
# Epoch 89/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9341 - val_loss: 1.3243
# Epoch 90/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9230 - val_loss: 1.3377
# Epoch 91/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.9404 - val_loss: 1.3669
# Epoch 92/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.9294 - val_loss: 1.3010
# Epoch 93/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.9197 - val_loss: 1.3491
# Epoch 94/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.9352 - val_loss: 1.3039
# Epoch 95/200
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.9186 - val_loss: 1.3323
# Final Training Loss: 0.9757972359657288
# Final Validation Loss: 1.3323171138763428

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# LSTM Model Performance:
# Training RMSE: 0.020379266382095453
# Test RMSE: 0.023003432981341804
# Training MAE: 0.014780027591528097
# Test MAE: 0.01739230298219025
# Directional Accuracy on Training Data: 54.30539609644087%
# Directional Accuracy on Test Data: 52.666666666666664%

# %% [markdown]
# ### Cross Validation

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Best hyperparameters
best_params = {
    'units1': 64,
    'units2': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.001,
    'epochs': 200,
    'dropout_rate': 0.3,
    'clipnorm': 1.0,
    'batch_size': 32
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step
# Fold 1 RMSE: 1.3774048906747127
# Fold 2
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 2 RMSE: 0.9408202582049232
# Fold 3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3 RMSE: 0.782903270098313
# Fold 4
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Fold 4 RMSE: 1.092230503404653
# Average RMSE from TSCV: 1.0483397305956503

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 268ms/step
# Rolling window RMSE: 1.2032686760193816
# Rolling window starting at index 50
# 1/2 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/stepWARNING:tensorflow:5 out of the last 23 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023ACB91D3A0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 286ms/step
# Rolling window RMSE: 1.2554291053892312
# Rolling window starting at index 100
# WARNING:tensorflow:6 out of the last 24 calls to <function TensorFlowTrainer.make_predict_function.<locals>.one_step_on_data_distributed at 0x0000023AC0EAB2E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 283ms/step
# Rolling window RMSE: 0.8725372378603327
# Rolling window starting at index 150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 261ms/step
# Rolling window RMSE: 0.7271502251201456
# Rolling window starting at index 200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 258ms/step
# Rolling window RMSE: 0.745394800974995
# Rolling window starting at index 250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 263ms/step
# Rolling window RMSE: 0.8753603138875937
# Rolling window starting at index 300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 260ms/step
# Rolling window RMSE: 0.8244675902311063
# Rolling window starting at index 350
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 262ms/step
# Rolling window RMSE: 0.5119507665397893
# Rolling window starting at index 400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 266ms/step
# Rolling window RMSE: 0.7530563633072053
# Rolling window starting at index 450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 259ms/step
# Rolling window RMSE: 1.0520426799261955
# Rolling window starting at index 500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 267ms/step
# Rolling window RMSE: 1.320989526877203
# Average Rolling Window RMSE: 0.9219679351030162

# %%
# Extracting train and val loss:
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Descale train and validation loss
descaled_train_loss = np.sqrt(scaled_train_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]
descaled_val_loss = np.sqrt(scaled_val_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]

print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.02419945225488671
# Descaled Validation Loss: 0.028664543870583613

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.029496339720642247, 0.02064367803489101, 0.01744158257350905, 0.023713835747330877]
# Descaled FRWCV RMSE Values: [0.025965365698812297, 0.02702302691785842, 0.01925909774269816, 0.016311073598994606, 0.016681020330122812, 0.01931634148222494, 0.018284385633828268, 0.011947456879387426, 0.016836374445377993, 0.02289894402031597, 0.028352400854190066]
# Average Descaled TSCV RMSE: 0.0228238590190933
# Average Descaled FRWCV RMSE: 0.020261407963982816

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 4
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       | Model 5       | Model 6       |
# |-----------------|---------------|---------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020287423   | 0.020105201   | 0.020128678   | 0.019353555   | 0.020256659   | 0.020379266   |
# | **Test RMSE**  | 0.023094093   | 0.02291128    | 0.022446095   | 0.022643482   | 0.022985125   | 0.023003433   |
# | **Train MAE**  | 0.014687988   | 0.014736305   | 0.014421072   | 0.013940608   | 0.01463059    | 0.014780028   |
# | **Test MAE**   | 0.017517594   | 0.017639765   | 0.016954642   | 0.017496236   | 0.017508579   | 0.017392303   |
# | **Train Loss** | 1.275761962   | 1.070977807   | 0.89046818    | 0.955986023   | 1.171245098   | 0.975797236   |
# | **Val Loss**   | 1.34799695    | 1.420421243   | 1.31695807    | 1.321932912   | 1.089339852   | 1.332317114   |
# | **Train DA**   | 53%           | 56%           | 63%           | 59%           | 58%           | 54%           |
# | **Test DA**    | 57%           | 51%           | 59%           | 51%           | 53%           | 53%           |
#
# **Abreviations:**
# - RMSE: Root Mean Squared Error.
# - MAE: Mean Absolute Error.
# - Loss: Training or Validation Loss.
# - DA: Directional Accuracy.
#
# ---
#
# **The selected model for the sequence length = 4 is the model 3**, The approach had the lowest RMSE, MAE, DA scores.
#
# #### Training and Validation Loss
# | Metric           | Loss           |
# |-------------------|----------------|
# | **Training Loss** | 0.02419945     |
# | **Validation Loss** | 0.02866454    |
#
# #### TSCV RMSE Values
# | Fold | RMSE           |
# |------|----------------|
# | 1    | 0.02949634     |
# | 2    | 0.02064368     |
# | 3    | 0.01744158     |
# | 4    | 0.02371384     |
#
# **Average TSCV RMSE**: **0.02282386**
#
# - The AVG TSCV shows that the model perfoms above the avg in the first and last fold, it could indicate that the folda might contain extreme values, high volatility, extreme events.
#
# #### FRWCV RMSE Values
# | Window | RMSE           |
# |--------|----------------|
# | 1      | 0.02596537     |
# | 2      | 0.02702303     |
# | 3      | 0.01925910     |
# | 4      | 0.01631107     |
# | 5      | 0.01668102     |
# | 6      | 0.01931634     |
# | 7      | 0.01828439     |
# | 8      | 0.01194746     |
# | 9      | 0.01683637     |
# | 10     | 0.02289894     |
# | 11     | 0.02835240     |
#
# **Average FRWCV RMSE**: **0.02026141**
#
# - The AVG Fixed Rolling Window CV is 0.020 and the scores points to tha same observations as the TSCV, where the model struggles at the start (1 and 2) and the the end (10 and 11).

# %% [markdown]
# ## Sequence Length = 12

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 12  # Number of time steps used for target prediction, 12 weeks (Quarterly).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (864, 12, 5)
# Reshaped y_train_seq shape: (864, 1)
# Reshaped X_test_seq shape: (143, 12, 5)
# Reshaped  y_test_seq shape: (143, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.6819857358932495
# Final Validation Loss: 1.7873555421829224
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.8224691152572632
# Final Validation Loss: 1.943240761756897
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1.68576979637146
# Final Validation Loss: 1.4648078680038452
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.243912220001221
# Final Validation Loss: 6.595617771148682
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.3004305362701416
# Final Validation Loss: 2.816009521484375
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.3951119184494019
# Final Validation Loss: 1.2006938457489014
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.214088439941406
# Final Validation Loss: 9.546709060668945
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.0392873287200928
# Final Validation Loss: 1.8556092977523804
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.746920585632324
# Final Validation Loss: 2.416308879852295
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.25070059299469
# Final Validation Loss: 1.4050463438034058
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.833901882171631
# Final Validation Loss: 6.465328216552734
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.6595274209976196
# Final Validation Loss: 1.1638845205307007
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.001922130584717
# Final Validation Loss: 4.303607940673828
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 19s]
# val_loss: 1.29628586769104
#
# Best val_loss So Far: 1.29628586769104
# Total elapsed time: 00h 20m 21s
# Built model with params: dropout_rate=0.4, recurrent_dropout=0.1, l2_lambda=0.0026041400819170504, learning_rate=0.001, learning_rate_decay=0.0, clipnorm=1.0, units=128, num_layers=1, batch_size=256
# Best hyperparameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026041400819170504, 'learning_rate': 0.001, 'learning_rate_decay': 0.0, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'batch_size': 256}
# Best batch size: 256

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0.0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0026041400819170504,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 256
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model
    
# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 33s 893ms/step - loss: 2.4649 - val_loss: 1.3547
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 3s 64ms/step - loss: 2.4845 - val_loss: 1.3603
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - loss: 2.2292 - val_loss: 1.3551
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 2.1329 - val_loss: 1.3580
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step - loss: 2.0442 - val_loss: 1.3563
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - loss: 2.1404 - val_loss: 1.3561
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.9728 - val_loss: 1.3565
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.9467 - val_loss: 1.3579
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - loss: 1.6519 - val_loss: 1.3575
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.7180 - val_loss: 1.3488
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - loss: 1.7189 - val_loss: 1.3454
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.7486 - val_loss: 1.3532
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step - loss: 1.8825 - val_loss: 1.3479
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.8529 - val_loss: 1.3482
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 1.5964 - val_loss: 1.3448
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 1.7751 - val_loss: 1.3377
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step - loss: 1.4487 - val_loss: 1.3392
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.5566 - val_loss: 1.3380
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.6951 - val_loss: 1.3430
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 1.6693 - val_loss: 1.3520
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - loss: 1.5186 - val_loss: 1.3531
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step - loss: 1.5383 - val_loss: 1.3488
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step - loss: 1.4175 - val_loss: 1.3501
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step - loss: 1.4856 - val_loss: 1.3422
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step - loss: 1.4824 - val_loss: 1.3448
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - loss: 1.4241 - val_loss: 1.3476
# Final Training Loss: 1.3887311220169067
# Final Validation Loss: 1.3475613594055176

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 2s 417ms/step
# LSTM Model Performance:
# Training RMSE: 0.020301631867874283
# Test RMSE: 0.023235272971684488
# Training MAE: 0.014708270631894439
# Test MAE: 0.0175777109707245
# Directional Accuracy on Training Data: 60.25492468134415%
# Directional Accuracy on Test Data: 58.45070422535211%

# %% [markdown]
# ### Cross Validation

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Best hyperparameters
best_params = {
    'units1': 32,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0012015897667654984,
    'epochs': 100,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Fold 1 RMSE: 1.3948628511563586
# Fold 2
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Fold 2 RMSE: 0.9487153376372921
# Fold 3
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 3 RMSE: 0.7903071753664767
# Fold 4
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Fold 4 RMSE: 1.1338795872288432
# Average RMSE from TSCV: 1.0669412378472427

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# Rolling window RMSE: 1.282620163740682
# Rolling window starting at index 50
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Rolling window RMSE: 1.3822951600473827
# Rolling window starting at index 100
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Rolling window RMSE: 0.9206345078136063
# Rolling window starting at index 150
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 153ms/step
# Rolling window RMSE: 0.7786881438478215
# Rolling window starting at index 200
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# Rolling window RMSE: 0.7884647796696848
# Rolling window starting at index 250
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# Rolling window RMSE: 0.8946514305084446
# Rolling window starting at index 300
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Rolling window RMSE: 0.8957477513949517
# Rolling window starting at index 350
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Rolling window RMSE: 0.45598799269557727
# Rolling window starting at index 400
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# Rolling window RMSE: 0.8068912537043444
# Rolling window starting at index 450
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step
# Rolling window RMSE: 0.9432086371391672
# Rolling window starting at index 500
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step
# Rolling window RMSE: 1.4104083846325526
# Average Rolling Window RMSE: 0.9599634731994741

# %%
# Extracting train and val loss:
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Descale train and validation loss
descaled_train_loss = np.sqrt(scaled_train_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]
descaled_val_loss = np.sqrt(scaled_val_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]

print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.027406534433443278
# Descaled Validation Loss: 0.030066503759855562

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.02985033618861898, 0.02080376719515647, 0.0175917121557658, 0.024558357567833942]
# Descaled FRWCV RMSE Values: [0.027574382193698486, 0.0295955001057972, 0.02023436995165307, 0.017356112119711272, 0.01755435375012812, 0.019707509004587478, 0.01972973919132668, 0.01081269521579795, 0.017927988845269516, 0.020692107386521247, 0.030165554220483143]
# Average Descaled TSCV RMSE: 0.023201043276843795
# Average Descaled FRWCV RMSE: 0.021031846544088562

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 12
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020357128   | 0.020397132   | 0.020418636   | 0.020301632   |
# | **Test RMSE**  | 0.023259253   | 0.023255509   | 0.023153177   | 0.023235273   |
# | **Train MAE**  | 0.01478992    | 0.014684571   | 0.014849      | 0.014708271   |
# | **Test MAE**   | 0.017503574   | 0.017394277   | 0.017508652   | 0.017577711   |
# | **Train Loss** | 1.210249424   | 1.410629749   | 1.371209502   | 1.388731122   |
# | **Val Loss**   | 1.436954141   | 1.305546761   | 1.116409898   | 1.347561359   |
# | **Train DA**   | 57%           | 52%           | 44%           | 60%           |
# | **Test DA**    | 61%           | 48%           | 51%           | 58%           |
#
# **The sequence length of 12 will be represented by the model 3**, the model outperfomed the others having lower test RMSE, lowest val loss and  the train loss "stabilized" faster than the others.
#
# #### Training and Validation Loss
# | Metric           | Loss           |
# |-------------------|----------------|
# | **Training Loss** | 0.02740653     |
# | **Validation Loss** | 0.03006650    |
#
# #### TSCV RMSE Values
# | Fold | RMSE           |
# |------|----------------|
# | 1    | 0.02985034     |
# | 2    | 0.02080377     |
# | 3    | 0.01759171     |
# | 4    | 0.02455836     |
#
# **Average TSCV RMSE**: **0.02320104**
#
# - The model of SL = 12 has higher AVG RMSE than the SL =4, however the performance across all 4 folds remained the same, where not performs well on the first and last fold.
#
# #### FRWCV RMSE Values
# | Window | RMSE           |
# |--------|----------------|
# | 1      | 0.02757438     |
# | 2      | 0.02959550     |
# | 3      | 0.02023437     |
# | 4      | 0.01735611     |
# | 5      | 0.01755435     |
# | 6      | 0.01970751     |
# | 7      | 0.01972974     |
# | 8      | 0.01081270     |
# | 9      | 0.01792799     |
# | 10     | 0.02069211     |
# | 11     | 0.03016555     |
#
# **Average FRWCV RMSE**: **0.02103185
#
# - Observing the FRWCV scores, the avg is higher than the previous sequence length, altough it performs a little better throughtout the windows (Windown 10 performs below avg, where in the previous SL it performs above avg).

# %% [markdown]
# ## Sequence Length = 26

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 26  # Number of time steps used for target prediction, 26 weeks (Six-Months).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (850, 26, 5)
# Reshaped y_train_seq shape: (850, 1)
# Reshaped X_test_seq shape: (129, 26, 5)
# Reshaped  y_test_seq shape: (129, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.08440101146698
# Final Validation Loss: 1.333011507987976
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.9566689729690552
# Final Validation Loss: 1.914771318435669
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1
150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 1.3518 - val_loss: 0.9677
# Epoch 14/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 1.2908 - val_loss: 0.9972
# Epoch 15/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.1478 - val_loss: 0.9669
# Epoch 16/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.2280 - val_loss: 0.9705
# Epoch 17/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 1.0730 - val_loss: 0.9655
# Epoch 18/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 1.1358 - val_loss: 0.9620
# Epoch 19/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.0746 - val_loss: 0.9593
# Epoch 20/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 1.1323 - val_loss: 0.9667
# Epoch 21/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 1.0815 - val_loss: 0.9592
# Epoch 22/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 1.0407 - val_loss: 0.9615
# Epoch 23/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.9704 - val_loss: 0.9498
# Epoch 24/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 1.0004 - val_loss: 0.9458
# Epoch 25/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 1.0600 - val_loss: 0.9475
# Epoch 26/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 0.9389 - val_loss: 0.9522
# Epoch 27/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.9794 - val_loss: 0.9482
# Epoch 28/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - loss: 0.9660 - val_loss: 0.9835
# Epoch 29/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 1.0100 - val_loss: 0.9592
# Epoch 30/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 0.9771 - val_loss: 0.9954
# Epoch 31/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - loss: 0.9565 - val_loss: 0.9876
# Epoch 32/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.9359 - val_loss: 1.0080
# Epoch 33/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - loss: 0.9492 - val_loss: 1.0251
# Epoch 34/150
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - loss: 0.9801 - val_loss: 1.0247
# Final Training Loss: 1.0032721757888794
# Final Validation Loss: 1.0246715545654297

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# LSTM Model Performance:
# Training RMSE: 0.020233155675107386
# Test RMSE: 0.023801557089073846
# Training MAE: 0.014721210001560682
# Test MAE: 0.018203910611018784
# Directional Accuracy on Training Data: 70.6713780918728%
# Directional Accuracy on Test Data: 66.40625%

# %% [markdown]
# ### 3. Keras Tuner (Model 4)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.


    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 00m 36s]
# val_loss: 1.5710058212280273
#
# Best val_loss So Far: 1.154745101928711
# Total elapsed time: 00h 39m 05s
# Built model with params: dropout_rate=0.4, recurrent_dropout=0.1, l2_lambda=0.0026041400819170504, learning_rate=0.001, learning_rate_decay=0.0, clipnorm=1.0, units=128, num_layers=1, batch_size=256
# Best hyperparameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026041400819170504, 'learning_rate': 0.001, 'learning_rate_decay': 0.0, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'batch_size': 256}
# Best batch size: 256

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 0.0,
    'learning_rate': 0.001,
    'l2_lambda': 0.0026041400819170504,
    'epochs': 200,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 256
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - loss: 2.4657 - val_loss: 1.4674
# Epoch 2/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 118ms/step - loss: 2.3210 - val_loss: 1.4640
# Epoch 3/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - loss: 2.0615 - val_loss: 1.4662
# Epoch 4/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 2.3965 - val_loss: 1.4636
# Epoch 5/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 1.9217 - val_loss: 1.4590
# Epoch 6/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 1.9861 - val_loss: 1.4656
# Epoch 7/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 1.8647 - val_loss: 1.4649
# Epoch 8/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - loss: 1.9412 - val_loss: 1.4670
# Epoch 9/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 155ms/step - loss: 1.8924 - val_loss: 1.4655
# Epoch 10/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - loss: 1.4930 - val_loss: 1.4564
# Epoch 11/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 101ms/step - loss: 2.0021 - val_loss: 1.4604
# Epoch 12/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 118ms/step - loss: 1.9306 - val_loss: 1.4658
# Epoch 13/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 1.6566 - val_loss: 1.4582
# Epoch 14/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 1.7935 - val_loss: 1.4617
# Epoch 15/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 127ms/step - loss: 1.6696 - val_loss: 1.4663
# Epoch 16/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 1.7176 - val_loss: 1.4579
# Epoch 17/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.6147 - val_loss: 1.4616
# Epoch 18/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 131ms/step - loss: 1.6413 - val_loss: 1.4695
# Epoch 19/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 153ms/step - loss: 1.5481 - val_loss: 1.4629
# Epoch 20/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 130ms/step - loss: 1.4731 - val_loss: 1.4531
# Epoch 21/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 1.7174 - val_loss: 1.4528
# Epoch 22/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 126ms/step - loss: 1.4862 - val_loss: 1.4530
# Epoch 23/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 1.5822 - val_loss: 1.4473
# Epoch 24/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 128ms/step - loss: 1.5834 - val_loss: 1.4443
# Epoch 25/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 1.5633 - val_loss: 1.4400
# Epoch 26/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 1.3878 - val_loss: 1.4442
# Epoch 27/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 1.3384 - val_loss: 1.4472
# Epoch 28/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 1.3755 - val_loss: 1.4493
# Epoch 29/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 1.4110 - val_loss: 1.4469
# Epoch 30/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 133ms/step - loss: 1.4390 - val_loss: 1.4471
# Epoch 31/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 1.3744 - val_loss: 1.4407
# Epoch 32/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 124ms/step - loss: 1.3776 - val_loss: 1.4439
# Epoch 33/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 184ms/step - loss: 1.2079 - val_loss: 1.4534
# Epoch 34/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 1.3582 - val_loss: 1.4468
# Epoch 35/200
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 122ms/step - loss: 1.3528 - val_loss: 1.4445
# Final Training Loss: 1.3891215324401855
# Final Validation Loss: 1.4444739818572998

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# LSTM Model Performance:
# Training RMSE: 0.02035861579386718
# Test RMSE: 0.024124869104101693
# Training MAE: 0.014754933578243125
# Test MAE: 0.018413920081660515
# Directional Accuracy on Training Data: 64.78209658421673%
# Directional Accuracy on Test Data: 65.625%

# %% [markdown]
# ### Cross Validation

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Best hyperparameters
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0015394277020084359,
    'epochs': 150,
    'dropout_rate': 0.4,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# Fold 1 RMSE: 1.3981000581281835
# Fold 2
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 2 RMSE: 0.9455451709022236
# Fold 3
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 3 RMSE: 0.7547278175981055
# Fold 4
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Fold 4 RMSE: 1.1452680272723192
# Average RMSE from TSCV: 1.060910268475208

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 50    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Rolling window RMSE: 1.0065762272284613
# Rolling window starting at index 50
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Rolling window RMSE: 1.5270547035690634
# Rolling window starting at index 100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Rolling window RMSE: 0.9907231761037796
# Rolling window starting at index 150
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Rolling window RMSE: 0.7927440011460382
# Rolling window starting at index 200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Rolling window RMSE: 0.7674108035743965
# Rolling window starting at index 250
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# Rolling window RMSE: 0.9280452078696475
# Rolling window starting at index 300
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# Rolling window RMSE: 0.6022921650936036
# Rolling window starting at index 350
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step
# Rolling window RMSE: 0.4216688307094885
# Rolling window starting at index 400
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Rolling window RMSE: 0.8000234856584677
# Rolling window starting at index 450
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Rolling window RMSE: 0.6369484238586697
# Rolling window starting at index 500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# Rolling window RMSE: 1.695759695428449
# Average Rolling Window RMSE: 0.9244769745672787

# %%
# Extracting train and val loss:
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Descale train and validation loss
descaled_train_loss = np.sqrt(scaled_train_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]
descaled_val_loss = np.sqrt(scaled_val_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]

print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.024038753940243462
# Descaled Validation Loss: 0.03605486628160111

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.029915977294596992, 0.020739485469447937, 0.016870266658387943, 0.02478928188201106]
# Descaled FRWCV RMSE Values: [0.021977017104319665, 0.03253080100572042, 0.021655563512378503, 0.01764112386797275, 0.017127440584501802, 0.02038463731236978, 0.01377931667960583, 0.010116802809593383, 0.017788730560564396, 0.014482044424293936, 0.03595164568634922]
# Average Descaled TSCV RMSE: 0.023078752826110983
# Average Descaled FRWCV RMSE: 0.020312283958879063

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 26
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020564458   | 0.020469691   | 0.020233156   | 0.020358616   |
# | **Test RMSE**  | 0.024389698   | 0.024201429   | 0.023801557   | 0.024124869   |
# | **Train MAE**  | 0.014952568   | 0.014876318   | 0.01472121    | 0.014754934   |
# | **Test MAE**   | 0.018951864   | 0.018582196   | 0.018203911   | 0.01841392    |
# | **Train Loss** | 1.390009165   | 1.575931907   | 1.003272176   | 1.389121532   |
# | **Val Loss**   | 1.338090062   | 1.270840764   | 1.024671555   | 1.444473982   |
# | **Train DA**   | 51%           | 51%           | 71%           | 65%           |
# | **Test DA**    | 54%           | 52%           | 66%           | 66%           |
#
# ---
#
# **Sequence Length of 26 has the model 3 the as the best performer**, it has the lowest metrics for all, but also the covergence between train and val loss is satisfatory.
#
#
# #### Training and Validation Loss
# | Metric           | Loss           |
# |-------------------|----------------|
# | **Training Loss** | 0.02740653     |
# | **Validation Loss** | 0.03006650    |
#
# #### TSCV RMSE Values
# | Fold | RMSE           |
# |------|----------------|
# | 1    | 0.02985034     |
# | 2    | 0.02080377     |
# | 3    | 0.01759171     |
# | 4    | 0.02455836     |
#
# **Average TSCV RMSE**: **0.02320104**
#
# - When TSCV performed it shows similar results and observations as the previous SL.
#
# #### FRWCV RMSE Values
# | Window | RMSE           |
# |--------|----------------|
# | 1      | 0.02757438     |
# | 2      | 0.02959550     |
# | 3      | 0.02023437     |
# | 4      | 0.01735611     |
# | 5      | 0.01755435     |
# | 6      | 0.01970751     |
# | 7      | 0.01972974     |
# | 8      | 0.01081270     |
# | 9      | 0.01792799     |
# | 10     | 0.02069211     |
# | 11     | 0.03016555     |
#
# **Average FRWCV RMSE**: **0.02103185**
#
# - The FRWCV scores shows that it performs similar to the SL = 12, where underperforms in 3 windows (location start and ent windows is also the same).

# %% [markdown]
# ## Sequence Length = 52

# %%
# Set the sequence length for LSTM input, representing the number of time steps.
sequence_length = 52  # Number of time steps used for target prediction, 52 weeks (One year).

# Reshape data into sequences for LSTM.
# Initialize empty lists to hold the sequences for the training set.
X_train_seq, y_train_seq = [], []
# Loop through the training data to create sequences of features and corresponding target values.
for i in range(len(X_train_scaled) - sequence_length):
    # Append a sequence of features for the current window.
    X_train_seq.append(X_train_scaled[i:i + sequence_length]) # Sequence of features.
    # Append the target value that comes immediately after the sequence.
    y_train_seq.append(y_train_scaled[i + sequence_length]) # Target value following the sequence.
# Initialize empty lists to hold the sequences for the test set    
X_test_seq, y_test_seq = [], []
# Same process for the test sets.
for i in range(len(X_test_scaled) - sequence_length):
    # Append a sequence of features for the current window in the test set.
    X_test_seq.append(X_test_scaled[i:i + sequence_length])
    # Append the target value immediately after the sequence in the test set.
    y_test_seq.append(y_test_scaled[i + sequence_length])

# Convert lists to numpy arrays to use in Neural Networks.
X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)

# Print the reshaped input data for LSTM.
print(f"Reshaped X_train_seq shape: {X_train_seq.shape}")
print(f"Reshaped y_train_seq shape: {y_train_seq.shape}")
print(f"Reshaped X_test_seq shape: {X_test_seq.shape}")
print(f"Reshaped  y_test_seq shape: { y_test_seq.shape}")
# Out:
# Reshaped X_train_seq shape: (824, 52, 5)
# Reshaped y_train_seq shape: (824, 1)
# Reshaped X_test_seq shape: (103, 52, 5)
# Reshaped  y_test_seq shape: (103, 1)

# %% [markdown]
# ### 1. Random Search (Two Layers - Model 1)

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Define parameter grid for random hyperparameter search.
param_grid = {
    'dropout_rate': [0.2, 0.3, 0.4],               # Dropout rate for regularization.
    'recurrent_dropout': [0.1, 0.2],               # Recurrent dropout within LSTM layers.
    'l2_lambda': [0.001, 0.01, 0.1],               # L2 regularization strength.
    'learning_rate': [0.001, 0.0005, 0.0001],      # Learning rate for optimizer.
    'learning_rate_decay': [1e-6, 1e-5, 0],        # Decay rate for learning rate over time.
    'units1': [32, 64, 128],                       # Number of units in the first LSTM layer.
    'units2': [32, 64, 128],                       # Number of units in the second LSTM layer.
    'batch_size': [32, 64, 120, 256],              # Batch size for training.
    'epochs': [50, 100, 200],                      # Number of epochs to train.
    'optimizer': ['adam'],                         # Optimizer to use.
    'clipnorm': [1.0, 5.0]                         # Gradient clipping to avoid exploding gradients.
}

# Generate a list of random combinations of hyperparameters.
n_iter_search = 30  # Number of random combinations to attempt.
# Random state being applied for reproducibility. 
random_combinations = list(ParameterSampler(param_grid, n_iter=n_iter_search, random_state=42)) 

# Define a function to build the LSTM model with given parameters.
def build_model(dropout_rate, recurrent_dropout, l2_lambda, learning_rate, learning_rate_decay, clipnorm, units1, units2, optimizer_name, loss_function):
    model = Sequential()
    
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units1, return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),  # Input shape based on sequence data.
                   kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())  # Batch normalization for stable training.
    model.add(Dropout(dropout_rate))  # Dropout for regularization.
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout.
    model.add(LSTM(units=units2, return_sequences=False, kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
    model.add(BatchNormalization())
    model.add(Dropout(dropout_rate))
    
    # Output layer with a single unit for regression output.
    model.add(Dense(1))
    
    # Select optimizer with learning rate decay and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
    
    # Compile the model with the chosen optimizer and loss function.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Define early stopping to stop training when validation loss does not improve.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Placeholder to store results of each model configuration.
results = []

# Run random search
for i, params in enumerate(random_combinations):
    print(f"Running combination {i+1}/{len(random_combinations)}: {params}")
    
    # Build model with the current parameters
    model = build_model(
        dropout_rate=params['dropout_rate'],
        recurrent_dropout=params['recurrent_dropout'],
        l2_lambda=params['l2_lambda'],
        learning_rate=params['learning_rate'],
        learning_rate_decay=params['learning_rate_decay'],
        clipnorm=params['clipnorm'],
        units1=params['units1'],
        units2=params['units2'],
        optimizer_name=params['optimizer'],
        loss_function='mean_squared_error'
    )
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=params['epochs'], 
        batch_size=params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to reduce output
    )
    
    # Get final validation loss and training loss
    final_val_loss = history.history['val_loss'][-1]
    final_train_loss = history.history['loss'][-1]
    
    # Store the results
    results.append({
        'params': params,
        'final_train_loss': final_train_loss,
        'final_val_loss': final_val_loss
    })
    
    print(f"Final Training Loss: {final_train_loss}")
    print(f"Final Validation Loss: {final_val_loss}")

results = sorted(results, key=lambda x: x['final_val_loss'])
print("Top results:")
for res in results[:5]:  # Show top 5 results
    print(res)
# Out:
# Running combination 1/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 1.827374815940857
# Final Validation Loss: 1.913159966468811
# Running combination 2/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.387868642807007
# Final Validation Loss: 2.4169936180114746
# Running combination 3/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 1.6863856315612793
# Final Validation Loss: 1.6620391607284546
# Running combination 4/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 7.407658100128174
# Final Validation Loss: 6.868350028991699
# Running combination 5/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 3.511692523956299
# Final Validation Loss: 3.1718499660491943
# Running combination 6/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 1.630065679550171
# Final Validation Loss: 1.6741653680801392
# Running combination 7/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}
# Final Training Loss: 10.497559547424316
# Final Validation Loss: 9.843597412109375
# Running combination 8/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.0399343967437744
# Final Validation Loss: 1.9937527179718018
# Running combination 9/30: {'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.001779079437256
# Final Validation Loss: 2.613908052444458
# Running combination 10/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.3110499382019043
# Final Validation Loss: 1.5028038024902344
# Running combination 11/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 6.901216506958008
# Final Validation Loss: 6.735052585601807
# Running combination 12/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 1.7686206102371216
# Final Validation Loss: 1.690525770187378
# Running combination 13/30: {'units2': 128, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 5.459934711456299
# Final Validation Loss: 5.261467933654785
# Running combination 14/30: {'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.001, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 1.8698182106018066
# Final Validation Loss: 1.6886961460113525
# Running combination 15/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 1.8089885711669922
# Final Validation Loss: 1.556607723236084
# Running combination 16/30: {'units2': 32, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 2.7093353271484375
# Final Validation Loss: 2.5380735397338867
# Running combination 17/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 14.547951698303223
# Final Validation Loss: 13.614897727966309
# Running combination 18/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 14.429163932800293
# Final Validation Loss: 14.263017654418945
# Running combination 19/30: {'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 20.41126823425293
# Final Validation Loss: 20.36656951904297
# Running combination 20/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 2.7463133335113525
# Final Validation Loss: 2.1080739498138428
# Running combination 21/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 1.4641541242599487
# Final Validation Loss: 1.7660901546478271
# Running combination 22/30: {'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 2.13358473777771
# Final Validation Loss: 2.18375825881958
# Running combination 23/30: {'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 7.537811279296875
# Final Validation Loss: 6.8426361083984375
# Running combination 24/30: {'units2': 64, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.23588228225708
# Final Validation Loss: 3.2700352668762207
# Running combination 25/30: {'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss:
# Running combination 21/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}
# Final Training Loss: 3.6790318489074707
# Final Validation Loss: 3.3470680713653564
# Running combination 22/30: {'units3': 128, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 33.70851516723633
# Final Validation Loss: 31.787094116210938
# Running combination 23/30: {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 18.490798950195312
# Final Validation Loss: 17.064054489135742
# Running combination 24/30: {'units3': 64, 'units2': 128, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.1, 'epochs': 200, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 38.022850036621094
# Final Validation Loss: 37.661094665527344
# Running combination 25/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 120}
# Final Training Loss: 12.339818000793457
# Final Validation Loss: 12.069515228271484
# Running combination 26/30: {'units3': 32, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 256}
# Final Training Loss: 3.9196033477783203
# Final Validation Loss: 3.5070383548736572
# Running combination 27/30: {'units3': 64, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 1.0, 'batch_size': 64}
# Final Training Loss: 4.18916130065918
# Final Validation Loss: 3.933065414428711
# Running combination 28/30: {'units3': 64, 'units2': 64, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.001, 'l2_lambda': 0.01, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 120}
# Final Training Loss: 3.2741382122039795
# Final Validation Loss: 3.0664634704589844
# Running combination 29/30: {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-06, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 50, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 256}
# Final Training Loss: 11.659074783325195
# Final Validation Loss: 11.329395294189453
# Running combination 30/30: {'units3': 128, 'units2': 128, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.01, 'epochs': 200, 'dropout_rate': 0.4, 'clipnorm': 5.0, 'batch_size': 32}
# Final Training Loss: 5.351394176483154
# Final Validation Loss: 4.098144054412842
# Top results:
# {'params': {'units3': 32, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.1, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 32}, 'final_train_loss': 1.0516377687454224, 'final_val_loss': 1.5555119514465332}
# {'params': {'units3': 64, 'units2': 64, 'units1': 64, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 50, 'dropout_rate': 0.3, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 2.5156431198120117, 'final_val_loss': 1.6032984256744385}
# {'params': {'units3': 64, 'units2': 32, 'units1': 32, 'recurrent_dropout': 0.1, 'optimizer': 'adam', 'learning_rate_decay': 0, 'learning_rate': 0.0001, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.3, 'clipnorm': 1.0, 'batch_size': 32}, 'final_train_loss': 2.492981433868408, 'final_val_loss': 1.6495344638824463}
# {'params': {'units3': 128, 'units2': 64, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.2, 'clipnorm': 5.0, 'batch_size': 64}, 'final_train_loss': 1.6312065124511719, 'final_val_loss': 1.7098944187164307}
# {'params': {'units3': 32, 'units2': 32, 'units1': 128, 'recurrent_dropout': 0.2, 'optimizer': 'adam', 'learning_rate_decay': 1e-05, 'learning_rate': 0.0005, 'l2_lambda': 0.001, 'epochs': 100, 'dropout_rate': 0.4, 'clipnorm': 1.0, 'batch_size': 120}, 'final_train_loss': 2.5601563453674316, 'final_val_loss': 1.7933379411697388}

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'units2': 64,
    'units3': 128,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.001,
    'epochs': 100,
    'dropout_rate': 0.2,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 57s 489ms/step - loss: 3.1689 - val_loss: 1.7344
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 2.5636 - val_loss: 1.7160
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 2.2878 - val_loss: 1.7233
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 1.9459 - val_loss: 1.7226
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 2.0355 - val_loss: 1.7131
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 206ms/step - loss: 1.9846 - val_loss: 1.7165
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 1.8173 - val_loss: 1.7147
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 219ms/step - loss: 1.6447 - val_loss: 1.7143
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 1.7454 - val_loss: 1.7235
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.5846 - val_loss: 1.7022
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 208ms/step - loss: 1.6611 - val_loss: 1.7223
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 218ms/step - loss: 1.7496 - val_loss: 1.7123
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 1.6342 - val_loss: 1.7148
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 1.6549 - val_loss: 1.7050
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - loss: 1.7190 - val_loss: 1.6876
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 1.6127 - val_loss: 1.7057
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.4811 - val_loss: 1.7713
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 1.6374 - val_loss: 1.6526
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - loss: 1.5696 - val_loss: 1.7049
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 217ms/step - loss: 1.5723 - val_loss: 1.7195
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 214ms/step - loss: 1.5534 - val_loss: 1.6504
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 207ms/step - loss: 1.4782 - val_loss: 1.6742
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 210ms/step - loss: 1.5259 - val_loss: 1.7465
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 215ms/step - loss: 1.4572 - val_loss: 1.6986
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 1.3765 - val_loss: 1.7439
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 216ms/step - loss: 1.4462 - val_loss: 1.7536
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 220ms/step - loss: 1.3689 - val_loss: 1.7311
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 205ms/step - loss: 1.3558 - val_loss: 1.7827
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 213ms/step - loss: 1.3789 - val_loss: 1.7084
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - loss: 1.3087 - val_loss: 1.7895
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 211ms/step - loss: 1.2834 - val_loss: 1.7900
# Final Training Loss: 1.3060624599456787
# Final Validation Loss: 1.7899718284606934

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# LSTM Model Performance:
# Training RMSE: 0.021570579950971648
# Test RMSE: 0.025544102735954748
# Training MAE: 0.016092109581277908
# Test MAE: 0.019771341407930246
# Directional Accuracy on Training Data: 60.51032806804374%
# Directional Accuracy on Test Data: 59.80392156862745%

# %% [markdown]
# ### 2. Optuna (Model 3)

# %%
# Set global random state for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Optuna's TPESampler with a fixed random seed for reproducibility in parameter search.
sampler = TPESampler(seed=random_seed)

# Create an Optuna study with direction "minimize" to minimize the validation loss.
study = optuna.create_study(direction="minimize", sampler=sampler)

# Define the objective function for hyperparameter optimization.
def objective(trial):
    """
    Objective function for Optuna to optimize hyperparameters of an LSTM model.
    Takes a trial object from Optuna and returns the validation loss of the model with given parameters.
    """

    # Define hyperparameters to tune.
    dropout_rate = trial.suggest_float("dropout_rate", 0.2, 0.4, step=0.1)  # Dropout rate for LSTM layers.
    recurrent_dropout = trial.suggest_categorical("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout rate for LSTM layers.
    l2_lambda = trial.suggest_loguniform("l2_lambda", 1e-3, 1e-1)  # L2 regularization factor.
    learning_rate = trial.suggest_categorical("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate for the optimizer.
    learning_rate_decay = trial.suggest_categorical("learning_rate_decay", [1e-6, 1e-5, 0])  # Learning rate decay.
    clipnorm = trial.suggest_categorical("clipnorm", [1.0, 5.0])  # Gradient clipping norm.
    units = trial.suggest_categorical("units", [32, 64, 128])  # Number of units in LSTM layers.
    num_layers = trial.suggest_int("num_layers", 1, 3)  # Number of LSTM layers.
    epochs = trial.suggest_int("epochs", 50, 200, step=50)  # Number of epochs.
    batch_size = trial.suggest_categorical("batch_size", [32, 64, 120, 256])  # Batch size.
    
    # Initialize the Sequential model.
    model = Sequential()

    # Add LSTM layers based on num_layers.
    for i in range(num_layers):
        # Set return_sequences=True for all but the last LSTM layer.
        return_sequences = (i < num_layers - 1)
        
        # Add LSTM layer with specified hyperparameters.
        model.add(LSTM(
            units=units,
            return_sequences=return_sequences,
            input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,  # Set input shape only for the first layer.
            kernel_regularizer=l2(l2_lambda),
            recurrent_dropout=recurrent_dropout
        ))

        # Add BatchNormalization and Dropout after each LSTM layer.
        model.add(BatchNormalization())
        model.add(Dropout(dropout_rate))

    # Add the output layer with a single unit (regression).
    model.add(Dense(1))

    # Initialize the optimizer with learning rate, decay, and gradient clipping norm.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    # Early stopping callback to avoid overfitting.
    early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
    
    # Train the model with given hyperparameters.
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=epochs,
        batch_size=batch_size,
        validation_data=(X_test_seq, y_test_seq),
        callbacks=[early_stopping],
        shuffle=False,
        verbose=0  # Set verbose=0 to suppress training logs for faster experimentation.
    )

    # Retrieve the minimum validation loss from the training history.
    val_loss = min(history.history['val_loss'])
    
    # Return the validation loss to be minimized by Optuna.
    return val_loss

# Run the Optuna study for a given number of trials.
study.optimize(objective, n_trials=30)

# Print the best parameters found by the study.
print("Best hyperparameters:", study.best_params)

# Print the best validation loss achieved with the optimal parameters.
print("Best validation loss:", study.best_value)
# Out:
# [I 2024-11-13 18:36:10,488] A new study created in memory with name: no-name-a1322880-430e-42fa-b9b2-7152897dc7a2
# [I 2024-11-13 18:36:41,636] Trial 0 finished with value: 1.8467261791229248 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0037550037026405905, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 0 with value: 1.8467261791229248.
# [I 2024-11-13 18:37:20,929] Trial 1 finished with value: 4.110915184020996 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.04641587067816149, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 2, 'epochs': 50, 'batch_size': 256}. Best is trial 0 with value: 1.8467261791229248.
# [I 2024-11-13 18:42:27,231] Trial 2 finished with value: 5.081692218780518 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.02754390996680696, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 120}. Best is trial 0 with value: 1.8467261791229248.
# [I 2024-11-13 18:45:07,236] Trial 3 finished with value: 1.9505810737609863 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06953241045943279, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 256}. Best is trial 0 with value: 1.8467261791229248.
# [I 2024-11-13 18:45:44,221] Trial 4 finished with value: 1.6147297620773315 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.07320157289972352, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 150, 'batch_size': 32}. Best is trial 4 with value: 1.6147297620773315.
# [I 2024-11-13 18:48:48,284] Trial 5 finished with value: 1.9636893272399902 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.06621901977279396, 'learning_rate': 0.0005, 'learning_rate_decay': 0, 'clipnorm': 1.0, 'units': 64, 'num_layers': 2, 'epochs': 150, 'batch_size': 256}. Best is trial 4 with value: 1.6147297620773315.
# [I 2024-11-13 18:49:56,509] Trial 6 finished with value: 3.2183070182800293 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0038300508438275606, 'learning_rate': 0.0001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 3, 'epochs': 50, 'batch_size': 256}. Best is trial 4 with value: 1.6147297620773315.
# [I 2024-11-13 18:50:54,448] Trial 7 finished with value: 1.3782212734222412 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:51:30,204] Trial 8 finished with value: 1.9863698482513428 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0017384974140603195, 'learning_rate': 0.0001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:52:24,692] Trial 9 finished with value: 1.6652352809906006 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.028980866560207673, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 1.0, 'units': 64, 'num_layers': 1, 'epochs': 200, 'batch_size': 120}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:53:20,507] Trial 10 finished with value: 1.395669937133789 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010012325682668814, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:54:10,298] Trial 11 finished with value: 1.383487343788147 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0011454828358668492, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:54:56,591] Trial 12 finished with value: 1.4221789836883545 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0035031592252575765, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:55:49,780] Trial 13 finished with value: 1.4166622161865234 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.008806713278062726, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:57:18,135] Trial 14 finished with value: 1.5919921398162842 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010282395772134737, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 100, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:57:48,332] Trial 15 finished with value: 1.406417727470398 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001900268331470526, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 32}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 18:59:34,894] Trial 16 finished with value: 1.5430119037628174 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.009118985456676882, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 2, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:00:31,789] Trial 17 finished with value: 1.4111287593841553 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.002370630816538054, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:03:29,289] Trial 18 finished with value: 1.8482787609100342 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.006750035538813451, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:03:45,698] Trial 19 finished with value: 1.5487407445907593 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.017039760221787055, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 100, 'batch_size': 32}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:04:44,096] Trial 20 finished with value: 1.7004165649414062 and parameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001492070475342425, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:05:28,806] Trial 21 finished with value: 1.400225043296814 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0010021936921001697, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:05:58,679] Trial 22 finished with value: 1.4320311546325684 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0026752923808708103, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 200, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:06:48,516] Trial 23 finished with value: 1.37994384765625 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0013643809740848866, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:07:44,389] Trial 24 finished with value: 1.3979604244232178 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.005632491290277578, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:08:31,338] Trial 25 finished with value: 1.405396580696106 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.001372851566592054, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:09:17,400] Trial 26 finished with value: 1.414581298828125 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0023161786099215797, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 100, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:10:11,804] Trial 27 finished with value: 1.6992305517196655 and parameters: {'dropout_rate': 0.2, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0014848587399971182, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 2, 'epochs': 150, 'batch_size': 32}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:10:29,585] Trial 28 finished with value: 1.627184271812439 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.00466845029849557, 'learning_rate': 0.001, 'learning_rate_decay': 0, 'clipnorm': 5.0, 'units': 32, 'num_layers': 1, 'epochs': 150, 'batch_size': 120}. Best is trial 7 with value: 1.3782212734222412.
# [I 2024-11-13 19:11:42,499] Trial 29 finished with value: 2.0631511211395264 and parameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.2, 'l2_lambda': 0.0032174827923371675, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 64, 'num_layers': 3, 'epochs': 100, 'batch_size': 64}. Best is trial 7 with value: 1.3782212734222412.
# Best hyperparameters: {'dropout_rate': 0.30000000000000004, 'recurrent_dropout': 0.1, 'l2_lambda': 0.0019223481607694784, 'learning_rate': 0.001, 'learning_rate_decay': 1e-06, 'clipnorm': 5.0, 'units': 128, 'num_layers': 1, 'epochs': 150, 'batch_size': 64}
# Best validation loss: 1.3782212734222412

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0019223481607694784,
    'epochs': 150,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
     # Select the optimizer with specified parameters
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Select the loss function based on tuning results.
    if params['loss_function'] == 'huber_loss':
        loss = Huber()  # Huber loss is more robust to outliers
    else:
        loss = MeanSquaredError()  # Use MSE as default loss function for regression
    
    # Compile the model with the specified optimizer and loss function
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters.
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving.
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping.
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss.
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 22s 213ms/step - loss: 1.8093 - val_loss: 1.4182
# Epoch 2/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - loss: 1.8499 - val_loss: 1.4358
# Epoch 3/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.7074 - val_loss: 1.4256
# Epoch 4/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 68ms/step - loss: 1.7575 - val_loss: 1.4357
# Epoch 5/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 70ms/step - loss: 1.4206 - val_loss: 1.4333
# Epoch 6/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.3772 - val_loss: 1.4295
# Epoch 7/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.4498 - val_loss: 1.4258
# Epoch 8/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - loss: 1.3688 - val_loss: 1.4309
# Epoch 9/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 67ms/step - loss: 1.3824 - val_loss: 1.4233
# Epoch 10/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 1.3099 - val_loss: 1.4271
# Epoch 11/150
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 1.3266 - val_loss: 1.4223
# Final Training Loss: 1.3508981466293335
# Final Validation Loss: 1.4223191738128662

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# LSTM Model Performance:
# Training RMSE: 0.020614847674757793
# Test RMSE: 0.025500470618167022
# Training MAE: 0.014900086136902616
# Test MAE: 0.019994078796736647
# Directional Accuracy on Training Data: 59.05224787363304%
# Directional Accuracy on Test Data: 70.58823529411765%

# %% [markdown]
# ### 3. Keras Tuner (Model 4)

# %%
# Set a global random seed for reproducibility.
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Build model function with hyperparameter choices.
def build_model(hp): #hp (kerastuner.HyperParameters) - Hyperparameter search space.
    model = Sequential()
    
    # Define hyperparameters using `hp` for various tuning options.
    dropout_rate = hp.Choice("dropout_rate", [0.2, 0.3, 0.4])  # Dropout rates to fight overfitting.
    recurrent_dropout = hp.Choice("recurrent_dropout", [0.1, 0.2])  # Recurrent dropout for LSTM layers.
    l2_lambda = hp.Float("l2_lambda", min_value=0.001, max_value=0.1, sampling="log")  # L2 regularization factor.
    learning_rate = hp.Choice("learning_rate", [0.001, 0.0005, 0.0001])  # Learning rate choices.
    learning_rate_decay = hp.Choice("learning_rate_decay", [1e-5, 0.0])  # Learning rate decay for gradual reduction.
    clipnorm = hp.Choice("clipnorm", [1.0, 5.0])  # Gradient clipping norm to prevent exploding gradients.
    units = hp.Choice("units", [32, 64, 128])  # Number of units for LSTM layers.
    num_layers = hp.Int("num_layers", 1, 3)  # Number of LSTM layers.
    batch_size = hp.Choice("batch_size", [32, 64, 120, 256])  # Batch size choices.

    # Add LSTM layers based on the number of layers selected.
    for i in range(num_layers):
        return_sequences = (i < num_layers - 1)
        model.add(LSTM(units=units, return_sequences=return_sequences,
                       input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]) if i == 0 else None,
                       kernel_regularizer=l2(l2_lambda), recurrent_dropout=recurrent_dropout))
        model.add(BatchNormalization()) # Add batch normalization to stabilize training.
        model.add(Dropout(dropout_rate))  # Add dropout to help with overfitting.

    model.add(Dense(1))  # Output layer for a single continuous value.
    # Configure optimizer with learning rate, decay, and gradient clipping.
    optimizer = Adam(learning_rate=learning_rate, decay=learning_rate_decay, clipnorm=clipnorm)
     # Compile model with specified optimizer and mean squared error loss.
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    print(f"Built model with params: dropout_rate={dropout_rate}, recurrent_dropout={recurrent_dropout}, "
          f"l2_lambda={l2_lambda}, learning_rate={learning_rate}, learning_rate_decay={learning_rate_decay}, "
          f"clipnorm={clipnorm}, units={units}, num_layers={num_layers}, batch_size={batch_size}")
    
    return model

# Set up Bayesian Optimization tuner to search for optimal hyperparameters.
tuner = BayesianOptimization(
    build_model,  # Model-building function.
    objective="val_loss",  # Target metric for optimization.
    max_trials=30,  # Maximum number of trials to run.
    executions_per_trial=1,  # Number of times to execute each trial.
    directory="tuner_dir",  # Directory to store tuning results.
    project_name="lstm_tuning_capstone",  # Tuning project name.
    overwrite=True  # Overwrite existing tuner results if present.
)

# Define early stopping.
early_stopping = EarlyStopping(monitor="val_loss", patience=20, restore_best_weights=True)

# Perform tuning with verbose logging.
tuner.search(
    X_train_seq, y_train_seq,
    validation_data=(X_test_seq, y_test_seq),
    epochs=200,
    callbacks=[early_stopping],
    shuffle=False,
    verbose=1  # Ensure output of each trial.
)

# Retrieve the best model and hyperparameters.
best_model = tuner.get_best_models(num_models=1)[0]
best_hyperparameters = tuner.get_best_hyperparameters(num_trials=1)[0]

print("Best hyperparameters:", best_hyperparameters.values)
print("Best batch size:", best_hyperparameters.get("batch_size"))
# Out:
# Trial 30 Complete [00h 01m 18s]
# val_loss: 1.7997627258300781
#
# Best val_loss So Far: 1.374737024307251
# Total elapsed time: 01h 08m 37s
# Built model with params: dropout_rate=0.4, recurrent_dropout=0.2, l2_lambda=0.025064206402151706, learning_rate=0.0005, learning_rate_decay=1e-05, clipnorm=1.0, units=32, num_layers=3, batch_size=120
# Best hyperparameters: {'dropout_rate': 0.4, 'recurrent_dropout': 0.2, 'l2_lambda': 0.025064206402151706, 'learning_rate': 0.0005, 'learning_rate_decay': 1e-05, 'clipnorm': 1.0, 'units': 32, 'num_layers': 3, 'batch_size': 120}
# Best batch size: 120

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)
random.seed(random_seed)

# Best hyperparameters found from tuning
best_params = {
    'units1': 32,
    'units2': 32,
    'units3': 32,
    'recurrent_dropout': 0.2,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-05,
    'learning_rate': 0.0005,
    'l2_lambda': 0.025064206402151706,
    'epochs': 100,
    'dropout_rate': 0.4,
    'clipnorm': 1.0,
    'batch_size': 120
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=True, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Second LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units2'], return_sequences=True, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Third LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units3'], return_sequences=False, kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    if params['optimizer'] == 'adam':
        optimizer = Adam(learning_rate=params['learning_rate'], decay=params['learning_rate_decay'], clipnorm=params['clipnorm'])
    else:
        raise ValueError(f"Optimizer '{params['optimizer']}' is not implemented in this setup.")

    # Compile the model
    model.compile(optimizer=optimizer, loss='mean_squared_error')
    
    return model

# Instantiate the model with the best hyperparameters
model = build_best_model(best_params)

# Early stopping to stop training when validation loss stops improving
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Train the model with early stopping
history = model.fit(
    X_train_seq, y_train_seq, 
    epochs=best_params['epochs'], 
    batch_size=best_params['batch_size'], 
    validation_data=(X_test_seq, y_test_seq), 
    shuffle=False,
    callbacks=[early_stopping]
)

# Print the final training and validation loss
print(f"Final Training Loss: {history.history['loss'][-1]}")
print(f"Final Validation Loss: {history.history['val_loss'][-1]}")
# Out:
# Epoch 1/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 77s 1s/step - loss: 7.9163 - val_loss: 4.4116
# Epoch 2/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 4s 118ms/step - loss: 6.4532 - val_loss: 4.3938
# Epoch 3/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 6.1212 - val_loss: 4.3765
# Epoch 4/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 116ms/step - loss: 6.0312 - val_loss: 4.3566
# Epoch 5/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 5.6930 - val_loss: 4.3367
# Epoch 6/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 5.5949 - val_loss: 4.3158
# Epoch 7/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 5.7923 - val_loss: 4.2937
# Epoch 8/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 5.4095 - val_loss: 4.2711
# Epoch 9/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step - loss: 5.2570 - val_loss: 4.2481
# Epoch 10/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 5.2420 - val_loss: 4.2246
# Epoch 11/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 5.1028 - val_loss: 4.1993
# Epoch 12/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 5.2086 - val_loss: 4.1742
# Epoch 13/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 4.9723 - val_loss: 4.1503
# Epoch 14/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 4.7121 - val_loss: 4.1264
# Epoch 15/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 5.1118 - val_loss: 4.1014
# Epoch 16/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 4.7176 - val_loss: 4.0754
# Epoch 17/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 4.5948 - val_loss: 4.0441
# Epoch 18/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 4.6395 - val_loss: 4.0130
# Epoch 19/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 137ms/step - loss: 4.5159 - val_loss: 3.9875
# Epoch 20/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 4.5238 - val_loss: 3.9640
# Epoch 21/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 132ms/step - loss: 4.4100 - val_loss: 3.9382
# Epoch 22/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 4.3885 - val_loss: 3.9093
# Epoch 23/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 144ms/step - loss: 4.5015 - val_loss: 3.8806
# Epoch 24/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 4.2080 - val_loss: 3.8530
# Epoch 25/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - loss: 4.0119 - val_loss: 3.8283
# Epoch 26/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 4.2209 - val_loss: 3.7977
# Epoch 27/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 4.1165 - val_loss: 3.7628
# Epoch 28/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 3.9793 - val_loss: 3.7290
# Epoch 29/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 4.0260 - val_loss: 3.6997
# Epoch 30/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 3.8669 - val_loss: 3.6718
# Epoch 31/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 3.9255 - val_loss: 3.6429
# Epoch 32/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 3.8902 - val_loss: 3.6147
# Epoch 33/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 3.8684 - val_loss: 3.5883
# Epoch 34/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 3.6834 - val_loss: 3.5660
# Epoch 35/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 3.6623 - val_loss: 3.5384
# Epoch 36/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 3.6197 - val_loss: 3.5036
# Epoch 37/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 3.7010 - val_loss: 3.4681
# Epoch 38/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 3.4817 - val_loss: 3.4289
# Epoch 39/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 125ms/step - loss: 3.5185 - val_loss: 3.3951
# Epoch 40/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 3.4268 - val_loss: 3.3602
# Epoch 41/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 3.3356 - val_loss: 3.3291
# Epoch 42/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 137ms/step - loss: 3.5123 - val_loss: 3.3015
# Epoch 43/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 3.3291 - val_loss: 3.2765
# Epoch 44/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 112ms/step - loss: 3.1339 - val_loss: 3.2402
# Epoch 45/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 95ms/step - loss: 3.1844 - val_loss: 3.2092
# Epoch 46/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - loss: 3.0914 - val_loss: 3.1862
# Epoch 47/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 3.1633 - val_loss: 3.1750
# Epoch 48/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - loss: 3.0421 - val_loss: 3.1624
# Epoch 49/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 2.9668 - val_loss: 3.1322
# Epoch 50/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2.9137 - val_loss: 3.1063
# Epoch 51/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 2.7593 - val_loss: 3.0804
# Epoch 52/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2.8542 - val_loss: 3.0715
# Epoch 53/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 120ms/step - loss: 2.8719 - val_loss: 3.0618
# Epoch 54/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 2s 160ms/step - loss: 2.7599 - val_loss: 3.0350
# Epoch 55/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 2.7700 - val_loss: 2.9976
# Epoch 56/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 119ms/step - loss: 2.7663 - val_loss: 2.9620
# Epoch 57/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 109ms/step - loss: 2.6723 - val_loss: 2.9294
# Epoch 58/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 2.7165 - val_loss: 2.9117
# Epoch 59/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - loss: 2.5781 - val_loss: 2.8915
# Epoch 60/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 2.5870 - val_loss: 2.8697
# Epoch 61/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 89ms/step - loss: 2.5325 - val_loss: 2.8399
# Epoch 62/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 2.4725 - val_loss: 2.8142
# Epoch 63/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2.4305 - val_loss: 2.7996
# Epoch 64/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 2.4183 - val_loss: 2.7777
# Epoch 65/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - loss: 2.5195 - val_loss: 2.7482
# Epoch 66/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 118ms/step - loss: 2.4259 - val_loss: 2.7148
# Epoch 67/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 2.3931 - val_loss: 2.6848
# Epoch 68/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2.2795 - val_loss: 2.6644
# Epoch 69/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 2.3404 - val_loss: 2.6520
# Epoch 70/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step - loss: 2.2370 - val_loss: 2.6216
# Epoch 71/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 140ms/step - loss: 2.1813 - val_loss: 2.5995
# Epoch 72/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 2.1496 - val_loss: 2.5910
# Epoch 73/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 2.1411 - val_loss: 2.5797
# Epoch 74/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 139ms/step - loss: 2.1148 - val_loss: 2.5555
# Epoch 75/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 117ms/step - loss: 2.1645 - val_loss: 2.5298
# Epoch 76/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 2.1151 - val_loss: 2.5020
# Epoch 77/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 105ms/step - loss: 2.0745 - val_loss: 2.4847
# Epoch 78/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - loss: 2.0704 - val_loss: 2.4744
# Epoch 79/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.9675 - val_loss: 2.4718
# Epoch 80/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 1.9830 - val_loss: 2.4506
# Epoch 81/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 88ms/step - loss: 1.9282 - val_loss: 2.4064
# Epoch 82/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 1.9126 - val_loss: 2.3813
# Epoch 83/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 93ms/step - loss: 1.9102 - val_loss: 2.3594
# Epoch 84/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 1.9500 - val_loss: 2.3564
# Epoch 85/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 1.8620 - val_loss: 2.3534
# Epoch 86/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 107ms/step - loss: 1.8636 - val_loss: 2.3429
# Epoch 87/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - loss: 1.8184 - val_loss: 2.3276
# Epoch 88/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 115ms/step - loss: 1.8188 - val_loss: 2.3056
# Epoch 89/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - loss: 1.7806 - val_loss: 2.2867
# Epoch 90/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - loss: 1.7816 - val_loss: 2.2703
# Epoch 91/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 123ms/step - loss: 1.7859 - val_loss: 2.2621
# Epoch 92/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - loss: 1.7316 - val_loss: 2.2632
# Epoch 93/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 1.7663 - val_loss: 2.2650
# Epoch 94/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 113ms/step - loss: 1.6592 - val_loss: 2.2537
# Epoch 95/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - loss: 1.7361 - val_loss: 2.2205
# Epoch 96/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 1.6750 - val_loss: 2.1963
# Epoch 97/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 121ms/step - loss: 1.6215 - val_loss: 2.1742
# Epoch 98/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 91ms/step - loss: 1.6256 - val_loss: 2.1614
# Epoch 99/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 149ms/step - loss: 1.6254 - val_loss: 2.1483
# Epoch 100/100
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - loss: 1.5852 - val_loss: 2.1396
# Final Training Loss: 1.5671888589859009
# Final Validation Loss: 2.1396241188049316

# %%
# Predict on both training and test sequences
y_train_pred = model.predict(X_train_seq)
y_test_pred = model.predict(X_test_seq)

# Inverse scale predictions and actual values to original scale
y_train_pred_rescaled = scaler_y.inverse_transform(y_train_pred)
y_test_pred_rescaled = scaler_y.inverse_transform(y_test_pred)
y_train_actual_rescaled = scaler_y.inverse_transform(y_train_seq)
y_test_actual_rescaled = scaler_y.inverse_transform(y_test_seq)

# Define a function for directional accuracy
def directional_accuracy(y_true, y_pred):
    return np.mean((np.sign(y_true[1:] - y_true[:-1]) == np.sign(y_pred[1:] - y_pred[:-1])).astype(int)) * 100

# Calculate metrics.
# Root Mean Squared Error (RMSE) for training set
train_rmse = np.sqrt(mean_squared_error(y_train_actual_rescaled, y_train_pred_rescaled))
test_rmse = np.sqrt(mean_squared_error(y_test_actual_rescaled, y_test_pred_rescaled)) # RMSE for test set.
train_mae = mean_absolute_error(y_train_actual_rescaled, y_train_pred_rescaled) # Mean Absolute Error (MAE) for training set.
test_mae = mean_absolute_error(y_test_actual_rescaled, y_test_pred_rescaled) # MAE for test set.
# Directional accuracy for training set.
train_directional_accuracy = directional_accuracy(y_train_actual_rescaled.flatten(), y_train_pred_rescaled.flatten())
# Directional accuracy for test set.
test_directional_accuracy = directional_accuracy(y_test_actual_rescaled.flatten(), y_test_pred_rescaled.flatten())

# Display score metrics to evaluate the model's performance.
print("LSTM Model Performance:")
print(f"Training RMSE: {train_rmse}")
print(f"Test RMSE: {test_rmse}")
print(f"Training MAE: {train_mae}")
print(f"Test MAE: {test_mae}")
print(f"Directional Accuracy on Training Data: {train_directional_accuracy}%")
print(f"Directional Accuracy on Test Data: {test_directional_accuracy}%")

# Plot training & validation loss values, it will help visualize how well the model fits the data over training epochs.
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 10s 205ms/step
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# LSTM Model Performance:
# Training RMSE: 0.020201890867667695
# Test RMSE: 0.025835920207775084
# Training MAE: 0.014861967951629954
# Test MAE: 0.02043284541149774
# Directional Accuracy on Training Data: 53.94896719319563%
# Directional Accuracy on Test Data: 50.98039215686274%

# %% [markdown]
# ### Cross-Validation for the best model

# %%
# Set random seeds for reproducibility
random_seed = 40
np.random.seed(random_seed)
tf.random.set_seed(random_seed)

# Best hyperparameters
best_params = {
    'units1': 128,
    'recurrent_dropout': 0.1,
    'optimizer': 'adam',
    'loss_function': 'mean_squared_error',
    'learning_rate_decay': 1e-06,
    'learning_rate': 0.001,
    'l2_lambda': 0.0019223481607694784,
    'epochs': 150,
    'dropout_rate': 0.30000000000000004,
    'clipnorm': 5.0,
    'batch_size': 64
}

# Build the model using the best parameters
def build_best_model(params):
    model = Sequential()
    # First LSTM layer with BatchNorm, Dropout, and recurrent_dropout
    model.add(LSTM(units=params['units1'], return_sequences=False, 
                   input_shape=(X_train_seq.shape[1], X_train_seq.shape[2]),
                   kernel_regularizer=l2(params['l2_lambda']), 
                   recurrent_dropout=params['recurrent_dropout']))
    model.add(BatchNormalization())
    model.add(Dropout(params['dropout_rate']))
    
    # Output layer
    model.add(Dense(1))
    
    # Select the optimizer
    optimizer = Adam(learning_rate=params['learning_rate'], 
                     decay=params['learning_rate_decay'], 
                     clipnorm=params['clipnorm'])
    
    # Compile the model
    model.compile(optimizer=optimizer, loss=params['loss_function'])
    
    return model

# Define the number of splits for Time Series Cross-Validation
n_splits = 4
tscv = TimeSeriesSplit(n_splits=n_splits)

# Initialize the list to store RMSE scores
tscv_rmse_scores = []

# Early stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Create the model once and save its initial weights
model = build_best_model(best_params)
initial_weights = model.get_weights()

# Perform TSCV
for fold, (train_index, test_index) in enumerate(tscv.split(X_train_scaled)):
    print(f"Fold {fold + 1}")

    # Reset model to initial weights
    model.set_weights(initial_weights)
    
    # Define train and test sets
    train, test = X_train_scaled[train_index], X_train_scaled[test_index]
    y_train_fold, y_test_fold = y_train_scaled[train_index], y_train_scaled[test_index]
    
    # Create sequences
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Train the model
    history = model.fit(
        X_train_seq, y_train_seq,
        epochs=best_params['epochs'],
        batch_size=best_params['batch_size'],
        validation_data=(X_test_seq, y_test_seq),
        shuffle=False,
        verbose=0,
        callbacks=[early_stopping]
    )
    
    # Predict and evaluate
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    tscv_rmse_scores.append(rmse)
    print(f"Fold {fold + 1} RMSE: {rmse}")

# Calculate the average RMSE across all folds
avg_rmse = np.mean(tscv_rmse_scores)
print(f"Average RMSE from TSCV: {avg_rmse}")
# Out:
# Fold 1
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Fold 1 RMSE: 1.4798433156674633
# Fold 2
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 2 RMSE: 0.7653262631352602
# Fold 3
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 3 RMSE: 0.7561677292282575
# Fold 4
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Fold 4 RMSE: 1.1977075564449342
# Average RMSE from TSCV: 1.0497612161189789

# %%
# Parameters for FRWCV
train_window = 300  # Training window size
test_window = 53    # Test window size

# Store RMSEs for each window
rolling_rmse_scores = []

for start in range(0, len(X_train_scaled) - train_window - test_window, test_window):
    print(f"Rolling window starting at index {start}")
    
    # Define train and test sets for the window
    train = X_train_scaled[start:start + train_window]
    test = X_train_scaled[start + train_window:start + train_window + test_window]
    y_train_fold = y_train_scaled[start:start + train_window]
    y_test_fold = y_train_scaled[start + train_window:start + train_window + test_window]
    
    # Create sequences for train and test
    X_train_seq, y_train_seq = [], []
    for i in range(len(train) - sequence_length):
        X_train_seq.append(train[i:i + sequence_length])
        y_train_seq.append(y_train_fold[i + sequence_length])
    
    X_test_seq, y_test_seq = [], []
    for i in range(len(test) - sequence_length):
        X_test_seq.append(test[i:i + sequence_length])
        y_test_seq.append(y_test_fold[i + sequence_length])
    
    # Convert to numpy arrays
    X_train_seq, y_train_seq = np.array(X_train_seq), np.array(y_train_seq)
    X_test_seq, y_test_seq = np.array(X_test_seq), np.array(y_test_seq)
    
    # Build and train the model
    model = build_best_model(best_params)
    history = model.fit(
        X_train_seq, y_train_seq, 
        epochs=best_params['epochs'], 
        batch_size=best_params['batch_size'], 
        validation_data=(X_test_seq, y_test_seq), 
        shuffle=False,
        verbose=0,  # Suppress training logs for brevity
        callbacks=[early_stopping]
    )
    
    # Evaluate on the test set
    y_pred = model.predict(X_test_seq)
    rmse = np.sqrt(mean_squared_error(y_test_seq, y_pred))
    rolling_rmse_scores.append(rmse)
    print(f"Rolling window RMSE: {rmse}")

# Calculate average RMSE across rolling windows
avg_rolling_rmse = np.mean(rolling_rmse_scores)
print(f"Average Rolling Window RMSE: {avg_rolling_rmse}")
# Out:
# Rolling window starting at index 0
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Rolling window RMSE: 0.5848774968499016
# Rolling window starting at index 53
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Rolling window RMSE: 0.49515099621999115
# Rolling window starting at index 106
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
# Rolling window RMSE: 0.3491962130026016
# Rolling window starting at index 159
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Rolling window RMSE: 0.023286622005266294
# Rolling window starting at index 212
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Rolling window RMSE: 0.8242264277418622
# Rolling window starting at index 265
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Rolling window RMSE: 0.5897786893246871
# Rolling window starting at index 318
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step
# Rolling window RMSE: 0.21980296998516416
# Rolling window starting at index 371
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# Rolling window RMSE: 0.17773687427233079
# Rolling window starting at index 424
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 146ms/step
# Rolling window RMSE: 0.4639890156514293
# Rolling window starting at index 477
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# Rolling window RMSE: 3.523493773157845
# Average Rolling Window RMSE: 0.725153907821108

# %%
# Extracting train and val loss:
scaled_train_loss = history.history['loss'][-1]  # Final train loss
scaled_val_loss = history.history['val_loss'][-1]  # Final validation loss

# Descale train and validation loss
descaled_train_loss = np.sqrt(scaled_train_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]
descaled_val_loss = np.sqrt(scaled_val_loss) * scaler_y.scale_[0] + scaler_y.mean_[0]

print(f"Descaled Training Loss: {descaled_train_loss}")
print(f"Descaled Validation Loss: {descaled_val_loss}")
# Out:
# Descaled Training Loss: 0.024312027947046056
# Descaled Validation Loss: 0.07295831226156373

# %%
# Function to descale RMSE
def descale_rmse(scaled_rmse, scaler_y):
    # Reshape RMSE value to fit scaler requirements
    scaled_rmse_array = np.array(scaled_rmse).reshape(-1, 1)
    # Inverse transform the RMSE
    descaled_rmse_array = scaler_y.inverse_transform(scaled_rmse_array)
    # Return the descaled RMSE as a list
    return descaled_rmse_array.flatten().tolist()

# Descale TSCV RMSE values
descaled_tscv_rmse = descale_rmse(tscv_rmse_scores, scaler_y)
print("Descaled TSCV RMSE Values:", descaled_tscv_rmse)

# Descale FRWCV RMSE values
descaled_frwcv_rmse = descale_rmse(rolling_rmse_scores, scaler_y)
print("Descaled FRWCV RMSE Values:", descaled_frwcv_rmse)

# Calculates average descaled RMSE
average_tscv_rmse = np.mean(descaled_tscv_rmse)
average_frwcv_rmse = np.mean(descaled_frwcv_rmse)
print(f"Average Descaled TSCV RMSE: {average_tscv_rmse}")
print(f"Average Descaled FRWCV RMSE: {average_frwcv_rmse}")
# Out:
# Descaled TSCV RMSE Values: [0.031573491898335485, 0.01708517219045974, 0.016899463862254244, 0.02585260243019221]
# Descaled FRWCV RMSE Values: [0.013426198051817762, 0.011606806586228539, 0.008647269714920726, 0.002038774741290126, 0.01827949556264895, 0.013525579925592324, 0.006023552525482477, 0.005170574921393507, 0.01097493260140494, 0.07301275649577867]
# Average Descaled TSCV RMSE: 0.022852682595310418
# Average Descaled FRWCV RMSE: 0.0162705941126558

# %% [markdown]
# ### Model Performance Metrics for Sequence Length = 52
#
# | Metric         | Model 1       | Model 2       | Model 3       | Model 4       |
# |-----------------|---------------|---------------|---------------|---------------|
# | **Train RMSE** | 0.020443237   | 0.02157058    | 0.020614848   | 0.020201891   |
# | **Test RMSE**  | 0.025435926   | 0.025544103   | 0.025500471   | 0.02583592    |
# | **Train MAE**  | 0.014981374   | 0.01609211    | 0.014900086   | 0.014861968   |
# | **Test MAE**   | 0.020283158   | 0.019771341   | 0.019994079   | 0.020432845   |
# | **Train Loss** | 1.459251523   | 1.30606246    | 1.350898147   | 1.567188859   |
# | **Val Loss**   | 1.64723587    | 1.789971828   | 1.422319174   | 2.139624119   |
# | **Train DA**   | 64%           | 61%           | 59%           | 54%           |
# | **Test DA**    | 55%           | 60%           | 71%           | 51%           |
#
# **The best performer for the sequence length of 52 is  the model 3**, having one of the lowest metrics of all models and its train and val loss plot shows more stability than the others.
#
# ### Evaluation Metrics
#
# #### Training and Validation Loss
# | Metric           | Loss           |
# |-------------------|----------------|
# | **Training Loss** | 0.02403875     |
# | **Validation Loss** | 0.03605487    |
#
# #### TSCV RMSE Values
# | Fold | RMSE           |
# |------|----------------|
# | 1    | 0.02991598     |
# | 2    | 0.02073949     |
# | 3    | 0.01687027     |
# | 4    | 0.02478928     |
#
# **Average TSCV RMSE**: **0.02307875**
#
# - The SL = 52 has same performance as the others SL. Thus, despite different sequence length and acrchitectures the technology underperforms at the start and at the end.

# %% [markdown]
# ## Evaluation
#
# ## LSTM - Standard Scaling Performance Metrics
#
# | Metrics        | SL = 4         | SL = 12         | SL = 26         | SL = 52         |
# |-----------------|----------------|-----------------|-----------------|-----------------|
# | **Train RMSE** | 0.020128678    | 0.020418636     | 0.020233156     | 0.020614848     |
# | **Test RMSE**  | 0.022446095    | 0.023153177     | 0.023801557     | 0.025500471     |
# | **Train MAE**  | 0.014421072    | 0.014849        | 0.01472121      | 0.014900086     |
# | **Test MAE**   | 0.016954642    | 0.017508652     | 0.018203911     | 0.019994079     |
# | **Train Loss** | 0.89046818     | 1.371209502     | 1.003272176     | 1.350898147     |
# | **Val Loss**   | 1.31695807     | 1.116409898     | 1.024671555     | 1.422319174     |
# | **Avg RMSE - TSCV** | 1.049797895 | 1.065019938     | 1.05921564      | 1.050389102     |
# | **Avg RMSE - FRWCV** | 0.92217397  | 0.944819762     | 0.929217867     | 0.704554111     |
# | **Train DA**   | 63%            | 44%             | 71%             | 59.00%          |
# | **Test DA**    | 59%            | 51%             | 66%             | 71.00%          |
#
# ---
#
# #### Training and Validation Loss
# | Sequence Length (SL) | Training Loss | Validation Loss |
# |-----------------------|---------------|-----------------|
# | **SL = 4**                | 0.02419945    | 0.02866454      |
# | **SL = 12**               | 0.02740653    | 0.03006650      |
# | **SL = 26**               | 0.02740653    | 0.03006650      |
# | **SL = 52**               | 0.02403875    | 0.03605487      |
#
# ---
#
# #### TSCV RMSE Comparison
# | Sequence Length (SL) | Fold 1 RMSE | Fold 2 RMSE | Fold 3 RMSE | Fold 4 RMSE | Average TSCV RMSE |
# |-----------------------|-------------|-------------|-------------|-------------|-------------------|
# | **SL = 4**           | 0.02949634  | 0.02064368  | 0.01744158  | 0.02371384  | **0.02282386**    |
# | **SL = 12**          | 0.02985034  | 0.02080377  | 0.01759171  | 0.02455836  | **0.02320104**    |
# | **SL = 26**          | 0.02985034  | 0.02080377  | 0.01759171  | 0.02455836  | **0.02320104**    |
# | **SL = 52**          | 0.02991598  | 0.02073949  | 0.01687027  | 0.02478928  | **0.02307875**    |
#
# ---
#
# #### FRWCV RMSE Comparison
# | Sequence Length (SL) | Window 1 RMSE | Window 2 RMSE | Window 3 RMSE | Window 4 RMSE | Window 5 RMSE | Window 6 RMSE | Window 7 RMSE | Window 8 RMSE | Window 9 RMSE | Window 10 RMSE | Window 11 RMSE | Average FRWCV RMSE |
# |-----------------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|---------------|----------------|----------------|-------------------|
# | **SL = 4**           | 0.02596537    | 0.02702303    | 0.01925910    | 0.01631107    | 0.01668102    | 0.01931634    | 0.01828439    | 0.01194746    | 0.01683637    | 0.02289894     | 0.02835240     | **0.02026141**    |
# | **SL = 12**          | 0.02757438    | 0.02959550    | 0.02023437    | 0.01735611    | 0.01755435    | 0.01970751    | 0.01972974    | 0.01081270    | 0.01792799    | 0.02069211     | 0.03016555     | **0.02103185**    |
# | **SL = 26**          | 0.02757438    | 0.02959550    | 0.02023437    | 0.01735611    | 0.01755435    | 0.01970751    | 0.01972974    | 0.01081270    | 0.01792799    | 0.02069211     | 0.03016555     | **0.02103185**    |
#
# ### Best Model: Sequence Length = 4.
#
# The LSTM model that yielded the best balanced performance was the sequence length of 4 (approx. One Month), having the lowest RMSE and MAE scores. Cross validation also shows that all sequences are generalizing well across different folds.
# In addition, by observing the cross-validation table, it shows that the SL = 4, is more stable across different periods. It performed well on both TSCV and FRWCV.
